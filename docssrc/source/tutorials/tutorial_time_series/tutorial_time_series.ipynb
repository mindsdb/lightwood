# %% [markdown]
# # Tutorial - Time series forecasting
#
# ## Introduction
#
# Time series are an ubiquitous type of data in all types of processes. Producing forecasts for them can be highly valuable in domains like retail or industrial manufacture, among many others.
#
# Lightwood supports time series forecasting (both univariate and multivariate inputs), handling many of the pain points commonly associated with setting up a manual time series predictive pipeline.
#
# In this tutorial, we will train a lightwood predictor and analyze its forecasts for the task of counting sunspots in monthly intervals.
#
# ## Load data
#
# Let's begin by loading the dataset and looking at it:

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/mindsdb/benchmarks/main/benchmarks/datasets/monthly_sunspots/data.csv")
df
# Out:
#         Month  Sunspots
# 0     1749-01      58.0
# 1     1749-02      62.6
# 2     1749-03      70.0
# 3     1749-04      55.7
# 4     1749-05      85.0
# ...       ...       ...
# 2815  1983-08      71.8
# 2816  1983-09      50.3
# 2817  1983-10      55.8
# 2818  1983-11      33.3
# 2819  1983-12      33.4
#
# [2820 rows x 2 columns]

# %% [markdown]
# This is a very simple dataset. It's got a single column that specifies the month in which the measurement was done, and then in the 'Sunspots' column we have the actual quantity we are interested in forecasting. As such, we can characterize this as a univariate time series problem.
#
# ## Define the predictive task
#
# We will use Lightwood high level methods to state what we want to predict. As this is a time series task (because we want to leverage the notion of time to predict), we need to specify a set of arguments that will activate Lightwood's time series pipeline:

# %%
from lightwood.api.high_level import ProblemDefinition

# %%
tss = {'horizon': 6,   # the predictor will learn to forecast what the next semester counts will look like (6 data points at monthly intervals -> 6 months)
       'order_by': 'Month', # what column is used to order the entire datset
       'window': 12           # how many past values to consider for emitting predictions
      }

pdef = ProblemDefinition.from_dict({'target': 'Sunspots',         # specify the column to forecast
                                    'timeseries_settings': tss    # pass along all time series specific parameters
                                   })

# %% [markdown]
# Now, let's do a very simple train-test split, leaving 10% of the data to check the forecasts that our predictor will produce:

# %%
cutoff = int(len(df)*0.9)

train = df[:cutoff]
test = df[cutoff:]

print(train.shape, test.shape)
# Out:
# (2538, 2) (282, 2)

# %% [markdown]
# ## Generate the predictor object
#
# Now, we can generate code for a machine learning model by using our problem definition and the data:

# %%
from lightwood.api.high_level import (
    json_ai_from_problem,
    code_from_json_ai,
    predictor_from_code
)

json_ai = json_ai_from_problem(df, problem_definition=pdef)
code = code_from_json_ai(json_ai)
predictor = predictor_from_code(code)

# uncomment this to see the generated code:
# print(code)
# Out:
# INFO:lightwood-1463050:Dropping features: []
# INFO:lightwood-1463050:Analyzing a sample of 2467
# INFO:lightwood-1463050:from a total population of 2820, this is equivalent to 87.5% of your data.
# INFO:lightwood-1463050:Using 7 processes to deduct types.
# INFO:lightwood-1463050:Infering type for: Sunspots
# INFO:lightwood-1463050:Infering type for: Month
# INFO:lightwood-1463050:Column Sunspots has data type float
# INFO:lightwood-1463050:Column Month has data type date
# /home/george/lightwood/lightwood/helpers/text.py:242: RuntimeWarning: invalid value encountered in double_scalars
#   randomness_per_index.append(S / np.log(N))
# INFO:lightwood-1463050:Starting statistical analysis
# INFO:lightwood-1463050:Finished statistical analysis

# %% [markdown]
# ## Train
#
# Okay, everything is ready now for our predictor to learn based on the training data we will provide.
#
# Internally, lightwood cleans and reshapes the data, featurizes measurements and timestamps, and comes up with a handful of different models that will be evaluated to keep the one that produces the best forecasts.
#
# Let's train the predictor. This should take a couple of minutes, at most:

# %%
predictor.learn(train)
# Out:
# INFO:lightwood-1463050:Dropping features: []
# INFO:lightwood-1463050:Performing statistical analysis on data
# INFO:lightwood-1463050:Starting statistical analysis
# INFO:lightwood-1463050:Finished statistical analysis
# DEBUG:lightwood-1463050: `analyze_data` runtime: 0.06 seconds
# INFO:lightwood-1463050:Cleaning the data
# INFO:lightwood-1463050:Transforming timeseries data
# INFO:lightwood-1463050:Using 7 processes to reshape.
# DEBUG:lightwood-1463050: `preprocess` runtime: 4.57 seconds
# INFO:lightwood-1463050:Splitting the data into train/test
# DEBUG:lightwood-1463050: `split` runtime: 0.0 seconds
# INFO:lightwood-1463050:Preparing the encoders
# INFO:lightwood-1463050:Encoder prepping dict length of: 1
# INFO:lightwood-1463050:Done running for: Sunspots
# DEBUG:lightwood-1463050: `prepare` runtime: 0.16 seconds
# INFO:lightwood-1463050:Featurizing the data
# DEBUG:lightwood-1463050: `featurize` runtime: 0.0 seconds
# INFO:lightwood-1463050:Training the mixers
# Found `num_iterations` in params. Will use it instead of argument
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-1463050:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-1463050:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-1463050:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-1463050:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-1463050:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-1463050:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
# This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1025.)
# INFO:lightwood-1463050:Loss of 0.5444552898406982 with learning rate 0.0001
# INFO:lightwood-1463050:Loss of 0.6546932458877563 with learning rate 0.00014
# INFO:lightwood-1463050:Found learning rate of: 0.0001
# torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
# INFO:lightwood-1463050:Loss @ epoch 1: 0.5853886306285858
# INFO:lightwood-1463050:Loss @ epoch 2: 0.580808088183403
# INFO:lightwood-1463050:Loss @ epoch 3: 0.5753300935029984
# INFO:lightwood-1463050:Loss @ epoch 4: 0.5690591186285019
# INFO:lightwood-1463050:Loss @ epoch 5: 0.562119647860527
# INFO:lightwood-1463050:Loss @ epoch 6: 0.5546740740537643
# INFO:lightwood-1463050:Loss @ epoch 7: 0.541803777217865
# INFO:lightwood-1463050:Loss @ epoch 8: 0.5331597924232483
# INFO:lightwood-1463050:Loss @ epoch 9: 0.5242291688919067
# INFO:lightwood-1463050:Loss @ epoch 10: 0.5150940418243408
# INFO:lightwood-1463050:Loss @ epoch 11: 0.5058085471391678
# INFO:lightwood-1463050:Loss @ epoch 12: 0.4964483380317688
# INFO:lightwood-1463050:Loss @ epoch 13: 0.48120442032814026
# INFO:lightwood-1463050:Loss @ epoch 14: 0.47158895432949066
# INFO:lightwood-1463050:Loss @ epoch 15: 0.4620226323604584
# INFO:lightwood-1463050:Loss @ epoch 16: 0.45251402258872986
# INFO:lightwood-1463050:Loss @ epoch 17: 0.443060502409935
# INFO:lightwood-1463050:Loss @ epoch 18: 0.4337444603443146
# INFO:lightwood-1463050:Loss @ epoch 19: 0.4190395623445511
# INFO:lightwood-1463050:Loss @ epoch 20: 0.4099678099155426
# INFO:lightwood-1463050:Loss @ epoch 21: 0.40111230313777924
# INFO:lightwood-1463050:Loss @ epoch 22: 0.39240410923957825
# INFO:lightwood-1463050:Loss @ epoch 23: 0.38385041058063507
# INFO:lightwood-1463050:Loss @ epoch 24: 0.3755306005477905
# INFO:lightwood-1463050:Loss @ epoch 25: 0.36262111365795135
# INFO:lightwood-1463050:Loss @ epoch 26: 0.3549261763691902
# INFO:lightwood-1463050:Loss @ epoch 27: 0.34744693338871
# INFO:lightwood-1463050:Loss @ epoch 28: 0.3402143120765686
# INFO:lightwood-1463050:Loss @ epoch 29: 0.3331300914287567
# INFO:lightwood-1463050:Loss @ epoch 30: 0.3263566195964813
# INFO:lightwood-1463050:Loss @ epoch 31: 0.3160539045929909
# INFO:lightwood-1463050:Loss @ epoch 32: 0.3099663704633713
# INFO:lightwood-1463050:Loss @ epoch 33: 0.30408596247434616
# INFO:lightwood-1463050:Loss @ epoch 34: 0.2983786165714264
# INFO:lightwood-1463050:Loss @ epoch 35: 0.2929398939013481
# INFO:lightwood-1463050:Loss @ epoch 36: 0.2877756729722023
# INFO:lightwood-1463050:Loss @ epoch 37: 0.27998822927474976
# INFO:lightwood-1463050:Loss @ epoch 38: 0.2754269316792488
# INFO:lightwood-1463050:Loss @ epoch 39: 0.2710350602865219
# INFO:lightwood-1463050:Loss @ epoch 40: 0.2668045908212662
# INFO:lightwood-1463050:Loss @ epoch 41: 0.26270343363285065
# INFO:lightwood-1463050:Loss @ epoch 42: 0.25884169340133667
# INFO:lightwood-1463050:Loss @ epoch 43: 0.2531554400920868
# INFO:lightwood-1463050:Loss @ epoch 44: 0.2498394474387169
# INFO:lightwood-1463050:Loss @ epoch 45: 0.24671050906181335
# INFO:lightwood-1463050:Loss @ epoch 46: 0.2437400370836258
# INFO:lightwood-1463050:Loss @ epoch 47: 0.24087387323379517
# INFO:lightwood-1463050:Loss @ epoch 48: 0.2383270114660263
# INFO:lightwood-1463050:Loss @ epoch 49: 0.23459460586309433
# INFO:lightwood-1463050:Loss @ epoch 50: 0.23245877772569656
# INFO:lightwood-1463050:Loss @ epoch 51: 0.23046986013650894
# INFO:lightwood-1463050:Loss @ epoch 52: 0.2285878211259842
# INFO:lightwood-1463050:Loss @ epoch 53: 0.22672255337238312
# INFO:lightwood-1463050:Loss @ epoch 54: 0.22505808621644974
# INFO:lightwood-1463050:Loss @ epoch 55: 0.22254633903503418
# INFO:lightwood-1463050:Loss @ epoch 56: 0.22107311338186264
# INFO:lightwood-1463050:Loss @ epoch 57: 0.2196943163871765
# INFO:lightwood-1463050:Loss @ epoch 58: 0.21825608611106873
# INFO:lightwood-1463050:Loss @ epoch 59: 0.21678689122200012
# INFO:lightwood-1463050:Loss @ epoch 60: 0.2154833972454071
# INFO:lightwood-1463050:Loss @ epoch 61: 0.21356754004955292
# INFO:lightwood-1463050:Loss @ epoch 62: 0.2124105989933014
# INFO:lightwood-1463050:Loss @ epoch 63: 0.21124501526355743
# INFO:lightwood-1463050:Loss @ epoch 64: 0.21015223860740662
# INFO:lightwood-1463050:Loss @ epoch 65: 0.209126777946949
# INFO:lightwood-1463050:Loss @ epoch 66: 0.20824934542179108
# INFO:lightwood-1463050:Loss @ epoch 67: 0.2068568617105484
# INFO:lightwood-1463050:Loss @ epoch 68: 0.20601419359445572
# INFO:lightwood-1463050:Loss @ epoch 69: 0.20517831295728683
# INFO:lightwood-1463050:Loss @ epoch 70: 0.20434069633483887
# INFO:lightwood-1463050:Loss @ epoch 71: 0.20354937762022018
# INFO:lightwood-1463050:Loss @ epoch 72: 0.20291871577501297
# INFO:lightwood-1463050:Loss @ epoch 73: 0.2019302248954773
# INFO:lightwood-1463050:Loss @ epoch 74: 0.20130783319473267
# INFO:lightwood-1463050:Loss @ epoch 75: 0.20075786858797073
# INFO:lightwood-1463050:Loss @ epoch 76: 0.2002377286553383
# INFO:lightwood-1463050:Loss @ epoch 77: 0.19980251044034958
# INFO:lightwood-1463050:Loss @ epoch 78: 0.19944210350513458
# INFO:lightwood-1463050:Loss @ epoch 79: 0.19888445734977722
# INFO:lightwood-1463050:Loss @ epoch 80: 0.1985197514295578
# INFO:lightwood-1463050:Loss @ epoch 81: 0.19818712025880814
# INFO:lightwood-1463050:Loss @ epoch 82: 0.19788052886724472
# INFO:lightwood-1463050:Loss @ epoch 83: 0.19756736606359482
# INFO:lightwood-1463050:Loss @ epoch 84: 0.19728951901197433
# INFO:lightwood-1463050:Loss @ epoch 85: 0.1969028115272522
# INFO:lightwood-1463050:Loss @ epoch 86: 0.1966378539800644
# INFO:lightwood-1463050:Loss @ epoch 87: 0.19641628861427307
# INFO:lightwood-1463050:Loss @ epoch 88: 0.19617554545402527
# INFO:lightwood-1463050:Loss @ epoch 89: 0.19594408571720123
# INFO:lightwood-1463050:Loss @ epoch 90: 0.1957668662071228
# INFO:lightwood-1463050:Loss @ epoch 91: 0.1955953910946846
# INFO:lightwood-1463050:Loss @ epoch 92: 0.19542814046144485
# INFO:lightwood-1463050:Loss @ epoch 93: 0.1952785775065422
# INFO:lightwood-1463050:Loss @ epoch 94: 0.19511037319898605
# INFO:lightwood-1463050:Loss @ epoch 95: 0.1948755457997322
# INFO:lightwood-1463050:Loss @ epoch 96: 0.19469106197357178
# INFO:lightwood-1463050:Loss @ epoch 97: 0.19448262453079224
# INFO:lightwood-1463050:Loss @ epoch 98: 0.1942855715751648
# INFO:lightwood-1463050:Loss @ epoch 99: 0.19409507513046265
# INFO:lightwood-1463050:Loss @ epoch 100: 0.19389601796865463
# INFO:lightwood-1463050:Loss @ epoch 101: 0.1936223953962326
# INFO:lightwood-1463050:Loss @ epoch 102: 0.19342924654483795
# INFO:lightwood-1463050:Loss @ epoch 103: 0.1932876631617546
# INFO:lightwood-1463050:Loss @ epoch 104: 0.19316721707582474
# INFO:lightwood-1463050:Loss @ epoch 105: 0.1929512768983841
# INFO:lightwood-1463050:Loss @ epoch 106: 0.19277466088533401
# INFO:lightwood-1463050:Loss @ epoch 107: 0.1925048530101776
# INFO:lightwood-1463050:Loss @ epoch 108: 0.19230249524116516
# INFO:lightwood-1463050:Loss @ epoch 109: 0.1921129897236824
# INFO:lightwood-1463050:Loss @ epoch 110: 0.19201530516147614
# INFO:lightwood-1463050:Loss @ epoch 111: 0.19181131571531296
# INFO:lightwood-1463050:Loss @ epoch 112: 0.19155265390872955
# INFO:lightwood-1463050:Loss @ epoch 113: 0.19127685576677322
# INFO:lightwood-1463050:Loss @ epoch 114: 0.19108089804649353
# INFO:lightwood-1463050:Loss @ epoch 115: 0.19087017327547073
# INFO:lightwood-1463050:Loss @ epoch 116: 0.19084925204515457
# INFO:lightwood-1463050:Loss @ epoch 117: 0.19071821868419647
# INFO:lightwood-1463050:Loss @ epoch 118: 0.19043069332838058
# INFO:lightwood-1463050:Loss @ epoch 119: 0.190192811191082
# INFO:lightwood-1463050:Loss @ epoch 120: 0.18999629467725754
# INFO:lightwood-1463050:Loss @ epoch 121: 0.18975628912448883
# INFO:lightwood-1463050:Loss @ epoch 122: 0.18985112756490707
# INFO:lightwood-1463050:Loss @ epoch 123: 0.18978626281023026
# INFO:lightwood-1463050:Loss @ epoch 124: 0.18951784074306488
# INFO:lightwood-1463050:Loss @ epoch 125: 0.18934376537799835
# INFO:lightwood-1463050:Loss @ epoch 126: 0.18920215219259262
# INFO:lightwood-1463050:Loss @ epoch 127: 0.18899983167648315
# INFO:lightwood-1463050:Loss @ epoch 128: 0.18885128945112228
# INFO:lightwood-1463050:Loss @ epoch 129: 0.18866226822137833
# INFO:lightwood-1463050:Loss @ epoch 130: 0.18846739828586578
# INFO:lightwood-1463050:Loss @ epoch 131: 0.18824516981840134
# INFO:lightwood-1463050:Loss @ epoch 132: 0.18805904686450958
# INFO:lightwood-1463050:Loss @ epoch 133: 0.18798783421516418
# INFO:lightwood-1463050:Loss @ epoch 134: 0.18805307894945145
# INFO:lightwood-1463050:Loss @ epoch 135: 0.1877892017364502
# INFO:lightwood-1463050:Loss @ epoch 136: 0.18759506195783615
# INFO:lightwood-1463050:Loss @ epoch 137: 0.1873171478509903
# INFO:lightwood-1463050:Loss @ epoch 138: 0.18714189529418945
# INFO:lightwood-1463050:Loss @ epoch 139: 0.18690240383148193
# INFO:lightwood-1463050:Loss @ epoch 140: 0.1871059089899063
# torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
# INFO:lightwood-1463050:Loss @ epoch 1: 0.14333829283714294
# INFO:lightwood-1463050:Loss @ epoch 2: 0.14343232661485672
# INFO:lightwood-1463050:Loss @ epoch 3: 0.14535161988301712
# INFO:lightwood-1463050:Loss @ epoch 4: 0.14517992734909058
# INFO:lightwood-1463050:Loss @ epoch 5: 0.14617340131239456
# INFO:lightwood-1463050:Started fitting LGBM models for array prediction
# INFO:lightwood-1463050:Started fitting LGBM model
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-1463050:Training GBM (<module 'lightgbm' from '/home/george/.local/lib/python3.8/site-packages/lightgbm/__init__.py'>) with 38015 iterations given 4751.937255382538 seconds constraint
# INFO:lightwood-1463050:Lightgbm model contains 26 weak estimators
# INFO:lightwood-1463050:Updating lightgbm model with 1.5 iterations
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:Model now has a total of 27 weak estimators
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:lightwood-1463050:Started fitting LGBM model
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-1463050:Training GBM (<module 'lightgbm' from '/home/george/.local/lib/python3.8/site-packages/lightgbm/__init__.py'>) with 38015 iterations given 4751.935502767563 seconds constraint
# INFO:lightwood-1463050:Lightgbm model contains 23 weak estimators
# INFO:lightwood-1463050:Updating lightgbm model with 1 iterations
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:Model now has a total of 24 weak estimators
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:lightwood-1463050:Started fitting LGBM model
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-1463050:Training GBM (<module 'lightgbm' from '/home/george/.local/lib/python3.8/site-packages/lightgbm/__init__.py'>) with 38015 iterations given 4751.924700498581 seconds constraint
# INFO:lightwood-1463050:Lightgbm model contains 23 weak estimators
# INFO:lightwood-1463050:Updating lightgbm model with 1 iterations
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:Model now has a total of 24 weak estimators
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:lightwood-1463050:Started fitting LGBM model
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-1463050:Training GBM (<module 'lightgbm' from '/home/george/.local/lib/python3.8/site-packages/lightgbm/__init__.py'>) with 38015 iterations given 4751.931957960129 seconds constraint
# INFO:lightwood-1463050:Lightgbm model contains 20 weak estimators
# INFO:lightwood-1463050:Updating lightgbm model with 1 iterations
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:Model now has a total of 21 weak estimators
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:lightwood-1463050:Started fitting LGBM model
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-1463050:Training GBM (<module 'lightgbm' from '/home/george/.local/lib/python3.8/site-packages/lightgbm/__init__.py'>) with 38015 iterations given 4751.932721853256 seconds constraint
# INFO:lightwood-1463050:Lightgbm model contains 15 weak estimators
# INFO:lightwood-1463050:Updating lightgbm model with 1 iterations
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:Model now has a total of 16 weak estimators
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:lightwood-1463050:Started fitting LGBM model
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-1463050:Training GBM (<module 'lightgbm' from '/home/george/.local/lib/python3.8/site-packages/lightgbm/__init__.py'>) with 38015 iterations given 4751.939363241196 seconds constraint
# INFO:lightwood-1463050:Lightgbm model contains 19 weak estimators
# INFO:lightwood-1463050:Updating lightgbm model with 1 iterations
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:Model now has a total of 20 weak estimators
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:lightwood-1463050:Started fitting sktime forecaster for array prediction
# INFO:lightwood-1463050:Ensembling the mixer
# INFO:lightwood-1463050:Mixer: Neural got accuracy: 0.5134282507923681
# WARNING:lightwood-1463050:This model does not output probability estimates
# INFO:lightwood-1463050:Mixer: LightGBMArray got accuracy: 0.453306526262744
# WARNING:lightwood-1463050:This mixer does not output probability estimates
# INFO:lightwood-1463050:Mixer: SkTime got accuracy: 0.214814641323111
# INFO:lightwood-1463050:Picked best mixer: Neural
# DEBUG:lightwood-1463050: `fit` runtime: 199.32 seconds
# INFO:lightwood-1463050:Analyzing the ensemble of mixers
# INFO:lightwood-1463050:The block ICP is now running its analyze() method
# INFO:lightwood-1463050:The block AccStats is now running its analyze() method
# INFO:lightwood-1463050:The block ConfStats is now running its analyze() method
# DEBUG:lightwood-1463050: `analyze_ensemble` runtime: 0.17 seconds
# INFO:lightwood-1463050:Adjustment on validation requested.
# INFO:lightwood-1463050:Updating the mixers
# torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
# INFO:lightwood-1463050:Loss @ epoch 1: 0.1468940774599711
# INFO:lightwood-1463050:Loss @ epoch 2: 0.14706196015079817
# INFO:lightwood-1463050:Loss @ epoch 3: 0.1463029384613037
# INFO:lightwood-1463050:Loss @ epoch 4: 0.14618245512247086
# INFO:lightwood-1463050:Loss @ epoch 5: 0.14700218041737875
# INFO:lightwood-1463050:Updating array of LGBM models...
# INFO:lightwood-1463050:Updating lightgbm model with 1.5 iterations
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:Model now has a total of 28 weak estimators
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:lightwood-1463050:Updating lightgbm model with 1 iterations
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:Model now has a total of 25 weak estimators
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:lightwood-1463050:Updating lightgbm model with 1 iterations
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:Model now has a total of 25 weak estimators
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:lightwood-1463050:Updating lightgbm model with 1 iterations
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:Model now has a total of 22 weak estimators
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:lightwood-1463050:Updating lightgbm model with 1 iterations
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:Model now has a total of 17 weak estimators
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:lightwood-1463050:Updating lightgbm model with 1 iterations
# Found `num_iterations` in params. Will use it instead of argument
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# INFO:lightwood-1463050:Model now has a total of 21 weak estimators
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:lightwood-1463050:Started fitting sktime forecaster for array prediction
# DEBUG:lightwood-1463050: `adjust` runtime: 99.83 seconds
# DEBUG:lightwood-1463050: `learn` runtime: 304.13 seconds

# %% [markdown]
# ## Predict
#
# Once the predictor has trained, we can use it to generate 6-month forecasts for each of the test set data points:

# %%
forecasts = predictor.predict(test)
# Out:
# INFO:lightwood-1463050:Dropping features: []
# INFO:lightwood-1463050:Cleaning the data
# INFO:lightwood-1463050:Transforming timeseries data
# DEBUG:lightwood-1463050: `preprocess` runtime: 0.6 seconds
# INFO:lightwood-1463050:Featurizing the data
# DEBUG:lightwood-1463050: `featurize` runtime: 0.0 seconds
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:lightwood-1463050:The block ICP is now running its explain() method
# INFO:lightwood-1463050:The block AccStats is now running its explain() method
# INFO:lightwood-1463050:AccStats.explain() has not been implemented, no modifications will be done to the data insights.
# INFO:lightwood-1463050:The block ConfStats is now running its explain() method
# INFO:lightwood-1463050:ConfStats.explain() has not been implemented, no modifications will be done to the data insights.
# DEBUG:lightwood-1463050: `predict` runtime: 1.28 seconds

# %% [markdown]
# Let's check how a single row might look:

# %%
forecasts.iloc[[10]]
# Out:
#     original_index                                         prediction  \
# 10              10  [61.11207832080158, 64.44474264897164, 68.6603...
#
#                                           order_Month  \
# 10  [-273456000.0, -270777600.0, -268099200.0, -26...
#
#                               confidence  \
# 10  [0.63, 0.63, 0.63, 0.63, 0.63, 0.63]
#
#                                                 lower  \
# 10  [48.04368768400762, 49.169785310207516, 51.498...
#
#                                                 upper
# 10  [74.18046895759554, 79.71969998773577, 85.8225...

# %% [markdown]
# You'll note that the point `prediction` has associated `lower` and `upper` bounds that are a function of the estimated `confidence` the model has on its own output. Apart from this, `order_Month` yields the timestamps of each prediction, the `anomaly` tag will let you know if the observed value falls outside of the predicted region.
#
#
# ## Visualizing a forecast
#
# Okay, time series are much easier to appreciate through plots. Let's make one:
#
# NOTE: We will use `matplotlib` to generate a simple plot of these forecasts. If you want to run this notebook locally, you will need to `pip install matplotlib` for the following code to work.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['prediction'], color='purple', label='point prediction')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['lower'], color='grey')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['upper'], color='grey')
plt.xlabel('timestep')
plt.ylabel('# sunspots')
plt.title("Forecasted amount of sunspots for the next semester")
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we have gone through how you can train a machine learning model with Lightwood to produce forecasts for a univariate time series task.
#
# There are additional parameters to further customize your timeseries settings and/or prediction insights, so be sure to check the rest of the documentation.
