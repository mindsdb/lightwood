# %% [markdown]
# # Tutorial - Implementing a custom analysis block in Lightwood
#
#
# ## Introduction
#
# As you might already know, Lightwood is designed to be a flexible machine learning (ML) library that is able to abstract and automate the entire ML pipeline. Crucially, it is also designed to be extended or modified very easily according to your needs, essentially offering the entire spectrum between fully automated AutoML and a lightweight wrapper for customized ML pipelines.
#
# As such, we can identify several different customizable "phases" in the process. The relevant phase for this tutorial is the "analysis" that comes after a predictor has been trained. The goal of this phase is to generate useful insights, like accuracy metrics, confusion matrices, feature importance, etc. These particular examples are all included in the core analysis procedure that Lightwood executes.
#
# However, the analysis procedure is structured into a sequential execution of "analysis blocks". Each analysis block should generate a well-defined set of insights, as well as handling any actions regarding these at inference time.
#
# As an example, one of the core blocks is the Inductive Conformal Prediction (`ICP`) block, which handles the confidence estimation of all Lightwood predictors. The logic within can be complex at times, but thanks to the block abstraction we can deal with it in a structured manner. As this `ICP` block is used when generating predictions, it implements the two main methods that the `BaseAnalysisBlock` class specifies: `.analyze()` to setup everything that is needed, and `.explain()` to actually estimate the confidence in any given prediction.
#
#
# ## Objective
#
# In this tutorial, we will go through the steps required to implement your own analysis blocks to customize the insights of any Lightwood predictor!
#
# In particular, we will implement a "model correlation heatmap" block: we want to compare the predictions of all mixers inside a `BestOf` ensemble object, to understand how they might differ in their overall behavior.

# %%
from typing import Dict, Tuple
import pandas as pd
import lightwood
lightwood.__version__
# Out:
# '1.6.1'

# %% [markdown]
# ## Step 1: figuring out what we need
#
# When designing an analysis block, an important choice needs to be made: will this block operate when calling the predictor? Or is it only going to describe its performance once in the held-out validation dataset?
#
# Being in the former case means we need to implement both `.analyze()` and `.explain()` methods, while the latter case only needs an `.analyze()` method. Our `ModelCorrelationHeatmap` belongs to this second category.
#
# Let's start the implementation by inheriting from `BaseAnalysisBlock`:

# %%
from lightwood.analysis import BaseAnalysisBlock

class ModelCorrelationHeatmap(BaseAnalysisBlock):
    def __init__(self):
        super().__init__()
        
    def analyze(self, info: Dict[str, object], **kwargs) -> Dict[str, object]:
        return info

    def explain(self,
                row_insights: pd.DataFrame,
                global_insights: Dict[str, object], **kwargs) -> Tuple[pd.DataFrame, Dict[str, object]]:
        
        return row_insights, global_insights

# %%
ModelCorrelationHeatmap()

# %% [markdown]
# Right now, our newly created analysis block doesn't do much, apart from returning the `info` and insights (`row_insights` and `global_insights`) exactly as it received them from the previous block.
#
# As previously discussed, we only need to implement a procedure that runs post-training, no action is required at inference time. This means we can use the default `.explain()` behavior in the parent class:

# %%
class ModelCorrelationHeatmap(BaseAnalysisBlock):
    def __init__(self):
        super().__init__()
        
    def analyze(self, info: Dict[str, object], **kwargs) -> Dict[str, object]:
        return info

# %% [markdown]
# ## Step 2: Implementing the custom analysis block
#
# Okay, now for the fun bit: we have to implement a correlation heatmap between the predictions of all mixers inside a `BestOf` ensemble. This is currently the only ensemble implemented in Lightwood, but it is a good idea to explicitly check that the type of the ensemble is what we expect.
#
# A natural question to ask at this point is: what information do we have to implement the procedure? You'll note that, apart from the `info` dictionary, we receive a `kwargs` dictionary. You can check out the full documentation for more details, but the keys (and respective value types) exposed in this object by default are:

# %%
kwargs = {
        'predictor': 'lightwood.ensemble.BaseEnsemble',
        'target': 'str',
        'input_cols': 'list',
        'dtype_dict': 'dict',
        'normal_predictions': 'pd.DataFrame',
        'data': 'pd.DataFrame',
        'train_data': 'lightwood.data.encoded_ds.EncodedDs',
        'encoded_val_data': 'lightwood.data.encoded_ds.EncodedDs',
        'is_classification': 'bool',
        'is_numerical': 'bool',
        'is_multi_ts': 'bool',
        'stats_info': 'lightwood.api.types.StatisticalAnalysis',
        'ts_cfg': 'lightwood.api.types.TimeseriesSettings',
        'accuracy_functions': 'list',
        'has_pretrained_text_enc': 'bool'
}

# %% [markdown]
# As you can see there is lots to work with, but for this example we will focus on using:
#
# 1. The `predictor` ensemble
# 2. The `encoded_val_data` to generate predictions for each mixer inside the ensemble
#
# And the insight we're want to produce is a matrix that compares the output of all mixers and computes the correlation between them.
#
# Let's implement the algorithm:

# %%
# %%writefile model_correlation.py

from typing import Dict
from types import SimpleNamespace

import numpy as np

from lightwood.ensemble import BestOf
from lightwood.analysis import BaseAnalysisBlock


class ModelCorrelationHeatmap(BaseAnalysisBlock):
    def __init__(self):
        super().__init__()
        
    def analyze(self, info: Dict[str, object], **kwargs) -> Dict[str, object]:
        ns = SimpleNamespace(**kwargs)
        
        # only triggered with the right type of ensemble
        if isinstance(ns.predictor, BestOf):
            
            # store prediction from every mixer
            all_predictions = []

            for mixer in ns.predictor.mixers:
                predictions = mixer(ns.encoded_val_data).values  # retrieve np.ndarray from the returned pd.DataFrame
                all_predictions.append(predictions.flatten().astype(int))  # flatten and cast labels to int
                
            # calculate correlation matrix
            corrs = np.corrcoef(np.array(all_predictions))
            
            # save inside `info` object
            info['mixer_correlation'] = corrs
        
        return info
# Out:
# Overwriting model_correlation.py

# %% [markdown]
# Notice the use of `SimpleNamespace` for dot notation accessors.
#
# The procedure above is fairly straightforward, as we leverage numpy's `corrcoef()` function to generate the matrix.
#
# Finally, it is very important to add the output to `info` so that it is saved inside the actual predictor object.

# %% [markdown]
# ## Step 3: Exposing the block to Lightwood
#
#
# To use this in an arbitrary script, we need to add the above class (and all necessary imports) to a `.py` file inside one of the following directories:
#
# * `~/lightwood_modules` (where `~` is your home directory, e.g. `/Users/username/` for macOS and `/home/username/` for linux
# * `/etc/lightwood_modules`
#
# Lightwood will scan these directories and import any class so that they can be found and used by the `JsonAI` code generating module.
#
# **To continue, please save the code cell above as `model_correlation.py` in one of the indicated directories.**

# %% [markdown]
# ## Step 4: Final test run
#
# Ok! Everything looks set to try out our custom block. Let's generate a predictor for [this](https://github.com/mindsdb/lightwood/blob/stable/tests/data/hdi.csv) sample dataset, and see whether our new insights are any good.
#
# First, it is important to add our `ModelCorrelationHeatmap` to the `analysis_blocks` attribute of the Json AI object that will generate your predictor code.

# %%
from lightwood.api.high_level import ProblemDefinition, json_ai_from_problem, load_custom_module

# First, load the custom module we wrote
load_custom_module('model_correlation.py')

# read dataset
df = pd.read_csv('https://raw.githubusercontent.com/mindsdb/lightwood/stable/tests/data/hdi.csv')

# define the predictive task
pdef = ProblemDefinition.from_dict({
    'target': 'Development Index',         # column you want to predict
    'time_aim': 100,
})

# generate the Json AI intermediate representation from the data and its corresponding settings
json_ai = json_ai_from_problem(df, problem_definition=pdef)

# add the custom list of analysis blocks; in this case, composed of a single block
json_ai.analysis_blocks = [{
    'module': 'model_correlation.ModelCorrelationHeatmap',
    'args': {}
}]
# Out:
# INFO:lightwood-908130:Dropping features: []
# INFO:lightwood-908130:Analyzing a sample of 222
# INFO:lightwood-908130:from a total population of 225, this is equivalent to 98.7% of your data.
# INFO:lightwood-908130:Using 7 processes to deduct types.
# INFO:lightwood-908130:Infering type for: Area (sq. mi.)
# INFO:lightwood-908130:Infering type for: Population
# INFO:lightwood-908130:Infering type for: Pop. Density
# INFO:lightwood-908130:Infering type for: Literacy (%)
# INFO:lightwood-908130:Column Area (sq. mi.) has data type integer
# INFO:lightwood-908130:Infering type for: Infant mortality
# INFO:lightwood-908130:Column Pop. Density  has data type float
# INFO:lightwood-908130:Infering type for: GDP ($ per capita)
# INFO:lightwood-908130:Infering type for: Development Index
# INFO:lightwood-908130:Column Population has data type integer
# INFO:lightwood-908130:Column Development Index has data type categorical
# INFO:lightwood-908130:Column GDP ($ per capita) has data type integer
# INFO:lightwood-908130:Column Literacy (%) has data type float
# INFO:lightwood-908130:Column Infant mortality  has data type float
# INFO:lightwood-908130:Starting statistical analysis
# INFO:lightwood-908130:Finished statistical analysis

# %% [markdown]
# We can take a look at the respective Json AI key just to confirm our newly added analysis block is in there:

# %%
json_ai.analysis_blocks
# Out:
# [{'module': 'model_correlation.ModelCorrelationHeatmap', 'args': {}}]

# %% [markdown]
# Now we are ready to create a predictor from this Json AI, and subsequently train it:

# %%
from lightwood.api.high_level import code_from_json_ai, predictor_from_code

code = code_from_json_ai(json_ai)
predictor = predictor_from_code(code)

predictor.learn(df)
# Out:
# INFO:lightwood-908130:Unable to import black formatter, predictor code might be a bit ugly.
# INFO:lightwood-908130:Dropping features: []
# INFO:lightwood-908130:Performing statistical analysis on data
# INFO:lightwood-908130:Starting statistical analysis
# INFO:lightwood-908130:Finished statistical analysis
# INFO:lightwood-908130:Cleaning the data
# INFO:lightwood-908130:Splitting the data into train/test
# INFO:lightwood-908130:Preparing the encoders
# INFO:lightwood-908130:Encoder prepping dict length of: 1
# INFO:lightwood-908130:Encoder prepping dict length of: 2
# INFO:lightwood-908130:Encoder prepping dict length of: 3
# INFO:lightwood-908130:Encoder prepping dict length of: 4
# INFO:lightwood-908130:Encoder prepping dict length of: 5
# INFO:lightwood-908130:Encoder prepping dict length of: 6
# INFO:lightwood-908130:Encoder prepping dict length of: 7
# INFO:lightwood-908130:Done running for: Development Index
# INFO:lightwood-908130:Done running for: Population
# INFO:lightwood-908130:Done running for: Area (sq. mi.)
# INFO:lightwood-908130:Done running for: Pop. Density
# INFO:lightwood-908130:Done running for: GDP ($ per capita)
# INFO:lightwood-908130:Done running for: Literacy (%)
# INFO:lightwood-908130:Done running for: Infant mortality
# INFO:lightwood-908130:Featurizing the data
# INFO:lightwood-908130:Training the mixers
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-908130:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# /home/george/.local/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# /home/george/.local/lib/python3.8/site-packages/pytorch_ranger/ranger.py:172: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1025.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# INFO:lightwood-908130:Loss of 2.2141835689544678 with learning rate 0.0001
# INFO:lightwood-908130:Loss of 2.186218023300171 with learning rate 0.00014
# INFO:lightwood-908130:Loss of 1.9386556148529053 with learning rate 0.00019599999999999997
# INFO:lightwood-908130:Loss of 2.0579020977020264 with learning rate 0.00027439999999999995
# INFO:lightwood-908130:Loss of 1.8931834697723389 with learning rate 0.0003841599999999999
# INFO:lightwood-908130:Loss of 1.8472695350646973 with learning rate 0.0005378239999999999
# INFO:lightwood-908130:Loss of 2.0167930126190186 with learning rate 0.0007529535999999998
# INFO:lightwood-908130:Loss of 3.7965553998947144 with learning rate 0.0010541350399999995
# INFO:lightwood-908130:Found learning rate of: 0.0005378239999999999
# INFO:lightwood-908130:Loss @ epoch 1: 1.4991437196731567
# INFO:lightwood-908130:Loss @ epoch 2: 1.6119575500488281
# INFO:lightwood-908130:Loss @ epoch 3: 1.5858194828033447
# INFO:lightwood-908130:Loss @ epoch 4: 1.5612322092056274
# INFO:lightwood-908130:Loss @ epoch 5: 1.5381176471710205
# INFO:lightwood-908130:Loss @ epoch 6: 1.5168108940124512
# INFO:lightwood-908130:Loss @ epoch 7: 1.4739866256713867
# INFO:lightwood-908130:Loss @ epoch 8: 1.4581321477890015
# INFO:lightwood-908130:Loss @ epoch 9: 1.4433478116989136
# INFO:lightwood-908130:Loss @ epoch 10: 1.4293681383132935
# INFO:lightwood-908130:Loss @ epoch 11: 1.4158488512039185
# INFO:lightwood-908130:Loss @ epoch 12: 1.4025087356567383
# INFO:lightwood-908130:Loss @ epoch 13: 1.3712449073791504
# INFO:lightwood-908130:Loss @ epoch 14: 1.3584681749343872
# INFO:lightwood-908130:Loss @ epoch 15: 1.3465051651000977
# INFO:lightwood-908130:Loss @ epoch 16: 1.3353314399719238
# INFO:lightwood-908130:Loss @ epoch 17: 1.3247796297073364
# INFO:lightwood-908130:Loss @ epoch 18: 1.3144772052764893
# INFO:lightwood-908130:Loss @ epoch 19: 1.2905746698379517
# INFO:lightwood-908130:Loss @ epoch 20: 1.281795620918274
# INFO:lightwood-908130:Loss @ epoch 21: 1.2732012271881104
# INFO:lightwood-908130:Loss @ epoch 22: 1.2648426294326782
# INFO:lightwood-908130:Loss @ epoch 23: 1.2565635442733765
# INFO:lightwood-908130:Loss @ epoch 24: 1.2481244802474976
# INFO:lightwood-908130:Loss @ epoch 25: 1.2277307510375977
# INFO:lightwood-908130:Loss @ epoch 26: 1.2195144891738892
# INFO:lightwood-908130:Loss @ epoch 27: 1.2113635540008545
# INFO:lightwood-908130:Loss @ epoch 28: 1.203439712524414
# INFO:lightwood-908130:Loss @ epoch 29: 1.1956262588500977
# INFO:lightwood-908130:Loss @ epoch 30: 1.1876771450042725
# INFO:lightwood-908130:Loss @ epoch 31: 1.1687393188476562
# INFO:lightwood-908130:Loss @ epoch 32: 1.161420464515686
# INFO:lightwood-908130:Loss @ epoch 33: 1.1541873216629028
# INFO:lightwood-908130:Loss @ epoch 34: 1.1471598148345947
# INFO:lightwood-908130:Loss @ epoch 35: 1.1402455568313599
# INFO:lightwood-908130:Loss @ epoch 36: 1.1331124305725098
# INFO:lightwood-908130:Loss @ epoch 37: 1.1160597801208496
# INFO:lightwood-908130:Loss @ epoch 38: 1.109392762184143
# INFO:lightwood-908130:Loss @ epoch 39: 1.102790117263794
# INFO:lightwood-908130:Loss @ epoch 40: 1.0963813066482544
# INFO:lightwood-908130:Loss @ epoch 41: 1.0900931358337402
# INFO:lightwood-908130:Loss @ epoch 42: 1.083558440208435
# INFO:lightwood-908130:Loss @ epoch 43: 1.0679552555084229
# INFO:lightwood-908130:Loss @ epoch 44: 1.0618613958358765
# INFO:lightwood-908130:Loss @ epoch 45: 1.0558291673660278
# INFO:lightwood-908130:Loss @ epoch 46: 1.049978494644165
# INFO:lightwood-908130:Loss @ epoch 47: 1.0442774295806885
# INFO:lightwood-908130:Loss @ epoch 48: 1.0382887125015259
# INFO:lightwood-908130:Loss @ epoch 49: 1.0239851474761963
# INFO:lightwood-908130:Loss @ epoch 50: 1.018364429473877
# INFO:lightwood-908130:Loss @ epoch 51: 1.0128005743026733
# INFO:lightwood-908130:Loss @ epoch 52: 1.007415771484375
# INFO:lightwood-908130:Loss @ epoch 53: 1.0021921396255493
# INFO:lightwood-908130:Loss @ epoch 54: 0.996641993522644
# INFO:lightwood-908130:Loss @ epoch 55: 0.9833624362945557
# INFO:lightwood-908130:Loss @ epoch 56: 0.978119432926178
# INFO:lightwood-908130:Loss @ epoch 57: 0.9729326963424683
# INFO:lightwood-908130:Loss @ epoch 58: 0.9679065346717834
# INFO:lightwood-908130:Loss @ epoch 59: 0.9630694389343262
# INFO:lightwood-908130:Loss @ epoch 60: 0.9578712582588196
# INFO:lightwood-908130:Loss @ epoch 61: 0.9454248547554016
# INFO:lightwood-908130:Loss @ epoch 62: 0.9404919147491455
# INFO:lightwood-908130:Loss @ epoch 63: 0.9356237649917603
# INFO:lightwood-908130:Loss @ epoch 64: 0.9309159517288208
# INFO:lightwood-908130:Loss @ epoch 65: 0.9264161586761475
# INFO:lightwood-908130:Loss @ epoch 66: 0.9215322732925415
# INFO:lightwood-908130:Loss @ epoch 67: 0.9098007082939148
# INFO:lightwood-908130:Loss @ epoch 68: 0.9051421880722046
# INFO:lightwood-908130:Loss @ epoch 69: 0.9005601406097412
# INFO:lightwood-908130:Loss @ epoch 70: 0.8961341381072998
# INFO:lightwood-908130:Loss @ epoch 71: 0.8919346332550049
# INFO:lightwood-908130:Loss @ epoch 72: 0.8873188495635986
# INFO:lightwood-908130:Loss @ epoch 73: 0.8762369751930237
# INFO:lightwood-908130:Loss @ epoch 74: 0.8718252778053284
# INFO:lightwood-908130:Loss @ epoch 75: 0.8674999475479126
# INFO:lightwood-908130:Loss @ epoch 76: 0.863336980342865
# INFO:lightwood-908130:Loss @ epoch 77: 0.8594394326210022
# INFO:lightwood-908130:Loss @ epoch 78: 0.8551239967346191
# INFO:lightwood-908130:Loss @ epoch 79: 0.8447586894035339
# INFO:lightwood-908130:Loss @ epoch 80: 0.8406375050544739
# INFO:lightwood-908130:Loss @ epoch 81: 0.8366269469261169
# INFO:lightwood-908130:Loss @ epoch 82: 0.8327817916870117
# INFO:lightwood-908130:Loss @ epoch 83: 0.8292136192321777
# INFO:lightwood-908130:Loss @ epoch 84: 0.8252128958702087
# INFO:lightwood-908130:Loss @ epoch 85: 0.8156102895736694
# INFO:lightwood-908130:Loss @ epoch 86: 0.8117791414260864
# INFO:lightwood-908130:Loss @ epoch 87: 0.8080527782440186
# INFO:lightwood-908130:Loss @ epoch 88: 0.8044831156730652
# INFO:lightwood-908130:Loss @ epoch 89: 0.8011949062347412
# INFO:lightwood-908130:Loss @ epoch 90: 0.7974539995193481
# INFO:lightwood-908130:Loss @ epoch 91: 0.7884248495101929
# INFO:lightwood-908130:Loss @ epoch 92: 0.7847872972488403
# INFO:lightwood-908130:Loss @ epoch 93: 0.7812823057174683
# INFO:lightwood-908130:Loss @ epoch 94: 0.7779803276062012
# INFO:lightwood-908130:Loss @ epoch 95: 0.774967610836029
# INFO:lightwood-908130:Loss @ epoch 96: 0.7714971899986267
# INFO:lightwood-908130:Loss @ epoch 97: 0.7630864381790161
# INFO:lightwood-908130:Loss @ epoch 98: 0.7596819996833801
# INFO:lightwood-908130:Loss @ epoch 99: 0.7564045190811157
# INFO:lightwood-908130:Loss @ epoch 100: 0.7533037662506104
# INFO:lightwood-908130:Loss @ epoch 101: 0.7504976391792297
# INFO:lightwood-908130:Loss @ epoch 102: 0.7472284436225891
# INFO:lightwood-908130:Loss @ epoch 103: 0.739241898059845
# INFO:lightwood-908130:Loss @ epoch 104: 0.7359909415245056
# INFO:lightwood-908130:Loss @ epoch 105: 0.7328737378120422
# INFO:lightwood-908130:Loss @ epoch 106: 0.7299246191978455
# INFO:lightwood-908130:Loss @ epoch 107: 0.7272693514823914
# INFO:lightwood-908130:Loss @ epoch 108: 0.7241381406784058
# INFO:lightwood-908130:Loss @ epoch 109: 0.7164721488952637
# INFO:lightwood-908130:Loss @ epoch 110: 0.7133376002311707
# INFO:lightwood-908130:Loss @ epoch 111: 0.7103498578071594
# INFO:lightwood-908130:Loss @ epoch 112: 0.7075321674346924
# INFO:lightwood-908130:Loss @ epoch 113: 0.7049992680549622
# INFO:lightwood-908130:Loss @ epoch 114: 0.7019882798194885
# INFO:lightwood-908130:Loss @ epoch 115: 0.6945720911026001
# INFO:lightwood-908130:Loss @ epoch 116: 0.6915415525436401
# INFO:lightwood-908130:Loss @ epoch 117: 0.6886721849441528
# INFO:lightwood-908130:Loss @ epoch 118: 0.6859886646270752
# INFO:lightwood-908130:Loss @ epoch 119: 0.683594286441803
# INFO:lightwood-908130:Loss @ epoch 120: 0.6807138919830322
# INFO:lightwood-908130:Loss @ epoch 121: 0.6735898852348328
# INFO:lightwood-908130:Loss @ epoch 122: 0.6706631779670715
# INFO:lightwood-908130:Loss @ epoch 123: 0.6678903102874756
# INFO:lightwood-908130:Loss @ epoch 124: 0.665312647819519
# INFO:lightwood-908130:Loss @ epoch 125: 0.6630218029022217
# INFO:lightwood-908130:Loss @ epoch 126: 0.6602458953857422
# INFO:lightwood-908130:Loss @ epoch 127: 0.6533876657485962
# INFO:lightwood-908130:Loss @ epoch 128: 0.6505781412124634
# INFO:lightwood-908130:Loss @ epoch 129: 0.6479470133781433
# INFO:lightwood-908130:Loss @ epoch 130: 0.6455216407775879
# INFO:lightwood-908130:Loss @ epoch 131: 0.6433591842651367
# INFO:lightwood-908130:Loss @ epoch 132: 0.6406826972961426
# INFO:lightwood-908130:Loss @ epoch 133: 0.634006142616272
# INFO:lightwood-908130:Loss @ epoch 134: 0.6312696933746338
# INFO:lightwood-908130:Loss @ epoch 135: 0.6287199258804321
# INFO:lightwood-908130:Loss @ epoch 136: 0.6263857483863831
# INFO:lightwood-908130:Loss @ epoch 137: 0.6243189573287964
# INFO:lightwood-908130:Loss @ epoch 138: 0.6217544674873352
# INFO:lightwood-908130:Loss @ epoch 139: 0.6153678297996521
# INFO:lightwood-908130:Loss @ epoch 140: 0.6127657294273376
# INFO:lightwood-908130:Loss @ epoch 141: 0.6103600263595581
# INFO:lightwood-908130:Loss @ epoch 142: 0.6081738471984863
# INFO:lightwood-908130:Loss @ epoch 143: 0.6062403321266174
# INFO:lightwood-908130:Loss @ epoch 144: 0.6038150787353516
# INFO:lightwood-908130:Loss @ epoch 145: 0.5977386832237244
# INFO:lightwood-908130:Loss @ epoch 146: 0.5952479839324951
# INFO:lightwood-908130:Loss @ epoch 147: 0.5929502248764038
# INFO:lightwood-908130:Loss @ epoch 148: 0.5908699035644531
# INFO:lightwood-908130:Loss @ epoch 149: 0.5890248417854309
# INFO:lightwood-908130:Loss @ epoch 150: 0.5866711139678955
# INFO:lightwood-908130:Loss @ epoch 151: 0.580730676651001
# INFO:lightwood-908130:Loss @ epoch 152: 0.578311026096344
# INFO:lightwood-908130:Loss @ epoch 153: 0.5760939121246338
# INFO:lightwood-908130:Loss @ epoch 154: 0.574100911617279
# INFO:lightwood-908130:Loss @ epoch 155: 0.5723411440849304
# INFO:lightwood-908130:Loss @ epoch 156: 0.5700581669807434
# INFO:lightwood-908130:Loss @ epoch 157: 0.5642378330230713
# INFO:lightwood-908130:Loss @ epoch 158: 0.5618575215339661
# INFO:lightwood-908130:Loss @ epoch 159: 0.5596745014190674
# INFO:lightwood-908130:Loss @ epoch 160: 0.5577310919761658
# INFO:lightwood-908130:Loss @ epoch 161: 0.556016206741333
# INFO:lightwood-908130:Loss @ epoch 162: 0.5537996888160706
# INFO:lightwood-908130:Loss @ epoch 163: 0.5481439828872681
# INFO:lightwood-908130:Loss @ epoch 164: 0.5458521246910095
# INFO:lightwood-908130:Loss @ epoch 165: 0.5437644720077515
# INFO:lightwood-908130:Loss @ epoch 166: 0.541918933391571
# INFO:lightwood-908130:Loss @ epoch 167: 0.5402806401252747
# INFO:lightwood-908130:Loss @ epoch 168: 0.5381308197975159
# INFO:lightwood-908130:Loss @ epoch 169: 0.5326342582702637
# INFO:lightwood-908130:Loss @ epoch 170: 0.5303996801376343
# INFO:lightwood-908130:Loss @ epoch 171: 0.5283887386322021
# INFO:lightwood-908130:Loss @ epoch 172: 0.5266227126121521
# INFO:lightwood-908130:Loss @ epoch 173: 0.5250541567802429
# INFO:lightwood-908130:Loss @ epoch 174: 0.5229812860488892
# INFO:lightwood-908130:Loss @ epoch 175: 0.5177215933799744
# INFO:lightwood-908130:Loss @ epoch 176: 0.5155863165855408
# INFO:lightwood-908130:Loss @ epoch 177: 0.5136663317680359
# INFO:lightwood-908130:Loss @ epoch 178: 0.5119927525520325
# INFO:lightwood-908130:Loss @ epoch 179: 0.5104910135269165
# INFO:lightwood-908130:Loss @ epoch 180: 0.5085047483444214
# INFO:lightwood-908130:Loss @ epoch 181: 0.503433108329773
# INFO:lightwood-908130:Loss @ epoch 182: 0.5014082789421082
# INFO:lightwood-908130:Loss @ epoch 183: 0.4995924234390259
# INFO:lightwood-908130:Loss @ epoch 184: 0.49802643060684204
# INFO:lightwood-908130:Loss @ epoch 185: 0.496620237827301
# INFO:lightwood-908130:Loss @ epoch 186: 0.49470993876457214
# INFO:lightwood-908130:Loss @ epoch 187: 0.48980870842933655
# INFO:lightwood-908130:Loss @ epoch 188: 0.4878471791744232
# INFO:lightwood-908130:Loss @ epoch 189: 0.4860997200012207
# INFO:lightwood-908130:Loss @ epoch 190: 0.4846099615097046
# INFO:lightwood-908130:Loss @ epoch 191: 0.48327749967575073
# INFO:lightwood-908130:Loss @ epoch 192: 0.4814499020576477
# INFO:lightwood-908130:Loss @ epoch 193: 0.47676676511764526
# INFO:lightwood-908130:Loss @ epoch 194: 0.47491195797920227
# INFO:lightwood-908130:Loss @ epoch 195: 0.47326743602752686
# INFO:lightwood-908130:Loss @ epoch 196: 0.47188419103622437
# INFO:lightwood-908130:Loss @ epoch 197: 0.47063952684402466
# INFO:lightwood-908130:Loss @ epoch 198: 0.4688984155654907
# INFO:lightwood-908130:Loss @ epoch 199: 0.4643794000148773
# INFO:lightwood-908130:Loss @ epoch 200: 0.4625864326953888
# INFO:lightwood-908130:Loss @ epoch 201: 0.4610224962234497
# INFO:lightwood-908130:Loss @ epoch 202: 0.4597231149673462
# INFO:lightwood-908130:Loss @ epoch 203: 0.4585324227809906
# INFO:lightwood-908130:Loss @ epoch 204: 0.45685330033302307
# INFO:lightwood-908130:Loss @ epoch 205: 0.45252060890197754
# INFO:lightwood-908130:Loss @ epoch 206: 0.4508155584335327
# INFO:lightwood-908130:Loss @ epoch 207: 0.44932642579078674
# INFO:lightwood-908130:Loss @ epoch 208: 0.44809073209762573
# INFO:lightwood-908130:Loss @ epoch 209: 0.4469653367996216
# INFO:lightwood-908130:Loss @ epoch 210: 0.4453660845756531
# INFO:lightwood-908130:Loss @ epoch 211: 0.44122448563575745
# INFO:lightwood-908130:Loss @ epoch 212: 0.43957942724227905
# INFO:lightwood-908130:Loss @ epoch 213: 0.4381459653377533
# INFO:lightwood-908130:Loss @ epoch 214: 0.4369588792324066
# INFO:lightwood-908130:Loss @ epoch 215: 0.4358774423599243
# INFO:lightwood-908130:Loss @ epoch 216: 0.4343181252479553
# INFO:lightwood-908130:Loss @ epoch 217: 0.43023931980133057
# INFO:lightwood-908130:Loss @ epoch 218: 0.4286462366580963
# INFO:lightwood-908130:Loss @ epoch 219: 0.42725512385368347
# INFO:lightwood-908130:Loss @ epoch 220: 0.4261258542537689
# INFO:lightwood-908130:Loss @ epoch 221: 0.42505961656570435
# INFO:lightwood-908130:Loss @ epoch 222: 0.4235336482524872
# INFO:lightwood-908130:Loss @ epoch 223: 0.41954711079597473
# INFO:lightwood-908130:Loss @ epoch 224: 0.41799476742744446
# INFO:lightwood-908130:Loss @ epoch 225: 0.416639119386673
# INFO:lightwood-908130:Loss @ epoch 226: 0.4155586361885071
# INFO:lightwood-908130:Loss @ epoch 227: 0.41452425718307495
# INFO:lightwood-908130:Loss @ epoch 228: 0.4130473732948303
# INFO:lightwood-908130:Loss @ epoch 229: 0.4091843068599701
# INFO:lightwood-908130:Loss @ epoch 230: 0.4076909124851227
# INFO:lightwood-908130:Loss @ epoch 231: 0.4063968360424042
# INFO:lightwood-908130:Loss @ epoch 232: 0.40536898374557495
# INFO:lightwood-908130:Loss @ epoch 233: 0.4043736755847931
# INFO:lightwood-908130:Loss @ epoch 234: 0.4029475450515747
# INFO:lightwood-908130:Loss @ epoch 235: 0.3992072641849518
# INFO:lightwood-908130:Loss @ epoch 236: 0.39776870608329773
# INFO:lightwood-908130:Loss @ epoch 237: 0.3965230882167816
# INFO:lightwood-908130:Loss @ epoch 238: 0.3955453336238861
# INFO:lightwood-908130:Loss @ epoch 239: 0.39458322525024414
# INFO:lightwood-908130:Loss @ epoch 240: 0.3932019770145416
# INFO:lightwood-908130:Loss @ epoch 241: 0.389560341835022
# INFO:lightwood-908130:Loss @ epoch 242: 0.38818246126174927
# INFO:lightwood-908130:Loss @ epoch 243: 0.387001633644104
# INFO:lightwood-908130:Loss @ epoch 244: 0.3860832452774048
# INFO:lightwood-908130:Loss @ epoch 245: 0.38515591621398926
# INFO:lightwood-908130:Loss @ epoch 246: 0.3838115632534027
# INFO:lightwood-908130:Loss @ epoch 247: 0.38026097416877747
# INFO:lightwood-908130:Loss @ epoch 248: 0.3789364695549011
# INFO:lightwood-908130:Loss @ epoch 249: 0.37781476974487305
# INFO:lightwood-908130:Loss @ epoch 250: 0.3769616484642029
# INFO:lightwood-908130:Loss @ epoch 251: 0.37607598304748535
# INFO:lightwood-908130:Loss @ epoch 252: 0.3748064339160919
# INFO:lightwood-908130:Loss @ epoch 253: 0.37142959237098694
# INFO:lightwood-908130:Loss @ epoch 254: 0.37015625834465027
# INFO:lightwood-908130:Loss @ epoch 255: 0.3690723776817322
# INFO:lightwood-908130:Loss @ epoch 256: 0.36827170848846436
# INFO:lightwood-908130:Loss @ epoch 257: 0.36741524934768677
# INFO:lightwood-908130:Loss @ epoch 258: 0.3661886155605316
# INFO:lightwood-908130:Loss @ epoch 259: 0.3628878891468048
# INFO:lightwood-908130:Loss @ epoch 260: 0.3616529107093811
# INFO:lightwood-908130:Loss @ epoch 261: 0.3606089949607849
# INFO:lightwood-908130:Loss @ epoch 262: 0.35984495282173157
# INFO:lightwood-908130:Loss @ epoch 263: 0.3590245246887207
# INFO:lightwood-908130:Loss @ epoch 264: 0.35786157846450806
# INFO:lightwood-908130:Loss @ epoch 265: 0.35474300384521484
# INFO:lightwood-908130:Loss @ epoch 266: 0.35361242294311523
# INFO:lightwood-908130:Loss @ epoch 267: 0.3526727855205536
# INFO:lightwood-908130:Loss @ epoch 268: 0.35200172662734985
# INFO:lightwood-908130:Loss @ epoch 269: 0.3512442708015442
# INFO:lightwood-908130:Loss @ epoch 270: 0.3501546382904053
# INFO:lightwood-908130:Loss @ epoch 271: 0.34720662236213684
# INFO:lightwood-908130:Loss @ epoch 272: 0.346163272857666
# INFO:lightwood-908130:Loss @ epoch 273: 0.34527289867401123
# INFO:lightwood-908130:Loss @ epoch 274: 0.34464186429977417
# INFO:lightwood-908130:Loss @ epoch 275: 0.3439252972602844
# INFO:lightwood-908130:Loss @ epoch 276: 0.34290051460266113
# INFO:lightwood-908130:Loss @ epoch 277: 0.34009456634521484
# INFO:lightwood-908130:Loss @ epoch 278: 0.3391106426715851
# INFO:lightwood-908130:Loss @ epoch 279: 0.33828800916671753
# INFO:lightwood-908130:Loss @ epoch 280: 0.33772096037864685
# INFO:lightwood-908130:Loss @ epoch 281: 0.337043821811676
# INFO:lightwood-908130:Loss @ epoch 282: 0.33607804775238037
# INFO:lightwood-908130:Loss @ epoch 283: 0.3334207534790039
# INFO:lightwood-908130:Loss @ epoch 284: 0.33248937129974365
# INFO:lightwood-908130:Loss @ epoch 285: 0.33169102668762207
# INFO:lightwood-908130:Loss @ epoch 286: 0.33117809891700745
# INFO:lightwood-908130:Loss @ epoch 287: 0.33052051067352295
# INFO:lightwood-908130:Loss @ epoch 288: 0.32959771156311035
# INFO:lightwood-908130:Loss @ epoch 289: 0.32701995968818665
# INFO:lightwood-908130:Loss @ epoch 290: 0.32613635063171387
# INFO:lightwood-908130:Loss @ epoch 291: 0.32537540793418884
# INFO:lightwood-908130:Loss @ epoch 292: 0.3248865604400635
# INFO:lightwood-908130:Loss @ epoch 293: 0.3242410123348236
# INFO:lightwood-908130:Loss @ epoch 294: 0.32333892583847046
# INFO:lightwood-908130:Loss @ epoch 295: 0.32081663608551025
# INFO:lightwood-908130:Loss @ epoch 296: 0.319924533367157
# INFO:lightwood-908130:Loss @ epoch 297: 0.3191774785518646
# INFO:lightwood-908130:Loss @ epoch 298: 0.3186822235584259
# INFO:lightwood-908130:Loss @ epoch 299: 0.3180370032787323
# INFO:lightwood-908130:Loss @ epoch 300: 0.31717008352279663
# INFO:lightwood-908130:Loss @ epoch 301: 0.31470897793769836
# INFO:lightwood-908130:Loss @ epoch 302: 0.3138195872306824
# INFO:lightwood-908130:Loss @ epoch 303: 0.3130706548690796
# INFO:lightwood-908130:Loss @ epoch 304: 0.31258219480514526
# INFO:lightwood-908130:Loss @ epoch 305: 0.31190821528434753
# INFO:lightwood-908130:Loss @ epoch 306: 0.3110314607620239
# INFO:lightwood-908130:Loss @ epoch 307: 0.30857130885124207
# INFO:lightwood-908130:Loss @ epoch 308: 0.30772826075553894
# INFO:lightwood-908130:Loss @ epoch 309: 0.30699971318244934
# INFO:lightwood-908130:Loss @ epoch 310: 0.3065258264541626
# INFO:lightwood-908130:Loss @ epoch 311: 0.30585557222366333
# INFO:lightwood-908130:Loss @ epoch 312: 0.3050065338611603
# INFO:lightwood-908130:Loss @ epoch 313: 0.30259156227111816
# INFO:lightwood-908130:Loss @ epoch 314: 0.30176231265068054
# INFO:lightwood-908130:Loss @ epoch 315: 0.30104121565818787
# INFO:lightwood-908130:Loss @ epoch 316: 0.30059465765953064
# INFO:lightwood-908130:Loss @ epoch 317: 0.29995015263557434
# INFO:lightwood-908130:Loss @ epoch 318: 0.2991543710231781
# INFO:lightwood-908130:Loss @ epoch 319: 0.2968589663505554
# INFO:lightwood-908130:Loss @ epoch 320: 0.29606378078460693
# INFO:lightwood-908130:Loss @ epoch 321: 0.29537972807884216
# INFO:lightwood-908130:Loss @ epoch 322: 0.2949591875076294
# INFO:lightwood-908130:Loss @ epoch 323: 0.2943340241909027
# INFO:lightwood-908130:Loss @ epoch 324: 0.2935647666454315
# INFO:lightwood-908130:Loss @ epoch 325: 0.2913503348827362
# INFO:lightwood-908130:Loss @ epoch 326: 0.2906405031681061
# INFO:lightwood-908130:Loss @ epoch 327: 0.290021687746048
# INFO:lightwood-908130:Loss @ epoch 328: 0.2896609604358673
# INFO:lightwood-908130:Loss @ epoch 329: 0.2890734076499939
# INFO:lightwood-908130:Loss @ epoch 330: 0.2883546054363251
# INFO:lightwood-908130:Loss @ epoch 331: 0.2862444221973419
# INFO:lightwood-908130:Loss @ epoch 332: 0.28552547097206116
# INFO:lightwood-908130:Loss @ epoch 333: 0.28491735458374023
# INFO:lightwood-908130:Loss @ epoch 334: 0.2845718264579773
# INFO:lightwood-908130:Loss @ epoch 335: 0.28398096561431885
# INFO:lightwood-908130:Loss @ epoch 336: 0.28329482674598694
# INFO:lightwood-908130:Loss @ epoch 337: 0.28124988079071045
# INFO:lightwood-908130:Loss @ epoch 338: 0.2805262506008148
# INFO:lightwood-908130:Loss @ epoch 339: 0.27991828322410583
# INFO:lightwood-908130:Loss @ epoch 340: 0.27955546975135803
# INFO:lightwood-908130:Loss @ epoch 341: 0.27894505858421326
# INFO:lightwood-908130:Loss @ epoch 342: 0.2782769203186035
# INFO:lightwood-908130:Loss @ epoch 343: 0.2762872874736786
# INFO:lightwood-908130:Loss @ epoch 344: 0.27559325098991394
# INFO:lightwood-908130:Loss @ epoch 345: 0.27500712871551514
# INFO:lightwood-908130:Loss @ epoch 346: 0.2746855616569519
# INFO:lightwood-908130:Loss @ epoch 347: 0.274074912071228
# INFO:lightwood-908130:Loss @ epoch 348: 0.2734192907810211
# INFO:lightwood-908130:Loss @ epoch 349: 0.27144622802734375
# INFO:lightwood-908130:Loss @ epoch 350: 0.2707632780075073
# INFO:lightwood-908130:Loss @ epoch 351: 0.27017495036125183
# INFO:lightwood-908130:Loss @ epoch 352: 0.26986733078956604
# INFO:lightwood-908130:Loss @ epoch 353: 0.2692624628543854
# INFO:lightwood-908130:Loss @ epoch 354: 0.26864203810691833
# INFO:lightwood-908130:Loss @ epoch 355: 0.2667226493358612
# INFO:lightwood-908130:Loss @ epoch 356: 0.26606249809265137
# INFO:lightwood-908130:Loss @ epoch 357: 0.2654884457588196
# INFO:lightwood-908130:Loss @ epoch 358: 0.26517727971076965
# INFO:lightwood-908130:Loss @ epoch 359: 0.2645682990550995
# INFO:lightwood-908130:Loss @ epoch 360: 0.2639687955379486
# INFO:lightwood-908130:Loss @ epoch 361: 0.26211270689964294
# INFO:lightwood-908130:Loss @ epoch 362: 0.2614624500274658
# INFO:lightwood-908130:Loss @ epoch 363: 0.2609347999095917
# INFO:lightwood-908130:Loss @ epoch 364: 0.2606496214866638
# INFO:lightwood-908130:Loss @ epoch 365: 0.2600456178188324
# INFO:lightwood-908130:Loss @ epoch 366: 0.25945398211479187
# INFO:lightwood-908130:Loss @ epoch 367: 0.25761914253234863
# INFO:lightwood-908130:Loss @ epoch 368: 0.25698310136795044
# INFO:lightwood-908130:Loss @ epoch 369: 0.2564389705657959
# INFO:lightwood-908130:Loss @ epoch 370: 0.25615373253822327
# INFO:lightwood-908130:Loss @ epoch 371: 0.255537748336792
# INFO:lightwood-908130:Loss @ epoch 372: 0.2549669146537781
# INFO:lightwood-908130:Loss @ epoch 373: 0.253163605928421
# INFO:lightwood-908130:Loss @ epoch 374: 0.25253385305404663
# INFO:lightwood-908130:Loss @ epoch 375: 0.25198400020599365
# INFO:lightwood-908130:Loss @ epoch 376: 0.25169727206230164
# INFO:lightwood-908130:Loss @ epoch 377: 0.25105834007263184
# INFO:lightwood-908130:Loss @ epoch 378: 0.25050458312034607
# INFO:lightwood-908130:Loss @ epoch 379: 0.24875034391880035
# INFO:lightwood-908130:Loss @ epoch 380: 0.24813072383403778
# INFO:lightwood-908130:Loss @ epoch 381: 0.2475997507572174
# INFO:lightwood-908130:Loss @ epoch 382: 0.24732187390327454
# INFO:lightwood-908130:Loss @ epoch 383: 0.2466779351234436
# INFO:lightwood-908130:Loss @ epoch 384: 0.24614520370960236
# INFO:lightwood-908130:Loss @ epoch 385: 0.2444324791431427
# INFO:lightwood-908130:Loss @ epoch 386: 0.24381381273269653
# INFO:lightwood-908130:Loss @ epoch 387: 0.24329783022403717
# INFO:lightwood-908130:Loss @ epoch 388: 0.24302682280540466
# INFO:lightwood-908130:Loss @ epoch 389: 0.2423836588859558
# INFO:lightwood-908130:Loss @ epoch 390: 0.24187032878398895
# INFO:lightwood-908130:Loss @ epoch 391: 0.2401982992887497
# INFO:lightwood-908130:Loss @ epoch 392: 0.23961150646209717
# INFO:lightwood-908130:Loss @ epoch 393: 0.23912206292152405
# INFO:lightwood-908130:Loss @ epoch 394: 0.23886246979236603
# INFO:lightwood-908130:Loss @ epoch 395: 0.23822689056396484
# INFO:lightwood-908130:Loss @ epoch 396: 0.237734854221344
# INFO:lightwood-908130:Loss @ epoch 397: 0.23611803352832794
# INFO:lightwood-908130:Loss @ epoch 398: 0.23554179072380066
# INFO:lightwood-908130:Loss @ epoch 399: 0.23504941165447235
# INFO:lightwood-908130:Loss @ epoch 400: 0.23481720685958862
# INFO:lightwood-908130:Loss @ epoch 401: 0.234195277094841
# INFO:lightwood-908130:Loss @ epoch 402: 0.2337416410446167
# INFO:lightwood-908130:Loss @ epoch 403: 0.23221845924854279
# INFO:lightwood-908130:Loss @ epoch 404: 0.23166179656982422
# INFO:lightwood-908130:Loss @ epoch 405: 0.23119647800922394
# INFO:lightwood-908130:Loss @ epoch 406: 0.2309601753950119
# INFO:lightwood-908130:Loss @ epoch 407: 0.2303217649459839
# INFO:lightwood-908130:Loss @ epoch 408: 0.22987957298755646
# INFO:lightwood-908130:Loss @ epoch 409: 0.2283727526664734
# INFO:lightwood-908130:Loss @ epoch 410: 0.22785036265850067
# INFO:lightwood-908130:Loss @ epoch 411: 0.2274087369441986
# INFO:lightwood-908130:Loss @ epoch 412: 0.2272031456232071
# INFO:lightwood-908130:Loss @ epoch 413: 0.2265806496143341
# INFO:lightwood-908130:Loss @ epoch 414: 0.22616399824619293
# INFO:lightwood-908130:Loss @ epoch 415: 0.22472381591796875
# INFO:lightwood-908130:Loss @ epoch 416: 0.22424206137657166
# INFO:lightwood-908130:Loss @ epoch 417: 0.22381484508514404
# INFO:lightwood-908130:Loss @ epoch 418: 0.22362565994262695
# INFO:lightwood-908130:Loss @ epoch 419: 0.2230103462934494
# INFO:lightwood-908130:Loss @ epoch 420: 0.22263017296791077
# INFO:lightwood-908130:Loss @ epoch 421: 0.2212706357240677
# INFO:lightwood-908130:Loss @ epoch 422: 0.22078944742679596
# INFO:lightwood-908130:Loss @ epoch 423: 0.22038373351097107
# INFO:lightwood-908130:Loss @ epoch 424: 0.22021669149398804
# INFO:lightwood-908130:Loss @ epoch 425: 0.21961724758148193
# INFO:lightwood-908130:Loss @ epoch 426: 0.21926285326480865
# INFO:lightwood-908130:Loss @ epoch 427: 0.21795646846294403
# INFO:lightwood-908130:Loss @ epoch 428: 0.21745790541172028
# INFO:lightwood-908130:Loss @ epoch 429: 0.21706315875053406
# INFO:lightwood-908130:Loss @ epoch 430: 0.2169005125761032
# INFO:lightwood-908130:Loss @ epoch 431: 0.2162984162569046
# INFO:lightwood-908130:Loss @ epoch 432: 0.21596290171146393
# INFO:lightwood-908130:Loss @ epoch 433: 0.21467675268650055
# INFO:lightwood-908130:Loss @ epoch 434: 0.2142096608877182
# INFO:lightwood-908130:Loss @ epoch 435: 0.21381807327270508
# INFO:lightwood-908130:Loss @ epoch 436: 0.21366967260837555
# INFO:lightwood-908130:Loss @ epoch 437: 0.21306045353412628
# INFO:lightwood-908130:Loss @ epoch 438: 0.21273104846477509
# INFO:lightwood-908130:Loss @ epoch 439: 0.2114597111940384
# INFO:lightwood-908130:Loss @ epoch 440: 0.21101294457912445
# INFO:lightwood-908130:Loss @ epoch 441: 0.2106405347585678
# INFO:lightwood-908130:Loss @ epoch 442: 0.21048691868782043
# INFO:lightwood-908130:Loss @ epoch 443: 0.20988716185092926
# INFO:lightwood-908130:Loss @ epoch 444: 0.209584578871727
# INFO:lightwood-908130:Loss @ epoch 445: 0.20837938785552979
# INFO:lightwood-908130:Loss @ epoch 446: 0.20790636539459229
# INFO:lightwood-908130:Loss @ epoch 447: 0.20751990377902985
# INFO:lightwood-908130:Loss @ epoch 448: 0.20735298097133636
# INFO:lightwood-908130:Loss @ epoch 449: 0.20671916007995605
# INFO:lightwood-908130:Loss @ epoch 450: 0.2063988298177719
# INFO:lightwood-908130:Loss @ epoch 451: 0.20517104864120483
# INFO:lightwood-908130:Loss @ epoch 452: 0.20471569895744324
# INFO:lightwood-908130:Loss @ epoch 453: 0.20432589948177338
# INFO:lightwood-908130:Loss @ epoch 454: 0.20417317748069763
# INFO:lightwood-908130:Loss @ epoch 455: 0.20356149971485138
# INFO:lightwood-908130:Loss @ epoch 456: 0.2032759189605713
# INFO:lightwood-908130:Loss @ epoch 457: 0.20210769772529602
# INFO:lightwood-908130:Loss @ epoch 458: 0.20165468752384186
# INFO:lightwood-908130:Loss @ epoch 459: 0.20128485560417175
# INFO:lightwood-908130:Loss @ epoch 460: 0.20113368332386017
# INFO:lightwood-908130:Loss @ epoch 461: 0.20052364468574524
# INFO:lightwood-908130:Loss @ epoch 462: 0.20025908946990967
# INFO:lightwood-908130:Loss @ epoch 463: 0.199128195643425
# INFO:lightwood-908130:Loss @ epoch 464: 0.19867146015167236
# INFO:lightwood-908130:Loss @ epoch 465: 0.19831950962543488
# INFO:lightwood-908130:Loss @ epoch 466: 0.1981717050075531
# INFO:lightwood-908130:Loss @ epoch 467: 0.19755315780639648
# INFO:lightwood-908130:Loss @ epoch 468: 0.1972937434911728
# INFO:lightwood-908130:Loss @ epoch 469: 0.19619576632976532
# INFO:lightwood-908130:Loss @ epoch 470: 0.19577406346797943
# INFO:lightwood-908130:Loss @ epoch 471: 0.19542600214481354
# INFO:lightwood-908130:Loss @ epoch 472: 0.19528289139270782
# INFO:lightwood-908130:Loss @ epoch 473: 0.19465351104736328
# INFO:lightwood-908130:Loss @ epoch 474: 0.19439992308616638
# INFO:lightwood-908130:Loss @ epoch 475: 0.19336199760437012
# INFO:lightwood-908130:Loss @ epoch 476: 0.1929384022951126
# INFO:lightwood-908130:Loss @ epoch 477: 0.19260521233081818
# INFO:lightwood-908130:Loss @ epoch 478: 0.19245915114879608
# INFO:lightwood-908130:Loss @ epoch 479: 0.19183608889579773
# INFO:lightwood-908130:Loss @ epoch 480: 0.1915982961654663
# INFO:lightwood-908130:Loss @ epoch 481: 0.19057606160640717
# INFO:lightwood-908130:Loss @ epoch 482: 0.19016018509864807
# INFO:lightwood-908130:Loss @ epoch 483: 0.18981729447841644
# INFO:lightwood-908130:Loss @ epoch 484: 0.1896592527627945
# INFO:lightwood-908130:Loss @ epoch 485: 0.18903104960918427
# INFO:lightwood-908130:Loss @ epoch 486: 0.1888105273246765
# INFO:lightwood-908130:Loss @ epoch 487: 0.18783874809741974
# INFO:lightwood-908130:Loss @ epoch 488: 0.18742635846138
# INFO:lightwood-908130:Loss @ epoch 489: 0.18710274994373322
# INFO:lightwood-908130:Loss @ epoch 490: 0.1869581639766693
# INFO:lightwood-908130:Loss @ epoch 491: 0.18633641302585602
# INFO:lightwood-908130:Loss @ epoch 492: 0.1861308217048645
# INFO:lightwood-908130:Loss @ epoch 493: 0.18518073856830597
# INFO:lightwood-908130:Loss @ epoch 494: 0.18477877974510193
# INFO:lightwood-908130:Loss @ epoch 495: 0.1844625473022461
# INFO:lightwood-908130:Loss @ epoch 496: 0.18431106209754944
# INFO:lightwood-908130:Loss @ epoch 497: 0.18369436264038086
# INFO:lightwood-908130:Loss @ epoch 498: 0.18349310755729675
# INFO:lightwood-908130:Loss @ epoch 499: 0.1825518012046814
# INFO:lightwood-908130:Loss @ epoch 500: 0.18213677406311035
# INFO:lightwood-908130:Loss @ epoch 501: 0.18183834850788116
# INFO:lightwood-908130:Loss @ epoch 502: 0.1817081868648529
# INFO:lightwood-908130:Loss @ epoch 503: 0.1810757964849472
# INFO:lightwood-908130:Loss @ epoch 504: 0.1808813065290451
# INFO:lightwood-908130:Loss @ epoch 505: 0.17996278405189514
# INFO:lightwood-908130:Loss @ epoch 506: 0.17956294119358063
# INFO:lightwood-908130:Loss @ epoch 507: 0.17926038801670074
# INFO:lightwood-908130:Loss @ epoch 508: 0.17914170026779175
# INFO:lightwood-908130:Loss @ epoch 509: 0.17853714525699615
# INFO:lightwood-908130:Loss @ epoch 510: 0.17837682366371155
# INFO:lightwood-908130:Loss @ epoch 511: 0.17755495011806488
# INFO:lightwood-908130:Loss @ epoch 512: 0.17717775702476501
# INFO:lightwood-908130:Loss @ epoch 513: 0.17692075669765472
# INFO:lightwood-908130:Loss @ epoch 514: 0.17682957649230957
# INFO:lightwood-908130:Loss @ epoch 515: 0.17622879147529602
# INFO:lightwood-908130:Loss @ epoch 516: 0.17608126997947693
# INFO:lightwood-908130:Loss @ epoch 517: 0.17530043423175812
# INFO:lightwood-908130:Loss @ epoch 518: 0.17492830753326416
# INFO:lightwood-908130:Loss @ epoch 519: 0.17466434836387634
# INFO:lightwood-908130:Loss @ epoch 520: 0.1745508909225464
# INFO:lightwood-908130:Loss @ epoch 521: 0.17393381893634796
# INFO:lightwood-908130:Loss @ epoch 522: 0.17379191517829895
# INFO:lightwood-908130:Loss @ epoch 523: 0.17304573953151703
# INFO:lightwood-908130:Loss @ epoch 524: 0.17264863848686218
# INFO:lightwood-908130:Loss @ epoch 525: 0.1723754107952118
# INFO:lightwood-908130:Loss @ epoch 526: 0.17226344347000122
# INFO:lightwood-908130:Loss @ epoch 527: 0.17164956033229828
# INFO:lightwood-908130:Loss @ epoch 528: 0.17150914669036865
# INFO:lightwood-908130:Loss @ epoch 529: 0.17074352502822876
# INFO:lightwood-908130:Loss @ epoch 530: 0.17034272849559784
# INFO:lightwood-908130:Loss @ epoch 531: 0.17008455097675323
# INFO:lightwood-908130:Loss @ epoch 532: 0.16997462511062622
# INFO:lightwood-908130:Loss @ epoch 533: 0.16934703290462494
# INFO:lightwood-908130:Loss @ epoch 534: 0.16920581459999084
# INFO:lightwood-908130:Loss @ epoch 535: 0.1684671938419342
# INFO:lightwood-908130:Loss @ epoch 536: 0.1680554300546646
# INFO:lightwood-908130:Loss @ epoch 537: 0.16779953241348267
# INFO:lightwood-908130:Loss @ epoch 538: 0.16771765053272247
# INFO:lightwood-908130:Loss @ epoch 539: 0.16709519922733307
# INFO:lightwood-908130:Loss @ epoch 540: 0.16696059703826904
# INFO:lightwood-908130:Loss @ epoch 541: 0.1662113517522812
# INFO:lightwood-908130:Loss @ epoch 542: 0.16583819687366486
# INFO:lightwood-908130:Loss @ epoch 543: 0.1655835658311844
# INFO:lightwood-908130:Loss @ epoch 544: 0.1654866635799408
# INFO:lightwood-908130:Loss @ epoch 545: 0.16486963629722595
# INFO:lightwood-908130:Loss @ epoch 546: 0.16475720703601837
# INFO:lightwood-908130:Loss @ epoch 547: 0.16407933831214905
# INFO:lightwood-908130:Loss @ epoch 548: 0.16369643807411194
# INFO:lightwood-908130:Loss @ epoch 549: 0.1634456217288971
# INFO:lightwood-908130:Loss @ epoch 550: 0.16335204243659973
# INFO:lightwood-908130:Loss @ epoch 551: 0.16273930668830872
# INFO:lightwood-908130:Loss @ epoch 552: 0.16262173652648926
# INFO:lightwood-908130:Loss @ epoch 553: 0.16194282472133636
# INFO:lightwood-908130:Loss @ epoch 554: 0.16156929731369019
# INFO:lightwood-908130:Loss @ epoch 555: 0.1613406091928482
# INFO:lightwood-908130:Loss @ epoch 556: 0.16122305393218994
# INFO:lightwood-908130:Loss @ epoch 557: 0.16061483323574066
# INFO:lightwood-908130:Loss @ epoch 558: 0.1605129837989807
# INFO:lightwood-908130:Loss @ epoch 559: 0.15989282727241516
# INFO:lightwood-908130:Loss @ epoch 560: 0.15951070189476013
# INFO:lightwood-908130:Loss @ epoch 561: 0.15928155183792114
# INFO:lightwood-908130:Loss @ epoch 562: 0.15917648375034332
# INFO:lightwood-908130:Loss @ epoch 563: 0.1585562378168106
# INFO:lightwood-908130:Loss @ epoch 564: 0.1584508866071701
# INFO:lightwood-908130:Loss @ epoch 565: 0.1578230857849121
# INFO:lightwood-908130:Loss @ epoch 566: 0.15743260085582733
# INFO:lightwood-908130:Loss @ epoch 567: 0.15720276534557343
# INFO:lightwood-908130:Loss @ epoch 568: 0.1570967584848404
# INFO:lightwood-908130:Loss @ epoch 569: 0.1564950793981552
# INFO:lightwood-908130:Loss @ epoch 570: 0.1564052253961563
# INFO:lightwood-908130:Loss @ epoch 571: 0.1558011919260025
# INFO:lightwood-908130:Loss @ epoch 572: 0.15543553233146667
# INFO:lightwood-908130:Loss @ epoch 573: 0.15522390604019165
# INFO:lightwood-908130:Loss @ epoch 574: 0.15510474145412445
# INFO:lightwood-908130:Loss @ epoch 575: 0.15448075532913208
# INFO:lightwood-908130:Loss @ epoch 576: 0.15437306463718414
# INFO:lightwood-908130:Loss @ epoch 577: 0.1537812203168869
# INFO:lightwood-908130:Loss @ epoch 578: 0.15342742204666138
# INFO:lightwood-908130:Loss @ epoch 579: 0.15322083234786987
# INFO:lightwood-908130:Loss @ epoch 580: 0.15312625467777252
# INFO:lightwood-908130:Loss @ epoch 581: 0.15251080691814423
# INFO:lightwood-908130:Loss @ epoch 582: 0.15240485966205597
# INFO:lightwood-908130:Loss @ epoch 583: 0.15180188417434692
# INFO:lightwood-908130:Loss @ epoch 584: 0.15146155655384064
# INFO:lightwood-908130:Loss @ epoch 585: 0.1512601375579834
# INFO:lightwood-908130:Loss @ epoch 586: 0.1512046605348587
# INFO:lightwood-908130:Loss @ epoch 587: 0.15059597790241241
# INFO:lightwood-908130:Loss @ epoch 588: 0.15052524209022522
# INFO:lightwood-908130:Loss @ epoch 589: 0.15002799034118652
# INFO:lightwood-908130:Loss @ epoch 590: 0.1496528536081314
# INFO:lightwood-908130:Loss @ epoch 591: 0.14944542944431305
# INFO:lightwood-908130:Loss @ epoch 592: 0.14936235547065735
# INFO:lightwood-908130:Loss @ epoch 593: 0.1487627625465393
# INFO:lightwood-908130:Loss @ epoch 594: 0.14867989718914032
# INFO:lightwood-908130:Loss @ epoch 595: 0.1481548696756363
# INFO:lightwood-908130:Loss @ epoch 596: 0.14781904220581055
# INFO:lightwood-908130:Loss @ epoch 597: 0.14761477708816528
# INFO:lightwood-908130:Loss @ epoch 598: 0.14752981066703796
# INFO:lightwood-908130:Loss @ epoch 599: 0.14695626497268677
# INFO:lightwood-908130:Loss @ epoch 600: 0.14689260721206665
# INFO:lightwood-908130:Loss @ epoch 601: 0.14637303352355957
# INFO:lightwood-908130:Loss @ epoch 602: 0.14598247408866882
# INFO:lightwood-908130:Loss @ epoch 603: 0.1458090990781784
# INFO:lightwood-908130:Loss @ epoch 604: 0.1457597017288208
# INFO:lightwood-908130:Loss @ epoch 605: 0.14517170190811157
# INFO:lightwood-908130:Loss @ epoch 606: 0.14510279893875122
# INFO:lightwood-908130:Loss @ epoch 607: 0.14461268484592438
# INFO:lightwood-908130:Loss @ epoch 608: 0.1442790925502777
# INFO:lightwood-908130:Loss @ epoch 609: 0.1440761238336563
# INFO:lightwood-908130:Loss @ epoch 610: 0.1439637839794159
# INFO:lightwood-908130:Loss @ epoch 611: 0.14339026808738708
# INFO:lightwood-908130:Loss @ epoch 612: 0.14333517849445343
# INFO:lightwood-908130:Loss @ epoch 613: 0.14289021492004395
# INFO:lightwood-908130:Loss @ epoch 614: 0.14252623915672302
# INFO:lightwood-908130:Loss @ epoch 615: 0.14234210550785065
# INFO:lightwood-908130:Loss @ epoch 616: 0.14227262139320374
# INFO:lightwood-908130:Loss @ epoch 617: 0.14167767763137817
# INFO:lightwood-908130:Loss @ epoch 618: 0.14162331819534302
# INFO:lightwood-908130:Loss @ epoch 619: 0.14114806056022644
# INFO:lightwood-908130:Loss @ epoch 620: 0.1407812535762787
# INFO:lightwood-908130:Loss @ epoch 621: 0.1406484693288803
# INFO:lightwood-908130:Loss @ epoch 622: 0.14058469235897064
# INFO:lightwood-908130:Loss @ epoch 623: 0.13998940587043762
# INFO:lightwood-908130:Loss @ epoch 624: 0.13993394374847412
# INFO:lightwood-908130:Loss @ epoch 625: 0.139502614736557
# INFO:lightwood-908130:Loss @ epoch 626: 0.13914409279823303
# INFO:lightwood-908130:Loss @ epoch 627: 0.13900350034236908
# INFO:lightwood-908130:Loss @ epoch 628: 0.1389307826757431
# INFO:lightwood-908130:Loss @ epoch 629: 0.1383512318134308
# INFO:lightwood-908130:Loss @ epoch 630: 0.13828778266906738
# INFO:lightwood-908130:Loss @ epoch 631: 0.13782517611980438
# INFO:lightwood-908130:Loss @ epoch 632: 0.1374991238117218
# INFO:lightwood-908130:Loss @ epoch 633: 0.1373615264892578
# INFO:lightwood-908130:Loss @ epoch 634: 0.13728588819503784
# INFO:lightwood-908130:Loss @ epoch 635: 0.13671275973320007
# INFO:lightwood-908130:Loss @ epoch 636: 0.13666383922100067
# INFO:lightwood-908130:Loss @ epoch 637: 0.13624359667301178
# INFO:lightwood-908130:Loss @ epoch 638: 0.13592025637626648
# INFO:lightwood-908130:Loss @ epoch 639: 0.13577060401439667
# INFO:lightwood-908130:Loss @ epoch 640: 0.13573139905929565
# INFO:lightwood-908130:Loss @ epoch 641: 0.13514167070388794
# INFO:lightwood-908130:Loss @ epoch 642: 0.13509899377822876
# INFO:lightwood-908130:Loss @ epoch 643: 0.1348009556531906
# INFO:lightwood-908130:Loss @ epoch 644: 0.13442862033843994
# INFO:lightwood-908130:Loss @ epoch 645: 0.13428670167922974
# INFO:lightwood-908130:Loss @ epoch 646: 0.13425418734550476
# INFO:lightwood-908130:Loss @ epoch 647: 0.13366393744945526
# INFO:lightwood-908130:Loss @ epoch 648: 0.13362039625644684
# INFO:lightwood-908130:Loss @ epoch 649: 0.1332494020462036
# INFO:lightwood-908130:Loss @ epoch 650: 0.13295848667621613
# INFO:lightwood-908130:Loss @ epoch 651: 0.13284243643283844
# INFO:lightwood-908130:Loss @ epoch 652: 0.13279221951961517
# INFO:lightwood-908130:Loss @ epoch 653: 0.1321975290775299
# INFO:lightwood-908130:Loss @ epoch 654: 0.13215911388397217
# INFO:lightwood-908130:Loss @ epoch 655: 0.13183866441249847
# INFO:lightwood-908130:Loss @ epoch 656: 0.13152629137039185
# INFO:lightwood-908130:Loss @ epoch 657: 0.13141591846942902
# INFO:lightwood-908130:Loss @ epoch 658: 0.13137805461883545
# INFO:lightwood-908130:Loss @ epoch 659: 0.13082456588745117
# INFO:lightwood-908130:Loss @ epoch 660: 0.130796417593956
# INFO:lightwood-908130:Loss @ epoch 661: 0.13050323724746704
# INFO:lightwood-908130:Loss @ epoch 662: 0.13020437955856323
# INFO:lightwood-908130:Loss @ epoch 663: 0.13009272515773773
# INFO:lightwood-908130:Loss @ epoch 664: 0.13006633520126343
# INFO:lightwood-908130:Loss @ epoch 665: 0.1294911503791809
# INFO:lightwood-908130:Loss @ epoch 666: 0.12944844365119934
# INFO:lightwood-908130:Loss @ epoch 667: 0.12918516993522644
# INFO:lightwood-908130:Loss @ epoch 668: 0.12888871133327484
# INFO:lightwood-908130:Loss @ epoch 669: 0.12879078090190887
# INFO:lightwood-908130:Loss @ epoch 670: 0.12875106930732727
# INFO:lightwood-908130:Loss @ epoch 671: 0.12817256152629852
# INFO:lightwood-908130:Loss @ epoch 672: 0.1281382441520691
# INFO:lightwood-908130:Loss @ epoch 673: 0.12789326906204224
# INFO:lightwood-908130:Loss @ epoch 674: 0.1275915801525116
# INFO:lightwood-908130:Loss @ epoch 675: 0.1275024265050888
# INFO:lightwood-908130:Loss @ epoch 676: 0.12748983502388
# INFO:lightwood-908130:Loss @ epoch 677: 0.12696318328380585
# INFO:lightwood-908130:Loss @ epoch 678: 0.1269436627626419
# INFO:lightwood-908130:Loss @ epoch 679: 0.1266997754573822
# INFO:lightwood-908130:Loss @ epoch 680: 0.12639999389648438
# INFO:lightwood-908130:Loss @ epoch 681: 0.12633533775806427
# INFO:lightwood-908130:Loss @ epoch 682: 0.12631458044052124
# INFO:lightwood-908130:Loss @ epoch 683: 0.125779926776886
# INFO:lightwood-908130:Loss @ epoch 684: 0.12575621902942657
# INFO:lightwood-908130:Loss @ epoch 685: 0.12551364302635193
# INFO:lightwood-908130:Loss @ epoch 686: 0.12518511712551117
# INFO:lightwood-908130:Loss @ epoch 687: 0.12508130073547363
# INFO:lightwood-908130:Loss @ epoch 688: 0.1250697523355484
# INFO:lightwood-908130:Loss @ epoch 689: 0.12454408407211304
# INFO:lightwood-908130:Loss @ epoch 690: 0.12452033162117004
# INFO:lightwood-908130:Loss @ epoch 691: 0.12426988035440445
# INFO:lightwood-908130:Loss @ epoch 692: 0.12396405637264252
# INFO:lightwood-908130:Loss @ epoch 693: 0.12391042709350586
# INFO:lightwood-908130:Loss @ epoch 694: 0.12387368083000183
# INFO:lightwood-908130:Loss @ epoch 695: 0.12333890050649643
# INFO:lightwood-908130:Loss @ epoch 696: 0.12332195788621902
# INFO:lightwood-908130:Loss @ epoch 697: 0.12313605099916458
# INFO:lightwood-908130:Loss @ epoch 698: 0.12281865626573563
# INFO:lightwood-908130:Loss @ epoch 699: 0.12272768467664719
# INFO:lightwood-908130:Loss @ epoch 700: 0.12270215898752213
# INFO:lightwood-908130:Loss @ epoch 701: 0.12218338251113892
# INFO:lightwood-908130:Loss @ epoch 702: 0.12216271460056305
# INFO:lightwood-908130:Loss @ epoch 703: 0.12196072936058044
# INFO:lightwood-908130:Loss @ epoch 704: 0.12164133042097092
# INFO:lightwood-908130:Loss @ epoch 705: 0.12158623337745667
# INFO:lightwood-908130:Loss @ epoch 706: 0.121589794754982
# INFO:lightwood-908130:Loss @ epoch 707: 0.12106841057538986
# INFO:lightwood-908130:Loss @ epoch 708: 0.12104156613349915
# INFO:lightwood-908130:Loss @ epoch 709: 0.12083958089351654
# INFO:lightwood-908130:Loss @ epoch 710: 0.12054767459630966
# INFO:lightwood-908130:Loss @ epoch 711: 0.12049080431461334
# INFO:lightwood-908130:Loss @ epoch 712: 0.12051218748092651
# INFO:lightwood-908130:Loss @ epoch 713: 0.11997763812541962
# INFO:lightwood-908130:Loss @ epoch 714: 0.11995280534029007
# INFO:lightwood-908130:Loss @ epoch 715: 0.11979631334543228
# INFO:lightwood-908130:Loss @ epoch 716: 0.11950591206550598
# INFO:lightwood-908130:Loss @ epoch 717: 0.11940625309944153
# INFO:lightwood-908130:Loss @ epoch 718: 0.11941412091255188
# INFO:lightwood-908130:Loss @ epoch 719: 0.11888512223958969
# INFO:lightwood-908130:Loss @ epoch 720: 0.1188698410987854
# INFO:lightwood-908130:Loss @ epoch 721: 0.1187317967414856
# INFO:lightwood-908130:Loss @ epoch 722: 0.11840859055519104
# INFO:lightwood-908130:Loss @ epoch 723: 0.11838638782501221
# INFO:lightwood-908130:Loss @ epoch 724: 0.11840500682592392
# INFO:lightwood-908130:Loss @ epoch 725: 0.11787142604589462
# INFO:lightwood-908130:Loss @ epoch 726: 0.11786124110221863
# INFO:lightwood-908130:Loss @ epoch 727: 0.1177288070321083
# INFO:lightwood-908130:Loss @ epoch 728: 0.11746444553136826
# INFO:lightwood-908130:Loss @ epoch 729: 0.1173962652683258
# INFO:lightwood-908130:Loss @ epoch 730: 0.1173873022198677
# INFO:lightwood-908130:Loss @ epoch 731: 0.11685530096292496
# INFO:lightwood-908130:Loss @ epoch 732: 0.11682343482971191
# INFO:lightwood-908130:Loss @ epoch 733: 0.11666446179151535
# INFO:lightwood-908130:Loss @ epoch 734: 0.11634565144777298
# INFO:lightwood-908130:Loss @ epoch 735: 0.11632642894983292
# INFO:lightwood-908130:Loss @ epoch 736: 0.11630884557962418
# INFO:lightwood-908130:Loss @ epoch 737: 0.11578623950481415
# INFO:lightwood-908130:Loss @ epoch 738: 0.11575408279895782
# INFO:lightwood-908130:Loss @ epoch 739: 0.11561760306358337
# INFO:lightwood-908130:Loss @ epoch 740: 0.1153736338019371
# INFO:lightwood-908130:Loss @ epoch 741: 0.11529770493507385
# INFO:lightwood-908130:Loss @ epoch 742: 0.11532368510961533
# INFO:lightwood-908130:Loss @ epoch 743: 0.1148049607872963
# INFO:lightwood-908130:Loss @ epoch 744: 0.11477407813072205
# INFO:lightwood-908130:Loss @ epoch 745: 0.11463240534067154
# INFO:lightwood-908130:Loss @ epoch 746: 0.11433375626802444
# INFO:lightwood-908130:Loss @ epoch 747: 0.11432340741157532
# INFO:lightwood-908130:Loss @ epoch 748: 0.1143229603767395
# INFO:lightwood-908130:Loss @ epoch 749: 0.11378251016139984
# INFO:lightwood-908130:Loss @ epoch 750: 0.11375992000102997
# INFO:lightwood-908130:Loss @ epoch 751: 0.11365910619497299
# INFO:lightwood-908130:Loss @ epoch 752: 0.1133420392870903
# INFO:lightwood-908130:Loss @ epoch 753: 0.11334141343832016
# INFO:lightwood-908130:Loss @ epoch 754: 0.11331292241811752
# INFO:lightwood-908130:Loss @ epoch 755: 0.11280126869678497
# INFO:lightwood-908130:Loss @ epoch 756: 0.11277835816144943
# INFO:lightwood-908130:Loss @ epoch 757: 0.11271759867668152
# INFO:lightwood-908130:Loss @ epoch 758: 0.1124328076839447
# INFO:lightwood-908130:Loss @ epoch 759: 0.11240795254707336
# INFO:lightwood-908130:Loss @ epoch 760: 0.11240893602371216
# INFO:lightwood-908130:Loss @ epoch 761: 0.11186157912015915
# INFO:lightwood-908130:Loss @ epoch 762: 0.11182514578104019
# INFO:lightwood-908130:Loss @ epoch 763: 0.11175310611724854
# INFO:lightwood-908130:Loss @ epoch 764: 0.11149219423532486
# INFO:lightwood-908130:Loss @ epoch 765: 0.11144796013832092
# INFO:lightwood-908130:Loss @ epoch 766: 0.11147201061248779
# INFO:lightwood-908130:Loss @ epoch 767: 0.11095741391181946
# INFO:lightwood-908130:Loss @ epoch 768: 0.11092893034219742
# INFO:lightwood-908130:Loss @ epoch 769: 0.110817089676857
# INFO:lightwood-908130:Loss @ epoch 770: 0.11054517328739166
# INFO:lightwood-908130:Loss @ epoch 771: 0.11051582545042038
# INFO:lightwood-908130:Loss @ epoch 772: 0.11056117713451385
# INFO:lightwood-908130:Loss @ epoch 773: 0.11001968383789062
# INFO:lightwood-908130:Loss @ epoch 774: 0.10998150706291199
# INFO:lightwood-908130:Loss @ epoch 775: 0.10991909354925156
# INFO:lightwood-908130:Loss @ epoch 776: 0.10966959595680237
# INFO:lightwood-908130:Loss @ epoch 777: 0.10966488718986511
# INFO:lightwood-908130:Loss @ epoch 778: 0.10969415307044983
# INFO:lightwood-908130:Loss @ epoch 779: 0.10915788263082504
# INFO:lightwood-908130:Loss @ epoch 780: 0.10912240296602249
# INFO:lightwood-908130:Loss @ epoch 781: 0.1090470552444458
# INFO:lightwood-908130:Loss @ epoch 782: 0.10882016271352768
# INFO:lightwood-908130:Loss @ epoch 783: 0.10884296149015427
# INFO:lightwood-908130:Loss @ epoch 784: 0.10883786529302597
# INFO:lightwood-908130:Loss @ epoch 785: 0.10830084979534149
# INFO:lightwood-908130:Loss @ epoch 786: 0.10826165974140167
# INFO:lightwood-908130:Loss @ epoch 787: 0.10818905383348465
# INFO:lightwood-908130:Loss @ epoch 788: 0.10796596854925156
# INFO:lightwood-908130:Loss @ epoch 789: 0.10797103494405746
# INFO:lightwood-908130:Loss @ epoch 790: 0.10801070183515549
# INFO:lightwood-908130:Loss @ epoch 791: 0.1074749156832695
# INFO:lightwood-908130:Loss @ epoch 792: 0.10741573572158813
# INFO:lightwood-908130:Loss @ epoch 793: 0.10739295184612274
# INFO:lightwood-908130:Loss @ epoch 794: 0.1071559488773346
# INFO:lightwood-908130:Loss @ epoch 795: 0.10713861137628555
# INFO:lightwood-908130:Loss @ epoch 796: 0.10717244446277618
# INFO:lightwood-908130:Loss @ epoch 797: 0.10663255304098129
# INFO:lightwood-908130:Loss @ epoch 798: 0.1066012978553772
# INFO:lightwood-908130:Loss @ epoch 799: 0.10660473257303238
# INFO:lightwood-908130:Loss @ epoch 800: 0.10635695606470108
# INFO:lightwood-908130:Loss @ epoch 801: 0.10637898743152618
# INFO:lightwood-908130:Loss @ epoch 802: 0.10639200359582901
# INFO:lightwood-908130:Loss @ epoch 803: 0.10584243386983871
# INFO:lightwood-908130:Loss @ epoch 804: 0.10580042749643326
# INFO:lightwood-908130:Loss @ epoch 805: 0.1058068722486496
# INFO:lightwood-908130:Loss @ epoch 806: 0.10555949062108994
# INFO:lightwood-908130:Loss @ epoch 807: 0.1055503711104393
# INFO:lightwood-908130:Loss @ epoch 808: 0.10559772700071335
# INFO:lightwood-908130:Loss @ epoch 809: 0.10508520901203156
# INFO:lightwood-908130:Loss @ epoch 810: 0.10505250096321106
# INFO:lightwood-908130:Loss @ epoch 811: 0.10504698753356934
# INFO:lightwood-908130:Loss @ epoch 812: 0.10478050261735916
# INFO:lightwood-908130:Loss @ epoch 813: 0.10479176789522171
# INFO:lightwood-908130:Loss @ epoch 814: 0.10485058277845383
# INFO:lightwood-908130:Loss @ epoch 815: 0.10432618856430054
# INFO:lightwood-908130:Loss @ epoch 816: 0.10426971316337585
# INFO:lightwood-908130:Loss @ epoch 817: 0.10424735397100449
# INFO:lightwood-908130:Loss @ epoch 818: 0.10403512418270111
# INFO:lightwood-908130:Loss @ epoch 819: 0.10404300689697266
# INFO:lightwood-908130:Loss @ epoch 820: 0.10412769764661789
# INFO:lightwood-908130:Loss @ epoch 1: 0.06249391362071037
# INFO:lightwood-908130:Loss @ epoch 2: 0.058456951379776
# INFO:lightwood-908130:Loss @ epoch 3: 0.060117895156145094
# INFO:lightwood-908130:Loss @ epoch 4: 0.06299138367176056
# INFO:lightwood-908130:Loss @ epoch 5: 0.06045155674219131
# INFO:lightwood-908130:Loss @ epoch 6: 0.05933189913630486
# INFO:lightwood-908130:Loss @ epoch 7: 0.057834693044424054
# INFO:lightwood-908130:Loss @ epoch 8: 0.059484850615262985
# INFO:lightwood-908130:Started fitting LGBM model
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-908130:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-908130:Training GBM (<module 'lightgbm' from '/home/george/.local/lib/python3.8/site-packages/lightgbm/__init__.py'>) with 176 iterations given 22 seconds constraint
# INFO:lightwood-908130:Lightgbm model contains 880 weak estimators
# INFO:lightwood-908130:Updating lightgbm model with 10.5 iterations
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-908130:Model now has a total of 880 weak estimators
# WARNING:lightwood-908130:Exception: Unspported categorical type for regression when training mixer: <lightwood.mixer.regression.Regression object at 0x7f2e65f8f340>
# INFO:lightwood-908130:Ensembling the mixer
# INFO:lightwood-908130:Mixer: Neural got accuracy: 0.9222222222222223
# INFO:lightwood-908130:Mixer: LightGBM got accuracy: 1.0
# INFO:lightwood-908130:Picked best mixer: LightGBM
# INFO:lightwood-908130:Analyzing the ensemble of mixers
# INFO:lightwood-908130:The block ModelCorrelationHeatmap is now running its analyze() method
# INFO:lightwood-908130:The block ICP is now running its analyze() method
# INFO:lightwood-908130:The block AccStats is now running its analyze() method
# INFO:lightwood-908130:Adjustment on validation requested.
# INFO:lightwood-908130:Updating the mixers
# /home/george/.local/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-908130:Loss @ epoch 1: 0.06400734409689904
# INFO:lightwood-908130:Loss @ epoch 2: 0.06470740959048271
# INFO:lightwood-908130:Loss @ epoch 3: 0.06548315212130547
# INFO:lightwood-908130:Loss @ epoch 4: 0.06550823301076888
# INFO:lightwood-908130:Loss @ epoch 5: 0.06503513380885124
# INFO:lightwood-908130:Loss @ epoch 6: 0.06325613111257553
# INFO:lightwood-908130:Loss @ epoch 7: 0.06568712890148162
# INFO:lightwood-908130:Updating lightgbm model with 10.5 iterations
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-908130:Model now has a total of 880 weak estimators

# %% [markdown]
# Finally, we can visualize the mixer correlation matrix:

# %%
import matplotlib.pyplot as plt
import numpy as np

mc = predictor.runtime_analyzer['mixer_correlation']  # newly produced insight

mixer_names = [c.__class__.__name__ for c in predictor.ensemble.mixers]

# plotting code
fig, ax = plt.subplots()
im = ax.imshow(mc, cmap='seismic')

# set ticks
ax.set_xticks(np.arange(mc.shape[0]))
ax.set_yticks(np.arange(mc.shape[1]))

# set tick labels
ax.set_xticklabels(mixer_names)
ax.set_yticklabels(mixer_names)

# show cell values
for i in range(len(mixer_names)):
    for j in range(len(mixer_names)):
        text = ax.text(j, i, round(mc[i, j], 3), ha="center", va="center", color="w")

# %% [markdown]
# Nice! We've just added an additional piece of insight regarding the predictor that Lightwood came up with for the task of predicting the Human Development Index of any given country.
#
# What this matrix is telling us is whether the predictions of both mixers stored in the ensemble -- Neural and LightGBM -- have a high correlation or not.
#
# This is, of course, a very simple example, but it shows the convenience of such an abstraction within the broader pipeline that Lightwood automates.
#
# For more complex examples, you can check out any of the three core analysis blocks that we use:
#
# * `lightwood.analysis.nc.calibrate.ICP`
# * `lightwood.analysis.helpers.acc_stats.AccStats`
# * `lightwood.analysis.helpers.feature_importance.GlobalFeatureImportance`
