# %% [markdown]
# # Tutorial - Time series forecasting
#
# ## Introduction
#
# Time series are an ubiquitous type of data in all types of processes. Producing forecasts for them can be highly valuable in domains like retail or industrial manufacture, among many others.
#
# Lightwood supports time series forecasting (both univariate and multivariate inputs), handling many of the pain points commonly associated with setting up a manual time series predictive pipeline.
#
# In this tutorial, we will train a lightwood predictor and analyze its forecasts for the task of counting sunspots in monthly intervals.
#
# ## Load data
#
# Let's begin by loading the dataset and looking at it:

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/mindsdb/benchmarks/main/benchmarks/datasets/monthly_sunspots/data.csv")
df
# Out:
#         Month  Sunspots
# 0     1749-01      58.0
# 1     1749-02      62.6
# 2     1749-03      70.0
# 3     1749-04      55.7
# 4     1749-05      85.0
# ...       ...       ...
# 2815  1983-08      71.8
# 2816  1983-09      50.3
# 2817  1983-10      55.8
# 2818  1983-11      33.3
# 2819  1983-12      33.4
#
# [2820 rows x 2 columns]

# %% [markdown]
# This is a very simple dataset. It's got a single column that specifies the month in which the measurement was done, and then in the 'Sunspots' column we have the actual quantity we are interested in forecasting. As such, we can characterize this as a univariate time series problem.
#
# ## Define the predictive task
#
# We will use Lightwood high level methods to state what we want to predict. As this is a time series task (because we want to leverage the notion of time to predict), we need to specify a set of arguments that will activate Lightwood's time series pipeline:

# %%
from lightwood.api.high_level import ProblemDefinition

# %%
tss = {'nr_predictions': 6,   # the predictor will learn to forecast what the next semester counts will look like (6 data points at monthly intervals -> 6 months)
       'order_by': ['Month'], # what column is used to order the entire datset
       'window': 12           # how many past values to consider for emitting predictions
      }

pdef = ProblemDefinition.from_dict({'target': 'Sunspots',         # specify the column to forecast
                                    'timeseries_settings': tss    # pass along all time series specific parameters
                                   })

# %% [markdown]
# Now, let's do a very simple train-test split, leaving 10% of the data to check the forecasts that our predictor will produce:

# %%
cutoff = int(len(df)*0.9)

train = df[:cutoff]
test = df[cutoff:]

print(train.shape, test.shape)
# Out:
# (2538, 2) (282, 2)

# %% [markdown]
# ## Generate the predictor object
#
# Now, we can generate code for a machine learning model by using our problem definition and the data:

# %%
from lightwood.api.high_level import (
    json_ai_from_problem,
    code_from_json_ai,
    predictor_from_code
)

json_ai = json_ai_from_problem(df, problem_definition=pdef)
code = code_from_json_ai(json_ai)
predictor = predictor_from_code(code)

# uncomment this to see the generated code:
# print(code)
# Out:
# INFO:lightwood-822666:Dropping features: []
# INFO:lightwood-822666:Analyzing a sample of 2467
# INFO:lightwood-822666:from a total population of 2820, this is equivalent to 87.5% of your data.
# INFO:lightwood-822666:Using 7 processes to deduct types.
# INFO:lightwood-822666:Infering type for: Month
# INFO:lightwood-822666:Infering type for: Sunspots
# INFO:lightwood-822666:Column Sunspots has data type float
# INFO:lightwood-822666:Column Month has data type date
# /home/george/lightwood/lightwood/helpers/text.py:236: RuntimeWarning: invalid value encountered in double_scalars
#   randomness_per_index.append(S / np.log(N))
# INFO:lightwood-822666:Starting statistical analysis
# INFO:lightwood-822666:Finished statistical analysis
# INFO:lightwood-822666:Unable to import black formatter, predictor code might be a bit ugly.

# %% [markdown]
# ## Train
#
# Okay, everything is ready now for our predictor to learn based on the training data we will provide.
#
# Internally, lightwood cleans and reshapes the data, featurizes measurements and timestamps, and comes up with a handful of different models that will be evaluated to keep the one that produces the best forecasts.
#
# Let's train the predictor. This should take a couple of minutes, at most:

# %%
predictor.learn(train)
# Out:
# INFO:lightwood-822666:Dropping features: []
# INFO:lightwood-822666:Performing statistical analysis on data
# INFO:lightwood-822666:Starting statistical analysis
# INFO:lightwood-822666:Finished statistical analysis
# INFO:lightwood-822666:Cleaning the data
# INFO:lightwood-822666:Transforming timeseries data
# INFO:lightwood-822666:Using 7 processes to reshape.
# INFO:lightwood-822666:Splitting the data into train/test
# INFO:lightwood-822666:Preparing the encoders
# INFO:lightwood-822666:Encoder prepping dict length of: 1
# INFO:lightwood-822666:Done running for: Sunspots
# INFO:lightwood-822666:time series encoder epoch [1/100000] average_loss = 0.01903937479130476
# INFO:lightwood-822666:time series encoder epoch [2/100000] average_loss = 0.00696583822559191
# INFO:lightwood-822666:time series encoder epoch [3/100000] average_loss = 0.005391207061456242
# INFO:lightwood-822666:time series encoder epoch [4/100000] average_loss = 0.00483731451448823
# INFO:lightwood-822666:time series encoder epoch [5/100000] average_loss = 0.004527512324803124
# INFO:lightwood-822666:time series encoder epoch [6/100000] average_loss = 0.004340611983412659
# INFO:lightwood-822666:time series encoder epoch [7/100000] average_loss = 0.004251250157810293
# INFO:lightwood-822666:time series encoder epoch [8/100000] average_loss = 0.0042061529017268905
# INFO:lightwood-822666:time series encoder epoch [9/100000] average_loss = 0.004155796261511648
# INFO:lightwood-822666:time series encoder epoch [10/100000] average_loss = 0.004123638548731752
# INFO:lightwood-822666:time series encoder epoch [11/100000] average_loss = 0.0040658751617873535
# INFO:lightwood-822666:time series encoder epoch [12/100000] average_loss = 0.0040551868642093114
# INFO:lightwood-822666:time series encoder epoch [13/100000] average_loss = 0.004032735371600122
# INFO:lightwood-822666:time series encoder epoch [14/100000] average_loss = 0.003999243524316216
# INFO:lightwood-822666:time series encoder epoch [15/100000] average_loss = 0.003966319085004404
# INFO:lightwood-822666:time series encoder epoch [16/100000] average_loss = 0.003857737416078669
# INFO:lightwood-822666:time series encoder epoch [17/100000] average_loss = 0.003759245801359062
# INFO:lightwood-822666:time series encoder epoch [18/100000] average_loss = 0.0037687173167986533
# INFO:lightwood-822666:time series encoder epoch [19/100000] average_loss = 0.0037838339334833565
# INFO:lightwood-822666:time series encoder epoch [20/100000] average_loss = 0.0037465232043163775
# INFO:lightwood-822666:time series encoder epoch [21/100000] average_loss = 0.0036927966655163767
# INFO:lightwood-822666:time series encoder epoch [22/100000] average_loss = 0.0036318935862545802
# INFO:lightwood-822666:time series encoder epoch [23/100000] average_loss = 0.0036223276030760997
# INFO:lightwood-822666:time series encoder epoch [24/100000] average_loss = 0.0036461105624956748
# INFO:lightwood-822666:time series encoder epoch [25/100000] average_loss = 0.003603528287652398
# INFO:lightwood-822666:time series encoder epoch [26/100000] average_loss = 0.0035378947599041927
# INFO:lightwood-822666:time series encoder epoch [27/100000] average_loss = 0.0036199200880428113
# INFO:lightwood-822666:time series encoder epoch [28/100000] average_loss = 0.0036412655339527673
# INFO:lightwood-822666:time series encoder epoch [29/100000] average_loss = 0.0036523426347994502
# INFO:lightwood-822666:time series encoder epoch [30/100000] average_loss = 0.0035194624354306834
# INFO:lightwood-822666:time series encoder epoch [31/100000] average_loss = 0.003562038825655674
# INFO:lightwood-822666:time series encoder epoch [32/100000] average_loss = 0.0035993742179117375
# INFO:lightwood-822666:time series encoder epoch [33/100000] average_loss = 0.003458746487030391
# INFO:lightwood-822666:time series encoder epoch [34/100000] average_loss = 0.0035206213390790563
# INFO:lightwood-822666:time series encoder epoch [35/100000] average_loss = 0.0034739018114264882
# INFO:lightwood-822666:time series encoder epoch [36/100000] average_loss = 0.003622404913883452
# INFO:lightwood-822666:time series encoder epoch [37/100000] average_loss = 0.003657833114429857
# INFO:lightwood-822666:Featurizing the data
# INFO:lightwood-822666:Training the mixers
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-822666:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# WARNING:lightwood-822666:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-822666:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-822666:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-822666:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-822666:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# /home/george/.local/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# /home/george/.local/lib/python3.8/site-packages/pytorch_ranger/ranger.py:172: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1025.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# INFO:lightwood-822666:Loss of 0.6649370789527893 with learning rate 0.0001
# INFO:lightwood-822666:Loss of 0.7516084909439087 with learning rate 0.00014
# INFO:lightwood-822666:Found learning rate of: 0.0001
# /home/george/.local/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-822666:Loss @ epoch 1: 0.6899526566267014
# INFO:lightwood-822666:Loss @ epoch 2: 0.6870950907468796
# INFO:lightwood-822666:Loss @ epoch 3: 0.6836055964231491
# INFO:lightwood-822666:Loss @ epoch 4: 0.6795387864112854
# INFO:lightwood-822666:Loss @ epoch 5: 0.6749720126390457
# INFO:lightwood-822666:Loss @ epoch 6: 0.6699804365634918
# INFO:lightwood-822666:Loss @ epoch 7: 0.6612617373466492
# INFO:lightwood-822666:Loss @ epoch 8: 0.6552322059869766
# INFO:lightwood-822666:Loss @ epoch 9: 0.6488936841487885
# INFO:lightwood-822666:Loss @ epoch 10: 0.6422525644302368
# INFO:lightwood-822666:Loss @ epoch 102: 0.2265927642583847
# INFO:lightwood-822666:Loss @ epoch 103: 0.22639447450637817
# INFO:lightwood-822666:Loss @ epoch 104: 0.22631967812776566
# INFO:lightwood-822666:Loss @ epoch 105: 0.22625518590211868
# INFO:lightwood-822666:Loss @ epoch 106: 0.22622010856866837
# INFO:lightwood-822666:Loss @ epoch 107: 0.22622466087341309
# INFO:lightwood-822666:Loss @ epoch 108: 0.22623711079359055
# INFO:lightwood-822666:Loss @ epoch 109: 0.2263835296034813
# /home/george/.local/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-822666:Loss @ epoch 1: 0.17373556440526788
# INFO:lightwood-822666:Loss @ epoch 2: 0.17143312096595764
# INFO:lightwood-822666:Loss @ epoch 3: 0.17642144181511618
# INFO:lightwood-822666:Loss @ epoch 4: 0.17398986626755109
# INFO:lightwood-822666:Loss @ epoch 5: 0.17502195862206546
# INFO:lightwood-822666:Started fitting LGBM models for array prediction
# INFO:lightwood-822666:Started fitting LGBM model
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-822666:Training GBM (<module 'lightgbm' from '/home/george/.local/lib/python3.8/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-822666:Lightgbm model contains 30 weak estimators
# INFO:lightwood-822666:Updating lightgbm model with 1.5 iterations
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:Model now has a total of 31 weak estimators
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-822666:Started fitting LGBM model
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-822666:Training GBM (<module 'lightgbm' from '/home/george/.local/lib/python3.8/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-822666:Lightgbm model contains 22 weak estimators
# INFO:lightwood-822666:Updating lightgbm model with 1 iterations
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:Model now has a total of 23 weak estimators
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-822666:Started fitting LGBM model
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-822666:Training GBM (<module 'lightgbm' from '/home/george/.local/lib/python3.8/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-822666:Lightgbm model contains 24 weak estimators
# INFO:lightwood-822666:Updating lightgbm model with 1 iterations
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:Model now has a total of 25 weak estimators
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-822666:Started fitting LGBM model
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-822666:Training GBM (<module 'lightgbm' from '/home/george/.local/lib/python3.8/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-822666:Lightgbm model contains 26 weak estimators
# INFO:lightwood-822666:Updating lightgbm model with 1.5 iterations
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:Model now has a total of 27 weak estimators
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-822666:Started fitting LGBM model
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-822666:Training GBM (<module 'lightgbm' from '/home/george/.local/lib/python3.8/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-822666:Lightgbm model contains 22 weak estimators
# INFO:lightwood-822666:Updating lightgbm model with 1 iterations
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:Model now has a total of 23 weak estimators
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-822666:Started fitting LGBM model
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-822666:Training GBM (<module 'lightgbm' from '/home/george/.local/lib/python3.8/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-822666:Lightgbm model contains 19 weak estimators
# INFO:lightwood-822666:Updating lightgbm model with 1 iterations
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:Model now has a total of 20 weak estimators
# INFO:lightwood-822666:Started fitting sktime forecaster for array prediction
# INFO:lightwood-822666:Ensembling the mixer
# INFO:lightwood-822666:Mixer: Neural got accuracy: 0.4367426003915138
# INFO:lightwood-822666:Mixer: LightGBMArray got accuracy: 0.4254831727640132
# /home/george/.local/lib/python3.8/site-packages/pmdarima/arima/arima.py:692: UserWarning: As of version 1.5.0 'typ' is no longer a valid arg for predict. In future versions this will raise a TypeError.
#   warnings.warn("As of version 1.5.0 'typ' is no longer a valid "
# INFO:lightwood-822666:Mixer: SkTime got accuracy: 0.20254358319171598
# INFO:lightwood-822666:Picked best mixer: Neural
# INFO:lightwood-822666:Analyzing the ensemble of mixers
# INFO:lightwood-822666:The block ICP is now running its analyze() method
# INFO:lightwood-822666:The block AccStats is now running its analyze() method
# INFO:lightwood-822666:Adjustment on validation requested.
# INFO:lightwood-822666:Updating the mixers
# /home/george/.local/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-822666:Loss @ epoch 1: 0.1763392115632693
# INFO:lightwood-822666:Loss @ epoch 2: 0.175850381453832
# INFO:lightwood-822666:Loss @ epoch 3: 0.17862005159258842
# INFO:lightwood-822666:Loss @ epoch 4: 0.17577014118433
# INFO:lightwood-822666:Loss @ epoch 5: 0.17566540837287903
# INFO:lightwood-822666:Loss @ epoch 6: 0.17590341717004776
# INFO:lightwood-822666:Loss @ epoch 7: 0.17646863435705504
# INFO:lightwood-822666:Updating array of LGBM models...
# INFO:lightwood-822666:Updating lightgbm model with 1.5 iterations
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:Model now has a total of 32 weak estimators
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-822666:Updating lightgbm model with 1 iterations
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:Model now has a total of 24 weak estimators
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-822666:Updating lightgbm model with 1 iterations
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:Model now has a total of 26 weak estimators
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-822666:Updating lightgbm model with 1.5 iterations
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:Model now has a total of 28 weak estimators
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-822666:Updating lightgbm model with 1 iterations
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:Model now has a total of 24 weak estimators
# /home/george/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-822666:Updating lightgbm model with 1 iterations
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/george/.local/lib/python3.8/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-822666:Model now has a total of 21 weak estimators
# INFO:lightwood-822666:Started fitting sktime forecaster for array prediction

# %% [markdown]
# ## Predict
#
# Once the predictor has trained, we can use it to generate 6-month forecasts for each of the test set data points:

# %%
forecasts = predictor.predict(test)
# Out:
# INFO:lightwood-822666:Dropping features: []
# INFO:lightwood-822666:Cleaning the data
# INFO:lightwood-822666:Transforming timeseries data
# INFO:lightwood-822666:Featurizing the data
# /home/george/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# INFO:lightwood-822666:The block ICP is now running its explain() method
# INFO:lightwood-822666:The block AccStats is now running its explain() method
# INFO:lightwood-822666:AccStats.explain() has not been implemented, no modifications will be done to the data insights.

# %% [markdown]
# Let's check how a single row might look:

# %%
forecasts.iloc[[10]]
# Out:
#                                            prediction  truth  \
# 10  [69.51483835835057, 67.51167823432463, 65.1680...   51.0
#
#                                           order_Month  \
# 10  [-272746800.0, -270068400.0, -267390000.0, -26...
#
#                               confidence  \
# 10  [0.59, 0.59, 0.59, 0.59, 0.59, 0.59]
#
#                                                 lower  \
# 10  [48.361229501663985, 46.358069377638046, 44.01...
#
#                                                 upper  anomaly
# 10  [90.66844721503716, 88.66528709101122, 86.3216...    False

# %% [markdown]
# You'll note that the point `prediction` has associated `lower` and `upper` bounds that are a function of the estimated `confidence` the model has on its own output. Apart from this, `order_Month` yields the timestamps of each prediction, `truth` lets us know what is the one-step-ahead observed value (if it exists at all). Finally, the `anomaly` tag will let you know if the observed value falls outside of the predicted region.
#
#
# ## Visualizing a forecast
#
# Okay, time series are much easier to appreciate through plots. Let's make one:
#
# NOTE: We will use `matplotlib` to generate a simple plot of these forecasts. If you want to run this notebook locally, you will need to `pip install matplotlib` for the following code to work.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.plot(forecasts['truth'].iloc[-24:], color='green', label='observed series')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['prediction'], color='purple', label='point prediction')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['lower'], color='grey')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['upper'], color='grey')
plt.xlabel('timestep')
plt.ylabel('# sunspots')
plt.title("Forecasted amount of sunspots for the next semester")
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we have gone through how you can train a machine learning model with Lightwood to produce forecasts for a univariate time series task.
#
# There are additional parameters to further customize your timeseries settings and/or prediction insights, so be sure to check the rest of the documentation.
