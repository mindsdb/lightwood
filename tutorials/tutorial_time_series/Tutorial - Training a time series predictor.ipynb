# %% [markdown]
# # Tutorial - Time series forecasting
#
# ## Introduction
#
# Time series are an ubiquitous type of data in all types of processes. Producing forecasts for them can be highly valuable in domains like retail or industrial manufacture, among many others.
#
# Lightwood supports time series forecasting (both univariate and multivariate inputs), handling many of the pain points commonly associated with setting up a manual time series predictive pipeline.
#
# In this tutorial, we will train a lightwood predictor and analyze its forecasts for the task of counting sunspots in monthly intervals.
#
# ## Load data
#
# Let's begin by loading the dataset and looking at it:

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/mindsdb/benchmarks/main/benchmarks/datasets/monthly_sunspots/data.csv")
df
# Out:
#         Month  Sunspots
# 0     1749-01      58.0
# 1     1749-02      62.6
# 2     1749-03      70.0
# 3     1749-04      55.7
# 4     1749-05      85.0
# ...       ...       ...
# 2815  1983-08      71.8
# 2816  1983-09      50.3
# 2817  1983-10      55.8
# 2818  1983-11      33.3
# 2819  1983-12      33.4
#
# [2820 rows x 2 columns]

# %% [markdown]
# This is a very simple dataset. It's got a single column that specifies the month in which the measurement was done, and then in the 'Sunspots' column we have the actual quantity we are interested in forecasting. As such, we can characterize this as a univariate time series problem.
#
# ## Define the predictive task
#
# We will use Lightwood high level methods to state what we want to predict. As this is a time series task (because we want to leverage the notion of time to predict), we need to specify a set of arguments that will activate Lightwood's time series pipeline:

# %%
from lightwood.api.high_level import ProblemDefinition
# Out:
# INFO:lightwood-2415:No torchvision detected, image helpers not supported.
# INFO:lightwood-2415:No torchvision/pillow detected, image encoder not supported

# %%
tss = {'nr_predictions': 6,   # the predictor will learn to forecast what the next semester counts will look like (6 data points at monthly intervals -> 6 months)
       'order_by': ['Month'], # what column is used to order the entire datset
       'window': 12           # how many past values to consider for emitting predictions
      }

pdef = ProblemDefinition.from_dict({'target': 'Sunspots',         # specify the column to forecast
                                    'timeseries_settings': tss    # pass along all time series specific parameters
                                   })

# %% [markdown]
# Now, let's do a very simple train-test split, leaving 10% of the data to check the forecasts that our predictor will produce:

# %%
cutoff = int(len(df)*0.9)

train = df[:cutoff]
test = df[cutoff:]

print(train.shape, test.shape)
# Out:
# (2538, 2) (282, 2)

# %% [markdown]
# ## Generate the predictor object
#
# Now, we can generate code for a machine learning model by using our problem definition and the data:

# %%
from lightwood.api.high_level import (
    json_ai_from_problem,
    code_from_json_ai,
    predictor_from_code
)

json_ai = json_ai_from_problem(df, problem_definition=pdef)
code = code_from_json_ai(json_ai)
predictor = predictor_from_code(code)

# uncomment this to see the generated code:
# print(code)
# Out:
# INFO:lightwood-2415:Dropping features: []
# INFO:lightwood-2415:Analyzing a sample of 2467
# INFO:lightwood-2415:from a total population of 2820, this is equivalent to 87.5% of your data.
# INFO:lightwood-2415:Infering type for: Month
# INFO:lightwood-2415:Column Month has data type date
# INFO:lightwood-2415:Infering type for: Sunspots
# INFO:lightwood-2415:Column Sunspots has data type float
# /home/runner/work/lightwood/lightwood/lightwood/helpers/text.py:242: RuntimeWarning: invalid value encountered in double_scalars
#   randomness_per_index.append(S / np.log(N))
# INFO:lightwood-2415:Starting statistical analysis
# INFO:lightwood-2415:Finished statistical analysis
# INFO:lightwood-2415:Unable to import black formatter, predictor code might be a bit ugly.

# %% [markdown]
# ## Train
#
# Okay, everything is ready now for our predictor to learn based on the training data we will provide.
#
# Internally, lightwood cleans and reshapes the data, featurizes measurements and timestamps, and comes up with a handful of different models that will be evaluated to keep the one that produces the best forecasts.
#
# Let's train the predictor. This should take a couple of minutes, at most:

# %%
predictor.learn(train)
# Out:
# INFO:lightwood-2415:Dropping features: []
# INFO:lightwood-2415:Performing statistical analysis on data
# INFO:lightwood-2415:Starting statistical analysis
# INFO:lightwood-2415:Finished statistical analysis
# INFO:lightwood-2415:Cleaning the data
# INFO:lightwood-2415:Transforming timeseries data
# INFO:lightwood-2415:Using 1 processes to reshape.
# INFO:lightwood-2415:Splitting the data into train/test
# INFO:lightwood-2415:Preparing the encoders
# INFO:lightwood-2415:Encoder prepping dict length of: 1
# INFO:lightwood-2415:Done running for: Sunspots
# INFO:lightwood-2415:time series encoder epoch [1/100000] average_loss = 0.017982035875320435
# INFO:lightwood-2415:time series encoder epoch [2/100000] average_loss = 0.007057315413880891
# INFO:lightwood-2415:time series encoder epoch [3/100000] average_loss = 0.005446755531164059
# INFO:lightwood-2415:time series encoder epoch [4/100000] average_loss = 0.004766821234948581
# INFO:lightwood-2415:time series encoder epoch [5/100000] average_loss = 0.0045627151500114
# INFO:lightwood-2415:time series encoder epoch [6/100000] average_loss = 0.004403072616473597
# INFO:lightwood-2415:time series encoder epoch [7/100000] average_loss = 0.0042669128776640485
# INFO:lightwood-2415:time series encoder epoch [8/100000] average_loss = 0.0042752294218895105
# INFO:lightwood-2415:time series encoder epoch [9/100000] average_loss = 0.004193102781075312
# INFO:lightwood-2415:time series encoder epoch [10/100000] average_loss = 0.0041757172753222145
# INFO:lightwood-2415:time series encoder epoch [11/100000] average_loss = 0.004133630915823834
# INFO:lightwood-2415:time series encoder epoch [12/100000] average_loss = 0.004138153222521633
# INFO:lightwood-2415:time series encoder epoch [13/100000] average_loss = 0.004134404627955315
# INFO:lightwood-2415:time series encoder epoch [14/100000] average_loss = 0.004091523783428239
# INFO:lightwood-2415:time series encoder epoch [15/100000] average_loss = 0.00408442154030875
# INFO:lightwood-2415:time series encoder epoch [16/100000] average_loss = 0.004049514147947215
# INFO:lightwood-2415:time series encoder epoch [17/100000] average_loss = 0.004054148800527569
# INFO:lightwood-2415:time series encoder epoch [18/100000] average_loss = 0.004145103348533243
# INFO:lightwood-2415:time series encoder epoch [19/100000] average_loss = 0.00424002045716588
# INFO:lightwood-2415:time series encoder epoch [20/100000] average_loss = 0.0043278865242171415
# INFO:lightwood-2415:time series encoder epoch [21/100000] average_loss = 0.004299022244279731
# INFO:lightwood-2415:time series encoder epoch [22/100000] average_loss = 0.00409338499326422
# INFO:lightwood-2415:time series encoder epoch [23/100000] average_loss = 0.003939817827553757
# INFO:lightwood-2415:time series encoder epoch [24/100000] average_loss = 0.003994196809945716
# INFO:lightwood-2415:time series encoder epoch [25/100000] average_loss = 0.004009815079735791
# INFO:lightwood-2415:time series encoder epoch [26/100000] average_loss = 0.003876836764937733
# INFO:lightwood-2415:time series encoder epoch [27/100000] average_loss = 0.003990251107725287
# INFO:lightwood-2415:time series encoder epoch [28/100000] average_loss = 0.0037811195996513298
# INFO:lightwood-2415:time series encoder epoch [29/100000] average_loss = 0.003880158327715618
# INFO:lightwood-2415:time series encoder epoch [30/100000] average_loss = 0.004208104179327208
# INFO:lightwood-2415:Featurizing the data
# INFO:lightwood-2415:Training the mixers
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2415:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2415:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2415:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2415:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2415:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2415:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/pytorch_ranger/ranger.py:172: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1025.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# INFO:lightwood-2415:Loss of 0.5610278844833374 with learning rate 0.0001
# INFO:lightwood-2415:Loss of 0.681261420249939 with learning rate 0.00014
# INFO:lightwood-2415:Found learning rate of: 0.0001
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2415:Loss @ epoch 1: 0.6347045302391052
# INFO:lightwood-2415:Loss @ epoch 2: 0.6313408017158508
# INFO:lightwood-2415:Loss @ epoch 3: 0.6272284537553787
# INFO:lightwood-2415:Loss @ epoch 4: 0.6224407106637955
# INFO:lightwood-2415:Loss @ epoch 5: 0.6170893311500549
# INFO:lightwood-2415:Loss @ epoch 6: 0.6112600564956665
# INFO:lightwood-2415:Loss @ epoch 7: 0.6011892557144165
# INFO:lightwood-2415:Loss @ epoch 8: 0.5943790376186371
# INFO:lightwood-2415:Loss @ epoch 9: 0.5873657166957855
# INFO:lightwood-2415:Loss @ epoch 10: 0.5801717042922974
# INFO:lightwood-2415:Loss @ epoch 11: 0.5728811919689178
# INFO:lightwood-2415:Loss @ epoch 12: 0.5655267089605331
# INFO:lightwood-2415:Loss @ epoch 13: 0.5536521375179291
# INFO:lightwood-2415:Loss @ epoch 14: 0.546097457408905
# INFO:lightwood-2415:Loss @ epoch 15: 0.5384721457958221
# INFO:lightwood-2415:Loss @ epoch 16: 0.530864879488945
# INFO:lightwood-2415:Loss @ epoch 17: 0.523259237408638
# INFO:lightwood-2415:Loss @ epoch 18: 0.5156972855329514
# INFO:lightwood-2415:Loss @ epoch 19: 0.5035927593708038
# INFO:lightwood-2415:Loss @ epoch 20: 0.4960074722766876
# INFO:lightwood-2415:Loss @ epoch 21: 0.48843109607696533
# INFO:lightwood-2415:Loss @ epoch 22: 0.48087067902088165
# INFO:lightwood-2415:Loss @ epoch 23: 0.4733206778764725
# INFO:lightwood-2415:Loss @ epoch 24: 0.4658580720424652
# INFO:lightwood-2415:Loss @ epoch 25: 0.45404934883117676
# INFO:lightwood-2415:Loss @ epoch 26: 0.4467405080795288
# INFO:lightwood-2415:Loss @ epoch 27: 0.43950769305229187
# INFO:lightwood-2415:Loss @ epoch 28: 0.4323364719748497
# INFO:lightwood-2415:Loss @ epoch 29: 0.4252518340945244
# INFO:lightwood-2415:Loss @ epoch 30: 0.4183507561683655
# INFO:lightwood-2415:Loss @ epoch 206: 0.18388519436120987
# INFO:lightwood-2415:Loss @ epoch 207: 0.18364369124174118
# INFO:lightwood-2415:Loss @ epoch 208: 0.18366562575101852
# INFO:lightwood-2415:Loss @ epoch 209: 0.18363601714372635
# INFO:lightwood-2415:Loss @ epoch 210: 0.1832796037197113
# INFO:lightwood-2415:Loss @ epoch 211: 0.18306197226047516
# INFO:lightwood-2415:Loss @ epoch 212: 0.18276140838861465
# INFO:lightwood-2415:Loss @ epoch 213: 0.18264444172382355
# INFO:lightwood-2415:Loss @ epoch 214: 0.1827198788523674
# INFO:lightwood-2415:Loss @ epoch 215: 0.1827508509159088
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2415:Loss @ epoch 1: 0.14480429616841403
# INFO:lightwood-2415:Loss @ epoch 2: 0.14202974194830115
# INFO:lightwood-2415:Loss @ epoch 3: 0.14538102393800562
# INFO:lightwood-2415:Loss @ epoch 4: 0.14331997795538468
# INFO:lightwood-2415:Loss @ epoch 5: 0.14361027424985712
# INFO:lightwood-2415:Loss @ epoch 6: 0.14213306118141522
# INFO:lightwood-2415:Loss @ epoch 7: 0.14045868543061343
# INFO:lightwood-2415:Loss @ epoch 8: 0.14106810228391128
# INFO:lightwood-2415:Loss @ epoch 9: 0.14083610068668018
# INFO:lightwood-2415:Loss @ epoch 10: 0.1451535319740122
# INFO:lightwood-2415:Started fitting LGBM models for array prediction
# INFO:lightwood-2415:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2415:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37880 iterations given 4735.121414422989 seconds constraint
# INFO:lightwood-2415:Lightgbm model contains 34 weak estimators
# INFO:lightwood-2415:Updating lightgbm model with 2.0 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:Model now has a total of 36 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2415:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2415:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37880 iterations given 4735.117366552353 seconds constraint
# INFO:lightwood-2415:Lightgbm model contains 21 weak estimators
# INFO:lightwood-2415:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:Model now has a total of 22 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2415:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2415:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37880 iterations given 4735.0481588840485 seconds constraint
# INFO:lightwood-2415:Lightgbm model contains 30 weak estimators
# INFO:lightwood-2415:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:Model now has a total of 31 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2415:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2415:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37881 iterations given 4735.184844255447 seconds constraint
# INFO:lightwood-2415:Lightgbm model contains 23 weak estimators
# INFO:lightwood-2415:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:Model now has a total of 24 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2415:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2415:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37880 iterations given 4735.054775714874 seconds constraint
# INFO:lightwood-2415:Lightgbm model contains 16 weak estimators
# INFO:lightwood-2415:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:Model now has a total of 17 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2415:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2415:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37880 iterations given 4735.074171543121 seconds constraint
# INFO:lightwood-2415:Lightgbm model contains 23 weak estimators
# INFO:lightwood-2415:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:Model now has a total of 24 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = original_target_train
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = original_target_dev
# INFO:lightwood-2415:Started fitting sktime forecaster for array prediction
# INFO:lightwood-2415:Ensembling the mixer
# INFO:lightwood-2415:Mixer: Neural got accuracy: 0.5086722422721424
# INFO:lightwood-2415:Mixer: LightGBMArray got accuracy: 0.4540754785903764
# INFO:lightwood-2415:Mixer: SkTime got accuracy: 0.21481464159207728
# INFO:lightwood-2415:Picked best mixer: Neural
# INFO:lightwood-2415:Analyzing the ensemble of mixers
# INFO:lightwood-2415:The block ICP is now running its analyze() method
# INFO:lightwood-2415:The block AccStats is now running its analyze() method
# INFO:lightwood-2415:Adjustment on validation requested.
# INFO:lightwood-2415:Updating the mixers
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2415:Loss @ epoch 1: 0.1449100859463215
# INFO:lightwood-2415:Loss @ epoch 2: 0.1452150841554006
# INFO:lightwood-2415:Loss @ epoch 3: 0.14531099299589792
# INFO:lightwood-2415:Loss @ epoch 4: 0.1442846084634463
# INFO:lightwood-2415:Loss @ epoch 5: 0.14473456144332886
# INFO:lightwood-2415:Loss @ epoch 6: 0.1438699228068193
# INFO:lightwood-2415:Loss @ epoch 7: 0.14533252889911333
# INFO:lightwood-2415:Updating array of LGBM models...
# INFO:lightwood-2415:Updating lightgbm model with 2.0 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:Model now has a total of 38 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2415:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:Model now has a total of 23 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2415:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:Model now has a total of 32 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2415:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:Model now has a total of 25 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2415:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:Model now has a total of 18 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2415:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2415:Model now has a total of 25 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = original_target_train
# INFO:lightwood-2415:Started fitting sktime forecaster for array prediction

# %% [markdown]
# ## Predict
#
# Once the predictor has trained, we can use it to generate 6-month forecasts for each of the test set data points:

# %%
forecasts = predictor.predict(test)
# Out:
# INFO:lightwood-2415:Dropping features: []
# INFO:lightwood-2415:Cleaning the data
# INFO:lightwood-2415:Transforming timeseries data
# INFO:lightwood-2415:Featurizing the data
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# INFO:lightwood-2415:The block ICP is now running its explain() method
# INFO:lightwood-2415:The block AccStats is now running its explain() method
# INFO:lightwood-2415:AccStats.explain() has not been implemented, no modifications will be done to the data insights.

# %% [markdown]
# Let's check how a single row might look:

# %%
forecasts.iloc[[10]]
# Out:
#     original_index                                         prediction  \
# 10              10  [68.86344884533501, 66.7271392398974, 70.13807...
#
#                                           order_Month  \
# 10  [-271728000.0, -269049600.0, -266371200.0, -26...
#
#                               confidence  \
# 10  [0.65, 0.65, 0.65, 0.65, 0.65, 0.65]
#
#                                                 lower  \
# 10  [55.13739186192469, 50.683470154835916, 52.112...
#
#                                                 upper
# 10  [82.58950582874535, 82.77080832495888, 88.1639...

# %% [markdown]
# You'll note that the point `prediction` has associated `lower` and `upper` bounds that are a function of the estimated `confidence` the model has on its own output. Apart from this, `order_Month` yields the timestamps of each prediction, the `anomaly` tag will let you know if the observed value falls outside of the predicted region.
#
#
# ## Visualizing a forecast
#
# Okay, time series are much easier to appreciate through plots. Let's make one:
#
# NOTE: We will use `matplotlib` to generate a simple plot of these forecasts. If you want to run this notebook locally, you will need to `pip install matplotlib` for the following code to work.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['prediction'], color='purple', label='point prediction')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['lower'], color='grey')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['upper'], color='grey')
plt.xlabel('timestep')
plt.ylabel('# sunspots')
plt.title("Forecasted amount of sunspots for the next semester")
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we have gone through how you can train a machine learning model with Lightwood to produce forecasts for a univariate time series task.
#
# There are additional parameters to further customize your timeseries settings and/or prediction insights, so be sure to check the rest of the documentation.
