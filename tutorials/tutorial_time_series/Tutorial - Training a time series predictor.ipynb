# %% [markdown]
# # Tutorial - Time series forecasting
#
# ## Introduction
#
# Time series are an ubiquitous type of data in all types of processes. Producing forecasts for them can be highly valuable in domains like retail or industrial manufacture, among many others.
#
# Lightwood supports time series forecasting (both univariate and multivariate inputs), handling many of the pain points commonly associated with setting up a manual time series predictive pipeline.
#
# In this tutorial, we will train a lightwood predictor and analyze its forecasts for the task of counting sunspots in monthly intervals.
#
# ## Load data
#
# Let's begin by loading the dataset and looking at it:

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/mindsdb/benchmarks/main/benchmarks/datasets/monthly_sunspots/data.csv")
df
# Out:
#         Month  Sunspots
# 0     1749-01      58.0
# 1     1749-02      62.6
# 2     1749-03      70.0
# 3     1749-04      55.7
# 4     1749-05      85.0
# ...       ...       ...
# 2815  1983-08      71.8
# 2816  1983-09      50.3
# 2817  1983-10      55.8
# 2818  1983-11      33.3
# 2819  1983-12      33.4
#
# [2820 rows x 2 columns]

# %% [markdown]
# This is a very simple dataset. It's got a single column that specifies the month in which the measurement was done, and then in the 'Sunspots' column we have the actual quantity we are interested in forecasting. As such, we can characterize this as a univariate time series problem.
#
# ## Define the predictive task
#
# We will use Lightwood high level methods to state what we want to predict. As this is a time series task (because we want to leverage the notion of time to predict), we need to specify a set of arguments that will activate Lightwood's time series pipeline:

# %%
from lightwood.api.high_level import ProblemDefinition

# %%
tss = {'nr_predictions': 6,   # the predictor will learn to forecast what the next semester counts will look like (6 data points at monthly intervals -> 6 months)
       'order_by': ['Month'], # what column is used to order the entire datset
       'window': 12           # how many past values to consider for emitting predictions
      }

pdef = ProblemDefinition.from_dict({'target': 'Sunspots',         # specify the column to forecast
                                    'timeseries_settings': tss    # pass along all time series specific parameters
                                   })

# %% [markdown]
# Now, let's do a very simple train-test split, leaving 10% of the data to check the forecasts that our predictor will produce:

# %%
cutoff = int(len(df)*0.9)

train = df[:cutoff]
test = df[cutoff:]

print(train.shape, test.shape)
# Out:
# (2538, 2) (282, 2)

# %% [markdown]
# ## Generate the predictor object
#
# Now, we can generate code for a machine learning model by using our problem definition and the data:

# %%
from lightwood.api.high_level import (
    json_ai_from_problem,
    code_from_json_ai,
    predictor_from_code
)

json_ai = json_ai_from_problem(df, problem_definition=pdef)
code = code_from_json_ai(json_ai)
predictor = predictor_from_code(code)

# uncomment this to see the generated code:
# print(code)
# Out:
# INFO:lightwood-2339:Dropping features: []
# INFO:lightwood-2339:Analyzing a sample of 2467
# INFO:lightwood-2339:from a total population of 2820, this is equivalent to 87.5% of your data.
# INFO:lightwood-2339:Infering type for: Month
# INFO:lightwood-2339:Column Month has data type date
# INFO:lightwood-2339:Infering type for: Sunspots
# INFO:lightwood-2339:Column Sunspots has data type float
# /home/runner/work/lightwood/lightwood/lightwood/helpers/text.py:242: RuntimeWarning: invalid value encountered in double_scalars
#   randomness_per_index.append(S / np.log(N))
# INFO:lightwood-2339:Starting statistical analysis
# INFO:lightwood-2339:Finished statistical analysis
# INFO:lightwood-2339:Unable to import black formatter, predictor code might be a bit ugly.

# %% [markdown]
# ## Train
#
# Okay, everything is ready now for our predictor to learn based on the training data we will provide.
#
# Internally, lightwood cleans and reshapes the data, featurizes measurements and timestamps, and comes up with a handful of different models that will be evaluated to keep the one that produces the best forecasts.
#
# Let's train the predictor. This should take a couple of minutes, at most:

# %%
predictor.learn(train)
# Out:
# INFO:lightwood-2339:Dropping features: []
# INFO:lightwood-2339:Performing statistical analysis on data
# INFO:lightwood-2339:Starting statistical analysis
# INFO:lightwood-2339:Finished statistical analysis
# INFO:lightwood-2339:Cleaning the data
# INFO:lightwood-2339:Transforming timeseries data
# INFO:lightwood-2339:Using 1 processes to reshape.
# INFO:lightwood-2339:Splitting the data into train/test
# INFO:lightwood-2339:Preparing the encoders
# INFO:lightwood-2339:Encoder prepping dict length of: 1
# INFO:lightwood-2339:Done running for: Sunspots
# INFO:lightwood-2339:time series encoder epoch [1/100000] average_loss = 0.018020971086057668
# INFO:lightwood-2339:time series encoder epoch [2/100000] average_loss = 0.007069677467563791
# INFO:lightwood-2339:time series encoder epoch [3/100000] average_loss = 0.005457657426530304
# INFO:lightwood-2339:time series encoder epoch [4/100000] average_loss = 0.004775775242605038
# INFO:lightwood-2339:time series encoder epoch [5/100000] average_loss = 0.004572796580978735
# INFO:lightwood-2339:time series encoder epoch [6/100000] average_loss = 0.00441276778668466
# INFO:lightwood-2339:time series encoder epoch [7/100000] average_loss = 0.004275715602181783
# INFO:lightwood-2339:time series encoder epoch [8/100000] average_loss = 0.0042840515432152745
# INFO:lightwood-2339:time series encoder epoch [9/100000] average_loss = 0.004201709047227954
# INFO:lightwood-2339:time series encoder epoch [10/100000] average_loss = 0.004184293584794316
# INFO:lightwood-2339:time series encoder epoch [11/100000] average_loss = 0.004141998793169719
# INFO:lightwood-2339:time series encoder epoch [12/100000] average_loss = 0.0041463537245478846
# INFO:lightwood-2339:time series encoder epoch [13/100000] average_loss = 0.004142978385960444
# INFO:lightwood-2339:time series encoder epoch [14/100000] average_loss = 0.004100212877180661
# INFO:lightwood-2339:time series encoder epoch [15/100000] average_loss = 0.004092652371914149
# INFO:lightwood-2339:time series encoder epoch [16/100000] average_loss = 0.004057805650116007
# INFO:lightwood-2339:time series encoder epoch [17/100000] average_loss = 0.004062035879894221
# INFO:lightwood-2339:time series encoder epoch [18/100000] average_loss = 0.004152227096674787
# INFO:lightwood-2339:time series encoder epoch [19/100000] average_loss = 0.004247726134534152
# INFO:lightwood-2339:time series encoder epoch [20/100000] average_loss = 0.004339672484487857
# INFO:lightwood-2339:time series encoder epoch [21/100000] average_loss = 0.004319320937529527
# INFO:lightwood-2339:time series encoder epoch [22/100000] average_loss = 0.004116020975744792
# INFO:lightwood-2339:time series encoder epoch [23/100000] average_loss = 0.003954215000574397
# INFO:lightwood-2339:time series encoder epoch [24/100000] average_loss = 0.004007998084017665
# INFO:lightwood-2339:time series encoder epoch [25/100000] average_loss = 0.004018661339275666
# INFO:lightwood-2339:time series encoder epoch [26/100000] average_loss = 0.003884968016429029
# INFO:lightwood-2339:time series encoder epoch [27/100000] average_loss = 0.003999911860030385
# INFO:lightwood-2339:time series encoder epoch [28/100000] average_loss = 0.003799697608997969
# INFO:lightwood-2339:time series encoder epoch [29/100000] average_loss = 0.0038939773801022737
# INFO:lightwood-2339:time series encoder epoch [30/100000] average_loss = 0.004215907349613687
# INFO:lightwood-2339:Featurizing the data
# INFO:lightwood-2339:Training the mixers
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2339:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2339:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2339:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2339:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2339:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2339:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/pytorch_ranger/ranger.py:172: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1025.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# INFO:lightwood-2339:Loss of 0.5622269511222839 with learning rate 0.0001
# INFO:lightwood-2339:Loss of 0.6833630204200745 with learning rate 0.00014
# INFO:lightwood-2339:Found learning rate of: 0.0001
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2339:Loss @ epoch 1: 0.6138376146554947
# INFO:lightwood-2339:Loss @ epoch 2: 0.6105348467826843
# INFO:lightwood-2339:Loss @ epoch 3: 0.6064981073141098
# INFO:lightwood-2339:Loss @ epoch 4: 0.6018044501543045
# INFO:lightwood-2339:Loss @ epoch 5: 0.5965517610311508
# INFO:lightwood-2339:Loss @ epoch 6: 0.5908339023590088
# INFO:lightwood-2339:Loss @ epoch 7: 0.5809542685747147
# INFO:lightwood-2339:Loss @ epoch 8: 0.574290320277214
# INFO:lightwood-2339:Loss @ epoch 9: 0.5674483180046082
# INFO:lightwood-2339:Loss @ epoch 10: 0.5604291409254074
# INFO:lightwood-2339:Loss @ epoch 11: 0.5533463954925537
# INFO:lightwood-2339:Loss @ epoch 12: 0.5462019294500351
# INFO:lightwood-2339:Loss @ epoch 13: 0.5346565693616867
# INFO:lightwood-2339:Loss @ epoch 14: 0.5273211151361465
# INFO:lightwood-2339:Loss @ epoch 15: 0.5199102163314819
# INFO:lightwood-2339:Loss @ epoch 16: 0.5125169306993484
# INFO:lightwood-2339:Loss @ epoch 17: 0.5051442086696625
# INFO:lightwood-2339:Loss @ epoch 18: 0.4978124499320984
# INFO:lightwood-2339:Loss @ epoch 19: 0.4861011803150177
# INFO:lightwood-2339:Loss @ epoch 20: 0.47875796258449554
# INFO:lightwood-2339:Loss @ epoch 21: 0.47143977880477905
# INFO:lightwood-2339:Loss @ epoch 22: 0.4641183465719223
# INFO:lightwood-2339:Loss @ epoch 23: 0.4568095803260803
# INFO:lightwood-2339:Loss @ epoch 24: 0.44960062205791473
# INFO:lightwood-2339:Loss @ epoch 25: 0.4382363557815552
# INFO:lightwood-2339:Loss @ epoch 26: 0.4312201291322708
# INFO:lightwood-2339:Loss @ epoch 27: 0.4242926687002182
# INFO:lightwood-2339:Loss @ epoch 28: 0.41744616627693176
# INFO:lightwood-2339:Loss @ epoch 29: 0.4107144996523857
# INFO:lightwood-2339:Loss @ epoch 30: 0.4041539877653122
# INFO:lightwood-2339:Loss @ epoch 31: 0.3938535451889038
# INFO:lightwood-2339:Loss @ epoch 32: 0.38749779760837555
# INFO:lightwood-2339:Loss @ epoch 33: 0.38120926171541214
# INFO:lightwood-2339:Loss @ epoch 34: 0.3750137686729431
# INFO:lightwood-2339:Loss @ epoch 35: 0.36889876425266266
# INFO:lightwood-2339:Loss @ epoch 36: 0.36295389384031296
# INFO:lightwood-2339:Loss @ epoch 227: 0.17789098620414734
# INFO:lightwood-2339:Loss @ epoch 228: 0.17760300636291504
# INFO:lightwood-2339:Loss @ epoch 229: 0.17734716087579727
# INFO:lightwood-2339:Loss @ epoch 230: 0.1771099492907524
# INFO:lightwood-2339:Loss @ epoch 231: 0.17712920159101486
# INFO:lightwood-2339:Loss @ epoch 232: 0.17696191370487213
# INFO:lightwood-2339:Loss @ epoch 233: 0.17677705734968185
# INFO:lightwood-2339:Loss @ epoch 234: 0.17650309205055237
# INFO:lightwood-2339:Loss @ epoch 235: 0.17628156393766403
# INFO:lightwood-2339:Loss @ epoch 236: 0.17613593488931656
# INFO:lightwood-2339:Loss @ epoch 237: 0.17601042240858078
# INFO:lightwood-2339:Loss @ epoch 238: 0.17587747424840927
# INFO:lightwood-2339:Loss @ epoch 239: 0.1758756786584854
# INFO:lightwood-2339:Loss @ epoch 240: 0.1754853054881096
# INFO:lightwood-2339:Loss @ epoch 241: 0.17539803683757782
# INFO:lightwood-2339:Loss @ epoch 242: 0.1751212328672409
# INFO:lightwood-2339:Loss @ epoch 243: 0.17505298554897308
# INFO:lightwood-2339:Loss @ epoch 244: 0.1752009391784668
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2339:Loss @ epoch 1: 0.14125843346118927
# INFO:lightwood-2339:Loss @ epoch 2: 0.14060104435140436
# INFO:lightwood-2339:Loss @ epoch 3: 0.14482458206740292
# INFO:lightwood-2339:Loss @ epoch 4: 0.13989096067168497
# INFO:lightwood-2339:Loss @ epoch 5: 0.144583061337471
# INFO:lightwood-2339:Started fitting LGBM models for array prediction
# INFO:lightwood-2339:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2339:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2339:Lightgbm model contains 29 weak estimators
# INFO:lightwood-2339:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 30 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2339:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2339:Lightgbm model contains 27 weak estimators
# INFO:lightwood-2339:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 28 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2339:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2339:Lightgbm model contains 24 weak estimators
# INFO:lightwood-2339:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 25 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2339:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2339:Lightgbm model contains 27 weak estimators
# INFO:lightwood-2339:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 28 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2339:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2339:Lightgbm model contains 15 weak estimators
# INFO:lightwood-2339:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 16 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2339:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2339:Lightgbm model contains 20 weak estimators
# INFO:lightwood-2339:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 21 weak estimators
# INFO:lightwood-2339:Started fitting sktime forecaster for array prediction
# INFO:lightwood-2339:Ensembling the mixer
# INFO:lightwood-2339:Mixer: Neural got accuracy: 0.5184600040804543
# INFO:lightwood-2339:Mixer: LightGBMArray got accuracy: 0.4503817941851636
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/pmdarima/arima/arima.py:692: UserWarning: As of version 1.5.0 'typ' is no longer a valid arg for predict. In future versions this will raise a TypeError.
#   warnings.warn("As of version 1.5.0 'typ' is no longer a valid "
# INFO:lightwood-2339:Mixer: SkTime got accuracy: 0.202543582497771
# INFO:lightwood-2339:Picked best mixer: Neural
# INFO:lightwood-2339:Analyzing the ensemble of mixers
# INFO:lightwood-2339:The block ICP is now running its analyze() method
# INFO:lightwood-2339:The block AccStats is now running its analyze() method
# INFO:lightwood-2339:Adjustment on validation requested.
# INFO:lightwood-2339:Updating the mixers
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2339:Loss @ epoch 1: 0.14247656737764677
# INFO:lightwood-2339:Loss @ epoch 2: 0.1433888922135035
# INFO:lightwood-2339:Loss @ epoch 3: 0.1414048634469509
# INFO:lightwood-2339:Loss @ epoch 4: 0.14158166448275247
# INFO:lightwood-2339:Loss @ epoch 5: 0.14045598295827708
# INFO:lightwood-2339:Loss @ epoch 6: 0.14084187460442385
# INFO:lightwood-2339:Loss @ epoch 7: 0.14226563771565756
# INFO:lightwood-2339:Updating array of LGBM models...
# INFO:lightwood-2339:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 31 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 29 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 26 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 29 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 17 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 22 weak estimators
# INFO:lightwood-2339:Started fitting sktime forecaster for array prediction

# %% [markdown]
# ## Predict
#
# Once the predictor has trained, we can use it to generate 6-month forecasts for each of the test set data points:

# %%
forecasts = predictor.predict(test)
# Out:
# INFO:lightwood-2339:Dropping features: []
# INFO:lightwood-2339:Cleaning the data
# INFO:lightwood-2339:Transforming timeseries data
# INFO:lightwood-2339:Featurizing the data
# INFO:lightwood-2339:The block ICP is now running its explain() method
# INFO:lightwood-2339:The block AccStats is now running its explain() method
# INFO:lightwood-2339:AccStats.explain() has not been implemented, no modifications will be done to the data insights.

# %% [markdown]
# Let's check how a single row might look:

# %%
forecasts.iloc[[10]]
# Out:
#                                            prediction  \
# 10  [72.0625222970787, 70.12127652872329, 74.80875...
#
#                                           order_Month  \
# 10  [-271728000.0, -269049600.0, -266371200.0, -26...
#
#                               confidence  \
# 10  [0.68, 0.68, 0.68, 0.68, 0.68, 0.68]
#
#                                                 lower  \
# 10  [51.091385546532535, 49.15013977817712, 53.837...
#
#                                                 upper
# 10  [93.03365904762487, 91.09241327926945, 95.7798...

# %% [markdown]
# You'll note that the point `prediction` has associated `lower` and `upper` bounds that are a function of the estimated `confidence` the model has on its own output. Apart from this, `order_Month` yields the timestamps of each prediction, the `anomaly` tag will let you know if the observed value falls outside of the predicted region.
#
#
# ## Visualizing a forecast
#
# Okay, time series are much easier to appreciate through plots. Let's make one:
#
# NOTE: We will use `matplotlib` to generate a simple plot of these forecasts. If you want to run this notebook locally, you will need to `pip install matplotlib` for the following code to work.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['prediction'], color='purple', label='point prediction')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['lower'], color='grey')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['upper'], color='grey')
plt.xlabel('timestep')
plt.ylabel('# sunspots')
plt.title("Forecasted amount of sunspots for the next semester")
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we have gone through how you can train a machine learning model with Lightwood to produce forecasts for a univariate time series task.
#
# There are additional parameters to further customize your timeseries settings and/or prediction insights, so be sure to check the rest of the documentation.
