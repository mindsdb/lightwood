# %% [markdown]
# # Tutorial - Time series forecasting
#
# ## Introduction
#
# Time series are an ubiquitous type of data in all types of processes. Producing forecasts for them can be highly valuable in domains like retail or industrial manufacture, among many others.
#
# Lightwood supports time series forecasting (both univariate and multivariate inputs), handling many of the pain points commonly associated with setting up a manual time series predictive pipeline.
#
# In this tutorial, we will train a lightwood predictor and analyze its forecasts for the task of counting sunspots in monthly intervals.
#
# ## Load data
#
# Let's begin by loading the dataset and looking at it:

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/mindsdb/benchmarks/main/benchmarks/datasets/monthly_sunspots/data.csv")
df
# Out:
#         Month  Sunspots
# 0     1749-01      58.0
# 1     1749-02      62.6
# 2     1749-03      70.0
# 3     1749-04      55.7
# 4     1749-05      85.0
# ...       ...       ...
# 2815  1983-08      71.8
# 2816  1983-09      50.3
# 2817  1983-10      55.8
# 2818  1983-11      33.3
# 2819  1983-12      33.4
#
# [2820 rows x 2 columns]

# %% [markdown]
# This is a very simple dataset. It's got a single column that specifies the month in which the measurement was done, and then in the 'Sunspots' column we have the actual quantity we are interested in forecasting. As such, we can characterize this as a univariate time series problem.
#
# ## Define the predictive task
#
# We will use Lightwood high level methods to state what we want to predict. As this is a time series task (because we want to leverage the notion of time to predict), we need to specify a set of arguments that will activate Lightwood's time series pipeline:

# %%
from lightwood.api.high_level import ProblemDefinition
# Out:
# [nltk_data] Downloading package punkt to /home/runner/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
tss = {'nr_predictions': 6,   # the predictor will learn to forecast what the next semester counts will look like (6 data points at monthly intervals -> 6 months)
       'order_by': ['Month'], # what column is used to order the entire datset
       'window': 12           # how many past values to consider for emitting predictions
      }

pdef = ProblemDefinition.from_dict({'target': 'Sunspots',         # specify the column to forecast
                                    'timeseries_settings': tss    # pass along all time series specific parameters
                                   })

# %% [markdown]
# Now, let's do a very simple train-test split, leaving 10% of the data to check the forecasts that our predictor will produce:

# %%
cutoff = int(len(df)*0.9)

train = df[:cutoff]
test = df[cutoff:]

print(train.shape, test.shape)
# Out:
# (2538, 2) (282, 2)

# %% [markdown]
# ## Generate the predictor object
#
# Now, we can generate code for a machine learning model by using our problem definition and the data:

# %%
from lightwood.api.high_level import (
    json_ai_from_problem,
    code_from_json_ai,
    predictor_from_code
)

json_ai = json_ai_from_problem(df, problem_definition=pdef)
code = code_from_json_ai(json_ai)
predictor = predictor_from_code(code)

# uncomment this to see the generated code:
# print(code)
# Out:
# INFO:lightwood-1980:Dropping features: []
# INFO:lightwood-1980:Analyzing a sample of 2467
# INFO:lightwood-1980:from a total population of 2820, this is equivalent to 87.5% of your data.
# INFO:lightwood-1980:Infering type for: Month
# INFO:lightwood-1980:Column Month has data type date
# INFO:lightwood-1980:Infering type for: Sunspots
# INFO:lightwood-1980:Column Sunspots has data type float
# /home/runner/work/lightwood/lightwood/lightwood/helpers/text.py:236: RuntimeWarning: invalid value encountered in double_scalars
#   randomness_per_index.append(S / np.log(N))
# INFO:lightwood-1980:Starting statistical analysis
# INFO:lightwood-1980:Finished statistical analysis
# INFO:lightwood-1980:Unable to import black formatter, predictor code might be a bit ugly.

# %% [markdown]
# ## Train
#
# Okay, everything is ready now for our predictor to learn based on the training data we will provide.
#
# Internally, lightwood cleans and reshapes the data, featurizes measurements and timestamps, and comes up with a handful of different models that will be evaluated to keep the one that produces the best forecasts.
#
# Let's train the predictor. This should take a couple of minutes, at most:

# %%
predictor.learn(train)
# Out:
# INFO:lightwood-1980:Dropping features: []
# INFO:lightwood-1980:Performing statistical analysis on data
# INFO:lightwood-1980:Starting statistical analysis
# INFO:lightwood-1980:Finished statistical analysis
# INFO:lightwood-1980:Cleaning the data
# INFO:lightwood-1980:Transforming timeseries data
# INFO:lightwood-1980:Using 1 processes to reshape.
# INFO:lightwood-1980:Splitting the data into train/test
# INFO:lightwood-1980:Preparing the encoders
# INFO:lightwood-1980:Encoder prepping dict length of: 1
# INFO:lightwood-1980:Done running for: Sunspots
# INFO:lightwood-1980:time series encoder epoch [1/100000] average_loss = 0.018331727630059517
# INFO:lightwood-1980:time series encoder epoch [2/100000] average_loss = 0.007308861256273445
# INFO:lightwood-1980:time series encoder epoch [3/100000] average_loss = 0.0055975783493708185
# INFO:lightwood-1980:time series encoder epoch [4/100000] average_loss = 0.0048074403736035835
# INFO:lightwood-1980:time series encoder epoch [5/100000] average_loss = 0.004469920428712517
# INFO:lightwood-1980:time series encoder epoch [6/100000] average_loss = 0.004401022663970117
# INFO:lightwood-1980:time series encoder epoch [7/100000] average_loss = 0.0042478864838439885
# INFO:lightwood-1980:time series encoder epoch [8/100000] average_loss = 0.004295934078305266
# INFO:lightwood-1980:time series encoder epoch [9/100000] average_loss = 0.004215001929167228
# INFO:lightwood-1980:time series encoder epoch [10/100000] average_loss = 0.004205311218234937
# INFO:lightwood-1980:time series encoder epoch [11/100000] average_loss = 0.0041679621998183085
# INFO:lightwood-1980:time series encoder epoch [12/100000] average_loss = 0.00416371502233943
# INFO:lightwood-1980:time series encoder epoch [13/100000] average_loss = 0.004155009658046854
# INFO:lightwood-1980:time series encoder epoch [14/100000] average_loss = 0.0041195882575038026
# INFO:lightwood-1980:time series encoder epoch [15/100000] average_loss = 0.004109016213829238
# INFO:lightwood-1980:time series encoder epoch [16/100000] average_loss = 0.004079995107211372
# INFO:lightwood-1980:time series encoder epoch [17/100000] average_loss = 0.004067434245633054
# INFO:lightwood-1980:time series encoder epoch [18/100000] average_loss = 0.004076994082654658
# INFO:lightwood-1980:time series encoder epoch [19/100000] average_loss = 0.004073939599610044
# INFO:lightwood-1980:time series encoder epoch [20/100000] average_loss = 0.004054778445546383
# INFO:lightwood-1980:time series encoder epoch [21/100000] average_loss = 0.003996188047424959
# INFO:lightwood-1980:time series encoder epoch [22/100000] average_loss = 0.0038654202429439584
# INFO:lightwood-1980:time series encoder epoch [23/100000] average_loss = 0.0038379723694095384
# INFO:lightwood-1980:time series encoder epoch [24/100000] average_loss = 0.00419188735776954
# INFO:lightwood-1980:time series encoder epoch [25/100000] average_loss = 0.003941598065122276
# INFO:lightwood-1980:time series encoder epoch [26/100000] average_loss = 0.003925148059318546
# INFO:lightwood-1980:time series encoder epoch [27/100000] average_loss = 0.003945235609223624
# INFO:lightwood-1980:time series encoder epoch [28/100000] average_loss = 0.0038574267343870114
# INFO:lightwood-1980:time series encoder epoch [29/100000] average_loss = 0.004085370575246606
# INFO:lightwood-1980:time series encoder epoch [30/100000] average_loss = 0.003909675109381213
# INFO:lightwood-1980:time series encoder epoch [31/100000] average_loss = 0.003918856722370163
# INFO:lightwood-1980:time series encoder epoch [32/100000] average_loss = 0.003947360100271201
# INFO:lightwood-1980:time series encoder epoch [33/100000] average_loss = 0.003898238079126282
# INFO:lightwood-1980:time series encoder epoch [34/100000] average_loss = 0.004050385499534088
# INFO:lightwood-1980:time series encoder epoch [35/100000] average_loss = 0.0038676341540356276
# INFO:lightwood-1980:time series encoder epoch [36/100000] average_loss = 0.003984114667625478
# INFO:lightwood-1980:time series encoder epoch [37/100000] average_loss = 0.0038277534682167992
# INFO:lightwood-1980:time series encoder epoch [38/100000] average_loss = 0.003739938264146297
# INFO:lightwood-1980:time series encoder epoch [39/100000] average_loss = 0.003687693825307882
# INFO:lightwood-1980:time series encoder epoch [40/100000] average_loss = 0.0035912523723684313
# INFO:lightwood-1980:time series encoder epoch [41/100000] average_loss = 0.00368940992384639
# INFO:lightwood-1980:time series encoder epoch [42/100000] average_loss = 0.003488364790865809
# INFO:lightwood-1980:time series encoder epoch [43/100000] average_loss = 0.003390322708675557
# INFO:lightwood-1980:time series encoder epoch [44/100000] average_loss = 0.003680342380913688
# INFO:lightwood-1980:Featurizing the data
# INFO:lightwood-1980:Training the mixers
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-1980:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-1980:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-1980:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-1980:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-1980:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-1980:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/pytorch_ranger/ranger.py:172: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1025.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# INFO:lightwood-1980:Loss of 0.6578899621963501 with learning rate 0.0001
# INFO:lightwood-1980:Loss of 0.8831674456596375 with learning rate 0.00014
# INFO:lightwood-1980:Found learning rate of: 0.0001
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-1980:Loss @ epoch 1: 0.794191300868988
# INFO:lightwood-1980:Loss @ epoch 2: 0.7909130454063416
# INFO:lightwood-1980:Loss @ epoch 3: 0.7869049608707428
# INFO:lightwood-1980:Loss @ epoch 4: 0.7822314202785492
# INFO:lightwood-1980:Loss @ epoch 5: 0.7769820690155029
# INFO:lightwood-1980:Loss @ epoch 6: 0.7712302207946777
# INFO:lightwood-1980:Loss @ epoch 7: 0.761167973279953
# INFO:lightwood-1980:Loss @ epoch 8: 0.754252165555954
# INFO:lightwood-1980:Loss @ epoch 9: 0.7469930350780487
# INFO:lightwood-1980:Loss @ epoch 10: 0.7394144833087921
# INFO:lightwood-1980:Loss @ epoch 11: 0.7315614819526672
# INFO:lightwood-1980:Loss @ epoch 12: 0.7234623432159424
# INFO:lightwood-1980:Loss @ epoch 13: 0.7099866271018982
# INFO:lightwood-1980:Loss @ epoch 14: 0.7011381387710571
# INFO:lightwood-1980:Loss @ epoch 147: 0.209298774600029
# INFO:lightwood-1980:Loss @ epoch 148: 0.20911656320095062
# INFO:lightwood-1980:Loss @ epoch 149: 0.20897478610277176
# INFO:lightwood-1980:Loss @ epoch 150: 0.20879299938678741
# INFO:lightwood-1980:Loss @ epoch 151: 0.20846642553806305
# INFO:lightwood-1980:Loss @ epoch 152: 0.20827485620975494
# INFO:lightwood-1980:Loss @ epoch 153: 0.2080850601196289
# INFO:lightwood-1980:Loss @ epoch 154: 0.20789597183465958
# INFO:lightwood-1980:Loss @ epoch 155: 0.20774491131305695
# INFO:lightwood-1980:Loss @ epoch 156: 0.20758163183927536
# INFO:lightwood-1980:Loss @ epoch 157: 0.20725174993276596
# INFO:lightwood-1980:Loss @ epoch 158: 0.20706258714199066
# INFO:lightwood-1980:Loss @ epoch 159: 0.2068798989057541
# INFO:lightwood-1980:Loss @ epoch 160: 0.20668694376945496
# INFO:lightwood-1980:Loss @ epoch 161: 0.20653291046619415
# INFO:lightwood-1980:Loss @ epoch 162: 0.20636767148971558
# INFO:lightwood-1980:Loss @ epoch 163: 0.20606160163879395
# INFO:lightwood-1980:Loss @ epoch 164: 0.20588334649801254
# INFO:lightwood-1980:Loss @ epoch 165: 0.2056882381439209
# INFO:lightwood-1980:Loss @ epoch 166: 0.2055094838142395
# INFO:lightwood-1980:Loss @ epoch 167: 0.20535139739513397
# INFO:lightwood-1980:Loss @ epoch 168: 0.20519304275512695
# INFO:lightwood-1980:Loss @ epoch 169: 0.2048865482211113
# INFO:lightwood-1980:Loss @ epoch 170: 0.2046995535492897
# INFO:lightwood-1980:Loss @ epoch 171: 0.2045084908604622
# INFO:lightwood-1980:Loss @ epoch 172: 0.20432154089212418
# INFO:lightwood-1980:Loss @ epoch 173: 0.20416680723428726
# INFO:lightwood-1980:Loss @ epoch 174: 0.2039988413453102
# INFO:lightwood-1980:Loss @ epoch 175: 0.20368211716413498
# INFO:lightwood-1980:Loss @ epoch 176: 0.20350707322359085
# INFO:lightwood-1980:Loss @ epoch 177: 0.20333301275968552
# INFO:lightwood-1980:Loss @ epoch 178: 0.20314346998929977
# INFO:lightwood-1980:Loss @ epoch 179: 0.20298714935779572
# INFO:lightwood-1980:Loss @ epoch 180: 0.20281530916690826
# INFO:lightwood-1980:Loss @ epoch 181: 0.20249812304973602
# INFO:lightwood-1980:Loss @ epoch 182: 0.20232246071100235
# INFO:lightwood-1980:Loss @ epoch 183: 0.20212818682193756
# INFO:lightwood-1980:Loss @ epoch 184: 0.20195268094539642
# INFO:lightwood-1980:Loss @ epoch 185: 0.201801098883152
# INFO:lightwood-1980:Loss @ epoch 186: 0.20162908732891083
# INFO:lightwood-1980:Loss @ epoch 187: 0.2013242170214653
# INFO:lightwood-1980:Loss @ epoch 188: 0.20115947723388672
# INFO:lightwood-1980:Loss @ epoch 189: 0.20099885761737823
# INFO:lightwood-1980:Loss @ epoch 190: 0.20083379745483398
# INFO:lightwood-1980:Loss @ epoch 191: 0.20069324225187302
# INFO:lightwood-1980:Loss @ epoch 192: 0.2004924789071083
# INFO:lightwood-1980:Loss @ epoch 193: 0.2001749351620674
# INFO:lightwood-1980:Loss @ epoch 194: 0.1999947801232338
# INFO:lightwood-1980:Loss @ epoch 195: 0.19982508569955826
# INFO:lightwood-1980:Loss @ epoch 196: 0.19977394491434097
# INFO:lightwood-1980:Loss @ epoch 197: 0.19956737011671066
# INFO:lightwood-1980:Loss @ epoch 198: 0.19928598403930664
# INFO:lightwood-1980:Loss @ epoch 199: 0.19893600791692734
# INFO:lightwood-1980:Loss @ epoch 200: 0.1987873688340187
# INFO:lightwood-1980:Loss @ epoch 201: 0.19861424714326859
# INFO:lightwood-1980:Loss @ epoch 202: 0.1985575407743454
# INFO:lightwood-1980:Loss @ epoch 203: 0.19840071350336075
# INFO:lightwood-1980:Loss @ epoch 204: 0.19814734905958176
# INFO:lightwood-1980:Loss @ epoch 205: 0.19774387031793594
# INFO:lightwood-1980:Loss @ epoch 206: 0.19752704352140427
# INFO:lightwood-1980:Loss @ epoch 207: 0.19736991077661514
# INFO:lightwood-1980:Loss @ epoch 208: 0.19727404415607452
# INFO:lightwood-1980:Loss @ epoch 209: 0.19707010686397552
# INFO:lightwood-1980:Loss @ epoch 210: 0.19685098528862
# INFO:lightwood-1980:Loss @ epoch 211: 0.19653305411338806
# INFO:lightwood-1980:Loss @ epoch 212: 0.1963544562458992
# INFO:lightwood-1980:Loss @ epoch 213: 0.19621500372886658
# INFO:lightwood-1980:Loss @ epoch 214: 0.19616617262363434
# INFO:lightwood-1980:Loss @ epoch 215: 0.19597969204187393
# INFO:lightwood-1980:Loss @ epoch 216: 0.19572121649980545
# INFO:lightwood-1980:Loss @ epoch 217: 0.19530202448368073
# INFO:lightwood-1980:Loss @ epoch 218: 0.1951240375638008
# INFO:lightwood-1980:Loss @ epoch 219: 0.19497662037611008
# INFO:lightwood-1980:Loss @ epoch 220: 0.19492504745721817
# INFO:lightwood-1980:Loss @ epoch 221: 0.1947094053030014
# INFO:lightwood-1980:Loss @ epoch 222: 0.19440265744924545
# INFO:lightwood-1980:Loss @ epoch 223: 0.1940622553229332
# INFO:lightwood-1980:Loss @ epoch 224: 0.1939077228307724
# INFO:lightwood-1980:Loss @ epoch 225: 0.19378679245710373
# INFO:lightwood-1980:Loss @ epoch 226: 0.19384750723838806
# INFO:lightwood-1980:Loss @ epoch 227: 0.19356106221675873
# INFO:lightwood-1980:Loss @ epoch 228: 0.19324278831481934
# INFO:lightwood-1980:Loss @ epoch 229: 0.19286376237869263
# INFO:lightwood-1980:Loss @ epoch 230: 0.19265923649072647
# INFO:lightwood-1980:Loss @ epoch 231: 0.19262174516916275
# INFO:lightwood-1980:Loss @ epoch 232: 0.19268358498811722
# INFO:lightwood-1980:Loss @ epoch 233: 0.1922917515039444
# INFO:lightwood-1980:Loss @ epoch 234: 0.19198618084192276
# INFO:lightwood-1980:Loss @ epoch 235: 0.1916928067803383
# INFO:lightwood-1980:Loss @ epoch 236: 0.19152288883924484
# INFO:lightwood-1980:Loss @ epoch 237: 0.1914568841457367
# INFO:lightwood-1980:Loss @ epoch 238: 0.19140945374965668
# INFO:lightwood-1980:Loss @ epoch 239: 0.19116279482841492
# INFO:lightwood-1980:Loss @ epoch 240: 0.19087738543748856
# INFO:lightwood-1980:Loss @ epoch 241: 0.19053449481725693
# INFO:lightwood-1980:Loss @ epoch 242: 0.19033793359994888
# INFO:lightwood-1980:Loss @ epoch 243: 0.19028359651565552
# INFO:lightwood-1980:Loss @ epoch 244: 0.19025321304798126
# INFO:lightwood-1980:Loss @ epoch 245: 0.1899886354804039
# INFO:lightwood-1980:Loss @ epoch 246: 0.18969335407018661
# INFO:lightwood-1980:Loss @ epoch 247: 0.1894759088754654
# INFO:lightwood-1980:Loss @ epoch 248: 0.189275324344635
# INFO:lightwood-1980:Loss @ epoch 249: 0.18928217142820358
# INFO:lightwood-1980:Loss @ epoch 250: 0.189436636865139
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-1980:Loss @ epoch 1: 0.1539161286570809
# INFO:lightwood-1980:Loss @ epoch 2: 0.152943417429924
# INFO:lightwood-1980:Loss @ epoch 3: 0.15367839553139426
# INFO:lightwood-1980:Loss @ epoch 4: 0.14876615391536194
# INFO:lightwood-1980:Loss @ epoch 5: 0.1505670344287699
# INFO:lightwood-1980:Loss @ epoch 6: 0.14930834824388678
# INFO:lightwood-1980:Loss @ epoch 7: 0.15017100220376794
# INFO:lightwood-1980:Started fitting LGBM models for array prediction
# INFO:lightwood-1980:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-1980:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-1980:Lightgbm model contains 25 weak estimators
# INFO:lightwood-1980:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:Model now has a total of 26 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-1980:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-1980:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-1980:Lightgbm model contains 21 weak estimators
# INFO:lightwood-1980:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:Model now has a total of 22 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-1980:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-1980:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-1980:Lightgbm model contains 18 weak estimators
# INFO:lightwood-1980:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:Model now has a total of 19 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-1980:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-1980:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-1980:Lightgbm model contains 18 weak estimators
# INFO:lightwood-1980:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:Model now has a total of 19 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-1980:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-1980:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-1980:Lightgbm model contains 18 weak estimators
# INFO:lightwood-1980:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:Model now has a total of 19 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-1980:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-1980:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-1980:Lightgbm model contains 20 weak estimators
# INFO:lightwood-1980:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:Model now has a total of 21 weak estimators
# INFO:lightwood-1980:Started fitting sktime forecaster for array prediction
# INFO:lightwood-1980:Ensembling the mixer
# INFO:lightwood-1980:Mixer: Neural got accuracy: 0.5206582085653144
# INFO:lightwood-1980:Mixer: LightGBMArray got accuracy: 0.44743922214788034
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/pmdarima/arima/arima.py:692: UserWarning: As of version 1.5.0 'typ' is no longer a valid arg for predict. In future versions this will raise a TypeError.
#   warnings.warn("As of version 1.5.0 'typ' is no longer a valid "
# INFO:lightwood-1980:Mixer: SkTime got accuracy: 0.2025435825521946
# INFO:lightwood-1980:Picked best mixer: Neural
# INFO:lightwood-1980:Analyzing the ensemble of mixers
# INFO:lightwood-1980:The block ICP is now running its analyze() method
# INFO:lightwood-1980:The block AccStats is now running its analyze() method
# INFO:lightwood-1980:Adjustment on validation requested.
# INFO:lightwood-1980:Updating the mixers
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-1980:Loss @ epoch 1: 0.15459302688638368
# INFO:lightwood-1980:Loss @ epoch 2: 0.15278507893284163
# INFO:lightwood-1980:Loss @ epoch 3: 0.15368996188044548
# INFO:lightwood-1980:Loss @ epoch 4: 0.15381904567281404
# INFO:lightwood-1980:Loss @ epoch 5: 0.15337310979763666
# INFO:lightwood-1980:Loss @ epoch 6: 0.15403116742769876
# INFO:lightwood-1980:Updating array of LGBM models...
# INFO:lightwood-1980:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:Model now has a total of 27 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-1980:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:Model now has a total of 23 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-1980:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:Model now has a total of 20 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-1980:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:Model now has a total of 20 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-1980:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:Model now has a total of 20 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-1980:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-1980:Model now has a total of 22 weak estimators
# INFO:lightwood-1980:Started fitting sktime forecaster for array prediction

# %% [markdown]
# ## Predict
#
# Once the predictor has trained, we can use it to generate 6-month forecasts for each of the test set data points:

# %%
forecasts = predictor.predict(test)
# Out:
# INFO:lightwood-1980:Dropping features: []
# INFO:lightwood-1980:Cleaning the data
# INFO:lightwood-1980:Transforming timeseries data
# INFO:lightwood-1980:Featurizing the data
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# INFO:lightwood-1980:The block ICP is now running its explain() method
# INFO:lightwood-1980:The block AccStats is now running its explain() method
# INFO:lightwood-1980:AccStats.explain() has not been implemented, no modifications will be done to the data insights.

# %% [markdown]
# Let's check how a single row might look:

# %%
forecasts.iloc[[10]]
# Out:
#                                            prediction  truth  \
# 10  [73.11902359652383, 72.49130566510362, 68.2849...   51.0
#
#                                           order_Month  \
# 10  [-272332800.0, -269654400.0, -266976000.0, -26...
#
#                         confidence  \
# 10  [0.7, 0.7, 0.7, 0.7, 0.7, 0.7]
#
#                                                 lower  \
# 10  [51.96518665776537, 51.337468726345165, 47.131...
#
#                                                 upper  anomaly
# 10  [94.27286053528229, 93.64514260386208, 89.4388...     True

# %% [markdown]
# You'll note that the point `prediction` has associated `lower` and `upper` bounds that are a function of the estimated `confidence` the model has on its own output. Apart from this, `order_Month` yields the timestamps of each prediction, `truth` lets us know what is the one-step-ahead observed value (if it exists at all). Finally, the `anomaly` tag will let you know if the observed value falls outside of the predicted region.
#
#
# ## Visualizing a forecast
#
# Okay, time series are much easier to appreciate through plots. Let's make one:
#
# NOTE: We will use `matplotlib` to generate a simple plot of these forecasts. If you want to run this notebook locally, you will need to `pip install matplotlib` for the following code to work.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.plot(forecasts['truth'].iloc[-24:], color='green', label='observed series')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['prediction'], color='purple', label='point prediction')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['lower'], color='grey')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['upper'], color='grey')
plt.xlabel('timestep')
plt.ylabel('# sunspots')
plt.title("Forecasted amount of sunspots for the next semester")
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we have gone through how you can train a machine learning model with Lightwood to produce forecasts for a univariate time series task.
#
# There are additional parameters to further customize your timeseries settings and/or prediction insights, so be sure to check the rest of the documentation.
