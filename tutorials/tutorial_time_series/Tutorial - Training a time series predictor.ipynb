# %% [markdown]
# # Tutorial - Time series forecasting
#
# ## Introduction
#
# Time series are an ubiquitous type of data in all types of processes. Producing forecasts for them can be highly valuable in domains like retail or industrial manufacture, among many others.
#
# Lightwood supports time series forecasting (both univariate and multivariate inputs), handling many of the pain points commonly associated with setting up a manual time series predictive pipeline.
#
# In this tutorial, we will train a lightwood predictor and analyze its forecasts for the task of counting sunspots in monthly intervals.
#
# ## Load data
#
# Let's begin by loading the dataset and looking at it:

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/mindsdb/benchmarks/main/benchmarks/datasets/monthly_sunspots/data.csv")
df
# Out:
#         Month  Sunspots
# 0     1749-01      58.0
# 1     1749-02      62.6
# 2     1749-03      70.0
# 3     1749-04      55.7
# 4     1749-05      85.0
# ...       ...       ...
# 2815  1983-08      71.8
# 2816  1983-09      50.3
# 2817  1983-10      55.8
# 2818  1983-11      33.3
# 2819  1983-12      33.4
#
# [2820 rows x 2 columns]

# %% [markdown]
# This is a very simple dataset. It's got a single column that specifies the month in which the measurement was done, and then in the 'Sunspots' column we have the actual quantity we are interested in forecasting. As such, we can characterize this as a univariate time series problem.
#
# ## Define the predictive task
#
# We will use Lightwood high level methods to state what we want to predict. As this is a time series task (because we want to leverage the notion of time to predict), we need to specify a set of arguments that will activate Lightwood's time series pipeline:

# %%
from lightwood.api.high_level import ProblemDefinition
# Out:
# INFO:lightwood-2177:No torchvision detected, image helpers not supported.
# INFO:lightwood-2177:No torchvision/pillow detected, image encoder not supported

# %%
tss = {'nr_predictions': 6,   # the predictor will learn to forecast what the next semester counts will look like (6 data points at monthly intervals -> 6 months)
       'order_by': ['Month'], # what column is used to order the entire datset
       'window': 12           # how many past values to consider for emitting predictions
      }

pdef = ProblemDefinition.from_dict({'target': 'Sunspots',         # specify the column to forecast
                                    'timeseries_settings': tss    # pass along all time series specific parameters
                                   })

# %% [markdown]
# Now, let's do a very simple train-test split, leaving 10% of the data to check the forecasts that our predictor will produce:

# %%
cutoff = int(len(df)*0.9)

train = df[:cutoff]
test = df[cutoff:]

print(train.shape, test.shape)
# Out:
# (2538, 2) (282, 2)

# %% [markdown]
# ## Generate the predictor object
#
# Now, we can generate code for a machine learning model by using our problem definition and the data:

# %%
from lightwood.api.high_level import (
    json_ai_from_problem,
    code_from_json_ai,
    predictor_from_code
)

json_ai = json_ai_from_problem(df, problem_definition=pdef)
code = code_from_json_ai(json_ai)
predictor = predictor_from_code(code)

# uncomment this to see the generated code:
# print(code)
# Out:
# INFO:lightwood-2177:Dropping features: []
# INFO:lightwood-2177:Analyzing a sample of 2467
# INFO:lightwood-2177:from a total population of 2820, this is equivalent to 87.5% of your data.
# INFO:lightwood-2177:Infering type for: Month
# INFO:lightwood-2177:Column Month has data type date
# INFO:lightwood-2177:Infering type for: Sunspots
# INFO:lightwood-2177:Column Sunspots has data type float
# /home/runner/work/lightwood/lightwood/lightwood/helpers/text.py:242: RuntimeWarning: invalid value encountered in double_scalars
#   randomness_per_index.append(S / np.log(N))
# INFO:lightwood-2177:Starting statistical analysis
# INFO:lightwood-2177:Finished statistical analysis
# INFO:lightwood-2177:Unable to import black formatter, predictor code might be a bit ugly.

# %% [markdown]
# ## Train
#
# Okay, everything is ready now for our predictor to learn based on the training data we will provide.
#
# Internally, lightwood cleans and reshapes the data, featurizes measurements and timestamps, and comes up with a handful of different models that will be evaluated to keep the one that produces the best forecasts.
#
# Let's train the predictor. This should take a couple of minutes, at most:

# %%
predictor.learn(train)
# Out:
# INFO:lightwood-2177:Dropping features: []
# INFO:lightwood-2177:Performing statistical analysis on data
# INFO:lightwood-2177:Starting statistical analysis
# INFO:lightwood-2177:Finished statistical analysis
# INFO:lightwood-2177:Cleaning the data
# INFO:lightwood-2177:Transforming timeseries data
# INFO:lightwood-2177:Using 1 processes to reshape.
# INFO:lightwood-2177:Splitting the data into train/test
# INFO:lightwood-2177:Preparing the encoders
# INFO:lightwood-2177:Encoder prepping dict length of: 1
# INFO:lightwood-2177:Done running for: Sunspots
# INFO:lightwood-2177:time series encoder epoch [1/100000] average_loss = 0.01813966171545239
# INFO:lightwood-2177:time series encoder epoch [2/100000] average_loss = 0.0071897343871054845
# INFO:lightwood-2177:time series encoder epoch [3/100000] average_loss = 0.005507370793046968
# INFO:lightwood-2177:time series encoder epoch [4/100000] average_loss = 0.004826837527564027
# INFO:lightwood-2177:time series encoder epoch [5/100000] average_loss = 0.00451363218644872
# INFO:lightwood-2177:time series encoder epoch [6/100000] average_loss = 0.004395986631538738
# INFO:lightwood-2177:time series encoder epoch [7/100000] average_loss = 0.00425604014492703
# INFO:lightwood-2177:time series encoder epoch [8/100000] average_loss = 0.004284225339021032
# INFO:lightwood-2177:time series encoder epoch [9/100000] average_loss = 0.00420809637644245
# INFO:lightwood-2177:time series encoder epoch [10/100000] average_loss = 0.004201766958169887
# INFO:lightwood-2177:time series encoder epoch [11/100000] average_loss = 0.0041663729685200495
# INFO:lightwood-2177:time series encoder epoch [12/100000] average_loss = 0.004173190184524723
# INFO:lightwood-2177:time series encoder epoch [13/100000] average_loss = 0.004168380214955051
# INFO:lightwood-2177:time series encoder epoch [14/100000] average_loss = 0.004135712955127455
# INFO:lightwood-2177:time series encoder epoch [15/100000] average_loss = 0.004137794707368426
# INFO:lightwood-2177:time series encoder epoch [16/100000] average_loss = 0.004116414855324032
# INFO:lightwood-2177:time series encoder epoch [17/100000] average_loss = 0.004137841342000744
# INFO:lightwood-2177:time series encoder epoch [18/100000] average_loss = 0.004166202766465222
# INFO:lightwood-2177:time series encoder epoch [19/100000] average_loss = 0.004153095198804985
# INFO:lightwood-2177:time series encoder epoch [20/100000] average_loss = 0.004106750108314688
# INFO:lightwood-2177:time series encoder epoch [21/100000] average_loss = 0.004087137231267271
# INFO:lightwood-2177:time series encoder epoch [22/100000] average_loss = 0.004082196961351117
# INFO:lightwood-2177:time series encoder epoch [23/100000] average_loss = 0.0042448547226743814
# INFO:lightwood-2177:time series encoder epoch [24/100000] average_loss = 0.0039619054195133485
# INFO:lightwood-2177:time series encoder epoch [25/100000] average_loss = 0.003856108192804607
# INFO:lightwood-2177:time series encoder epoch [26/100000] average_loss = 0.0039990599252505395
# INFO:lightwood-2177:time series encoder epoch [27/100000] average_loss = 0.004011112850831394
# INFO:lightwood-2177:time series encoder epoch [28/100000] average_loss = 0.003929516140717341
# INFO:lightwood-2177:time series encoder epoch [29/100000] average_loss = 0.004074303534423407
# INFO:lightwood-2177:time series encoder epoch [30/100000] average_loss = 0.00385916467932185
# INFO:lightwood-2177:time series encoder epoch [31/100000] average_loss = 0.0038092843079107655
# INFO:lightwood-2177:time series encoder epoch [32/100000] average_loss = 0.003733291882767151
# INFO:lightwood-2177:time series encoder epoch [33/100000] average_loss = 0.003729428972024634
# INFO:lightwood-2177:time series encoder epoch [34/100000] average_loss = 0.0038626126671004422
# INFO:lightwood-2177:time series encoder epoch [35/100000] average_loss = 0.003735300590612007
# INFO:lightwood-2177:time series encoder epoch [36/100000] average_loss = 0.003776433588953235
# INFO:lightwood-2177:Featurizing the data
# INFO:lightwood-2177:Training the mixers
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2177:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2177:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2177:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2177:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2177:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2177:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/pytorch_ranger/ranger.py:172: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1025.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# INFO:lightwood-2177:Loss of 0.5872397422790527 with learning rate 0.0001
# INFO:lightwood-2177:Loss of 0.7069736123085022 with learning rate 0.00014
# INFO:lightwood-2177:Found learning rate of: 0.0001
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2177:Loss @ epoch 1: 0.6458545029163361
# INFO:lightwood-2177:Loss @ epoch 2: 0.6432312279939651
# INFO:lightwood-2177:Loss @ epoch 3: 0.6400156766176224
# INFO:lightwood-2177:Loss @ epoch 4: 0.6362731009721756
# INFO:lightwood-2177:Loss @ epoch 5: 0.632084459066391
# INFO:lightwood-2177:Loss @ epoch 6: 0.6275183111429214
# INFO:lightwood-2177:Loss @ epoch 7: 0.6195354014635086
# INFO:lightwood-2177:Loss @ epoch 8: 0.6140014231204987
# INFO:lightwood-2177:Loss @ epoch 9: 0.6081724017858505
# INFO:lightwood-2177:Loss @ epoch 10: 0.6020721346139908
# INFO:lightwood-2177:Loss @ epoch 11: 0.5957496762275696
# INFO:lightwood-2177:Loss @ epoch 12: 0.589256688952446
# INFO:lightwood-2177:Loss @ epoch 13: 0.5785405784845352
# INFO:lightwood-2177:Loss @ epoch 14: 0.5715482532978058
# INFO:lightwood-2177:Loss @ epoch 15: 0.564422607421875
# INFO:lightwood-2177:Loss @ epoch 16: 0.5571884661912918
# INFO:lightwood-2177:Loss @ epoch 17: 0.5498556196689606
# INFO:lightwood-2177:Loss @ epoch 18: 0.542450949549675
# INFO:lightwood-2177:Loss @ epoch 19: 0.530476525425911
# INFO:lightwood-2177:Loss @ epoch 20: 0.5228910446166992
# INFO:lightwood-2177:Loss @ epoch 21: 0.5152955055236816
# INFO:lightwood-2177:Loss @ epoch 22: 0.5076679289340973
# INFO:lightwood-2177:Loss @ epoch 23: 0.5000148564577103
# INFO:lightwood-2177:Loss @ epoch 24: 0.4924517124891281
# INFO:lightwood-2177:Loss @ epoch 203: 0.18266399204730988
# INFO:lightwood-2177:Loss @ epoch 204: 0.18253955245018005
# INFO:lightwood-2177:Loss @ epoch 205: 0.18232834339141846
# INFO:lightwood-2177:Loss @ epoch 206: 0.18217800557613373
# INFO:lightwood-2177:Loss @ epoch 207: 0.18207617849111557
# INFO:lightwood-2177:Loss @ epoch 208: 0.18207012861967087
# INFO:lightwood-2177:Loss @ epoch 209: 0.18180733919143677
# INFO:lightwood-2177:Loss @ epoch 210: 0.1816784217953682
# INFO:lightwood-2177:Loss @ epoch 211: 0.1813882663846016
# INFO:lightwood-2177:Loss @ epoch 212: 0.18124882876873016
# INFO:lightwood-2177:Loss @ epoch 213: 0.18100931495428085
# INFO:lightwood-2177:Loss @ epoch 214: 0.18094410002231598
# INFO:lightwood-2177:Loss @ epoch 215: 0.18077702075242996
# INFO:lightwood-2177:Loss @ epoch 216: 0.18072881549596786
# INFO:lightwood-2177:Loss @ epoch 217: 0.1804284155368805
# INFO:lightwood-2177:Loss @ epoch 218: 0.18031129986047745
# INFO:lightwood-2177:Loss @ epoch 219: 0.18011626601219177
# INFO:lightwood-2177:Loss @ epoch 220: 0.180331788957119
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2177:Loss @ epoch 1: 0.14624138176441193
# INFO:lightwood-2177:Loss @ epoch 2: 0.14054893295873294
# INFO:lightwood-2177:Loss @ epoch 3: 0.14233770831064743
# INFO:lightwood-2177:Loss @ epoch 4: 0.14133566482500595
# INFO:lightwood-2177:Loss @ epoch 5: 0.14288499409502203
# INFO:lightwood-2177:Started fitting LGBM models for array prediction
# INFO:lightwood-2177:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2177:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37881 iterations given 4735.176536798477 seconds constraint
# INFO:lightwood-2177:Lightgbm model contains 33 weak estimators
# INFO:lightwood-2177:Updating lightgbm model with 2.0 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:Model now has a total of 35 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2177:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2177:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37876 iterations given 4734.6042222976685 seconds constraint
# INFO:lightwood-2177:Lightgbm model contains 26 weak estimators
# INFO:lightwood-2177:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:Model now has a total of 27 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2177:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2177:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37874 iterations given 4734.337462186813 seconds constraint
# INFO:lightwood-2177:Lightgbm model contains 32 weak estimators
# INFO:lightwood-2177:Updating lightgbm model with 2.0 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:Model now has a total of 34 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2177:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2177:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37871 iterations given 4733.882657289505 seconds constraint
# INFO:lightwood-2177:Lightgbm model contains 25 weak estimators
# INFO:lightwood-2177:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:Model now has a total of 26 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2177:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2177:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37875 iterations given 4734.396986246109 seconds constraint
# INFO:lightwood-2177:Lightgbm model contains 19 weak estimators
# INFO:lightwood-2177:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:Model now has a total of 20 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2177:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2177:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37875 iterations given 4734.375006914139 seconds constraint
# INFO:lightwood-2177:Lightgbm model contains 24 weak estimators
# INFO:lightwood-2177:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:Model now has a total of 25 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = original_target_train
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = original_target_dev
# INFO:lightwood-2177:Started fitting sktime forecaster for array prediction
# INFO:lightwood-2177:Ensembling the mixer
# INFO:lightwood-2177:Mixer: Neural got accuracy: 0.5214662673682952
# INFO:lightwood-2177:Mixer: LightGBMArray got accuracy: 0.4851772086341023
# INFO:lightwood-2177:Mixer: SkTime got accuracy: 0.21481464159207728
# INFO:lightwood-2177:Picked best mixer: Neural
# INFO:lightwood-2177:Analyzing the ensemble of mixers
# INFO:lightwood-2177:The block ICP is now running its analyze() method
# INFO:lightwood-2177:The block AccStats is now running its analyze() method
# INFO:lightwood-2177:Adjustment on validation requested.
# INFO:lightwood-2177:Updating the mixers
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2177:Loss @ epoch 1: 0.14315503338972727
# INFO:lightwood-2177:Loss @ epoch 2: 0.14372179408868155
# INFO:lightwood-2177:Loss @ epoch 3: 0.14316301047801971
# INFO:lightwood-2177:Loss @ epoch 4: 0.14255195359388986
# INFO:lightwood-2177:Loss @ epoch 5: 0.14328621327877045
# INFO:lightwood-2177:Updating array of LGBM models...
# INFO:lightwood-2177:Updating lightgbm model with 2.0 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:Model now has a total of 37 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2177:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:Model now has a total of 28 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2177:Updating lightgbm model with 2.0 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:Model now has a total of 36 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2177:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:Model now has a total of 27 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2177:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:Model now has a total of 21 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2177:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2177:Model now has a total of 26 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = original_target_train
# INFO:lightwood-2177:Started fitting sktime forecaster for array prediction

# %% [markdown]
# ## Predict
#
# Once the predictor has trained, we can use it to generate 6-month forecasts for each of the test set data points:

# %%
forecasts = predictor.predict(test)
# Out:
# INFO:lightwood-2177:Dropping features: []
# INFO:lightwood-2177:Cleaning the data
# INFO:lightwood-2177:Transforming timeseries data
# INFO:lightwood-2177:Featurizing the data
# INFO:lightwood-2177:The block ICP is now running its explain() method
# INFO:lightwood-2177:The block AccStats is now running its explain() method
# INFO:lightwood-2177:AccStats.explain() has not been implemented, no modifications will be done to the data insights.

# %% [markdown]
# Let's check how a single row might look:

# %%
forecasts.iloc[[10]]
# Out:
#                                            prediction  \
# 10  [67.52756269823574, 71.64786186327231, 66.3184...
#
#                                           order_Month  \
# 10  [-271987200.0, -269308800.0, -266630400.0, -26...
#
#                               confidence  \
# 10  [0.68, 0.68, 0.68, 0.68, 0.68, 0.68]
#
#                                                 lower  \
# 10  [53.1312340293017, 54.82074731148823, 47.41232...
#
#                                                 upper
# 10  [81.92389136716977, 88.47497641505639, 85.2246...

# %% [markdown]
# You'll note that the point `prediction` has associated `lower` and `upper` bounds that are a function of the estimated `confidence` the model has on its own output. Apart from this, `order_Month` yields the timestamps of each prediction, the `anomaly` tag will let you know if the observed value falls outside of the predicted region.
#
#
# ## Visualizing a forecast
#
# Okay, time series are much easier to appreciate through plots. Let's make one:
#
# NOTE: We will use `matplotlib` to generate a simple plot of these forecasts. If you want to run this notebook locally, you will need to `pip install matplotlib` for the following code to work.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['prediction'], color='purple', label='point prediction')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['lower'], color='grey')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['upper'], color='grey')
plt.xlabel('timestep')
plt.ylabel('# sunspots')
plt.title("Forecasted amount of sunspots for the next semester")
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we have gone through how you can train a machine learning model with Lightwood to produce forecasts for a univariate time series task.
#
# There are additional parameters to further customize your timeseries settings and/or prediction insights, so be sure to check the rest of the documentation.
