# %% [markdown]
# # Tutorial - Time series forecasting
#
# ## Introduction
#
# Time series are an ubiquitous type of data in all types of processes. Producing forecasts for them can be highly valuable in domains like retail or industrial manufacture, among many others.
#
# Lightwood supports time series forecasting (both univariate and multivariate inputs), handling many of the pain points commonly associated with setting up a manual time series predictive pipeline.
#
# In this tutorial, we will train a lightwood predictor and analyze its forecasts for the task of counting sunspots in monthly intervals.
#
# ## Load data
#
# Let's begin by loading the dataset and looking at it:

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/mindsdb/benchmarks/main/benchmarks/datasets/monthly_sunspots/data.csv")
df
# Out:
#         Month  Sunspots
# 0     1749-01      58.0
# 1     1749-02      62.6
# 2     1749-03      70.0
# 3     1749-04      55.7
# 4     1749-05      85.0
# ...       ...       ...
# 2815  1983-08      71.8
# 2816  1983-09      50.3
# 2817  1983-10      55.8
# 2818  1983-11      33.3
# 2819  1983-12      33.4
#
# [2820 rows x 2 columns]

# %% [markdown]
# This is a very simple dataset. It's got a single column that specifies the month in which the measurement was done, and then in the 'Sunspots' column we have the actual quantity we are interested in forecasting. As such, we can characterize this as a univariate time series problem.
#
# ## Define the predictive task
#
# We will use Lightwood high level methods to state what we want to predict. As this is a time series task (because we want to leverage the notion of time to predict), we need to specify a set of arguments that will activate Lightwood's time series pipeline:

# %%
from lightwood.api.high_level import ProblemDefinition

# %%
tss = {'nr_predictions': 6,   # the predictor will learn to forecast what the next semester counts will look like (6 data points at monthly intervals -> 6 months)
       'order_by': ['Month'], # what column is used to order the entire datset
       'window': 12           # how many past values to consider for emitting predictions
      }

pdef = ProblemDefinition.from_dict({'target': 'Sunspots',         # specify the column to forecast
                                    'timeseries_settings': tss    # pass along all time series specific parameters
                                   })

# %% [markdown]
# Now, let's do a very simple train-test split, leaving 10% of the data to check the forecasts that our predictor will produce:

# %%
cutoff = int(len(df)*0.9)

train = df[:cutoff]
test = df[cutoff:]

print(train.shape, test.shape)
# Out:
# (2538, 2) (282, 2)

# %% [markdown]
# ## Generate the predictor object
#
# Now, we can generate code for a machine learning model by using our problem definition and the data:

# %%
from lightwood.api.high_level import (
    json_ai_from_problem,
    code_from_json_ai,
    predictor_from_code
)

json_ai = json_ai_from_problem(df, problem_definition=pdef)
code = code_from_json_ai(json_ai)
predictor = predictor_from_code(code)

# uncomment this to see the generated code:
# print(code)
# Out:
# INFO:lightwood-2698:Dropping features: []
# INFO:lightwood-2698:Analyzing a sample of 2467
# INFO:lightwood-2698:from a total population of 2820, this is equivalent to 87.5% of your data.
# INFO:lightwood-2698:Infering type for: Month
# INFO:lightwood-2698:Column Month has data type date
# INFO:lightwood-2698:Infering type for: Sunspots
# INFO:lightwood-2698:Column Sunspots has data type float
# /home/runner/work/lightwood/lightwood/lightwood/helpers/text.py:242: RuntimeWarning: invalid value encountered in double_scalars
#   randomness_per_index.append(S / np.log(N))
# INFO:lightwood-2698:Starting statistical analysis
# INFO:lightwood-2698:Finished statistical analysis
# INFO:lightwood-2698:Unable to import black formatter, predictor code might be a bit ugly.

# %% [markdown]
# ## Train
#
# Okay, everything is ready now for our predictor to learn based on the training data we will provide.
#
# Internally, lightwood cleans and reshapes the data, featurizes measurements and timestamps, and comes up with a handful of different models that will be evaluated to keep the one that produces the best forecasts.
#
# Let's train the predictor. This should take a couple of minutes, at most:

# %%
predictor.learn(train)
# Out:
# INFO:lightwood-2698:Dropping features: []
# INFO:lightwood-2698:Performing statistical analysis on data
# INFO:lightwood-2698:Starting statistical analysis
# INFO:lightwood-2698:Finished statistical analysis
# INFO:lightwood-2698:Cleaning the data
# INFO:lightwood-2698:Transforming timeseries data
# INFO:lightwood-2698:Using 1 processes to reshape.
# INFO:lightwood-2698:Splitting the data into train/test
# INFO:lightwood-2698:Preparing the encoders
# INFO:lightwood-2698:Encoder prepping dict length of: 1
# INFO:lightwood-2698:Done running for: Sunspots
# INFO:lightwood-2698:time series encoder epoch [1/100000] average_loss = 0.01823149986986844
# INFO:lightwood-2698:time series encoder epoch [2/100000] average_loss = 0.0071819509629253335
# INFO:lightwood-2698:time series encoder epoch [3/100000] average_loss = 0.005542610836112745
# INFO:lightwood-2698:time series encoder epoch [4/100000] average_loss = 0.004768271281981792
# INFO:lightwood-2698:time series encoder epoch [5/100000] average_loss = 0.004545405330549159
# INFO:lightwood-2698:time series encoder epoch [6/100000] average_loss = 0.004399197046146836
# INFO:lightwood-2698:time series encoder epoch [7/100000] average_loss = 0.004269317557488475
# INFO:lightwood-2698:time series encoder epoch [8/100000] average_loss = 0.004272921820804182
# INFO:lightwood-2698:time series encoder epoch [9/100000] average_loss = 0.004188930454773043
# INFO:lightwood-2698:time series encoder epoch [10/100000] average_loss = 0.004173760850369904
# INFO:lightwood-2698:time series encoder epoch [11/100000] average_loss = 0.004128536460377658
# INFO:lightwood-2698:time series encoder epoch [12/100000] average_loss = 0.004135320980646151
# INFO:lightwood-2698:time series encoder epoch [13/100000] average_loss = 0.004118046984436115
# INFO:lightwood-2698:time series encoder epoch [14/100000] average_loss = 0.004078709200423451
# INFO:lightwood-2698:time series encoder epoch [15/100000] average_loss = 0.004076274197684301
# INFO:lightwood-2698:time series encoder epoch [16/100000] average_loss = 0.004031576337182454
# INFO:lightwood-2698:time series encoder epoch [17/100000] average_loss = 0.004018633498492708
# INFO:lightwood-2698:time series encoder epoch [18/100000] average_loss = 0.004081545795668317
# INFO:lightwood-2698:time series encoder epoch [19/100000] average_loss = 0.004138938896276282
# INFO:lightwood-2698:time series encoder epoch [20/100000] average_loss = 0.004202838161630869
# INFO:lightwood-2698:time series encoder epoch [21/100000] average_loss = 0.0042991639491286706
# INFO:lightwood-2698:time series encoder epoch [22/100000] average_loss = 0.004237830455808484
# INFO:lightwood-2698:time series encoder epoch [23/100000] average_loss = 0.004164642516642927
# INFO:lightwood-2698:time series encoder epoch [24/100000] average_loss = 0.003938625260579476
# INFO:lightwood-2698:time series encoder epoch [25/100000] average_loss = 0.003738706155846442
# INFO:lightwood-2698:time series encoder epoch [26/100000] average_loss = 0.003746362567314091
# INFO:lightwood-2698:time series encoder epoch [27/100000] average_loss = 0.00383719222594793
# INFO:lightwood-2698:time series encoder epoch [28/100000] average_loss = 0.003718626922868542
# INFO:lightwood-2698:time series encoder epoch [29/100000] average_loss = 0.0037291311757404483
# INFO:lightwood-2698:time series encoder epoch [30/100000] average_loss = 0.003693755596758452
# INFO:lightwood-2698:time series encoder epoch [31/100000] average_loss = 0.0038485093669129757
# INFO:lightwood-2698:Featurizing the data
# INFO:lightwood-2698:Training the mixers
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2698:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2698:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2698:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2698:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2698:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2698:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/pytorch_ranger/ranger.py:172: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1025.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# INFO:lightwood-2698:Loss of 0.5583959221839905 with learning rate 0.0001
# INFO:lightwood-2698:Loss of 0.6662687659263611 with learning rate 0.00014
# INFO:lightwood-2698:Found learning rate of: 0.0001
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2698:Loss @ epoch 1: 0.6096558570861816
# INFO:lightwood-2698:Loss @ epoch 2: 0.6071201413869858
# INFO:lightwood-2698:Loss @ epoch 3: 0.6040138453245163
# INFO:lightwood-2698:Loss @ epoch 4: 0.6003891974687576
# INFO:lightwood-2698:Loss @ epoch 5: 0.5963321179151535
# INFO:lightwood-2698:Loss @ epoch 6: 0.5919057875871658
# INFO:lightwood-2698:Loss @ epoch 7: 0.5841480940580368
# INFO:lightwood-2698:Loss @ epoch 8: 0.5787945240736008
# INFO:lightwood-2698:Loss @ epoch 9: 0.5731688290834427
# INFO:lightwood-2698:Loss @ epoch 10: 0.5673100054264069
# INFO:lightwood-2698:Loss @ epoch 11: 0.5612362921237946
# INFO:lightwood-2698:Loss @ epoch 12: 0.5550072938203812
# INFO:lightwood-2698:Loss @ epoch 13: 0.5446306467056274
# INFO:lightwood-2698:Loss @ epoch 14: 0.5378096699714661
# INFO:lightwood-2698:Loss @ epoch 15: 0.5308099687099457
# INFO:lightwood-2698:Loss @ epoch 16: 0.523627296090126
# INFO:lightwood-2698:Loss @ epoch 17: 0.5163164436817169
# INFO:lightwood-2698:Loss @ epoch 18: 0.5090311914682388
# INFO:lightwood-2698:Loss @ epoch 19: 0.49763043224811554
# INFO:lightwood-2698:Loss @ epoch 20: 0.49058663845062256
# INFO:lightwood-2698:Loss @ epoch 21: 0.48353955149650574
# INFO:lightwood-2698:Loss @ epoch 22: 0.47640763223171234
# INFO:lightwood-2698:Loss @ epoch 23: 0.46926188468933105
# INFO:lightwood-2698:Loss @ epoch 24: 0.4622286856174469
# INFO:lightwood-2698:Loss @ epoch 25: 0.4510375112295151
# INFO:lightwood-2698:Loss @ epoch 26: 0.4441084563732147
# INFO:lightwood-2698:Loss @ epoch 27: 0.43724222481250763
# INFO:lightwood-2698:Loss @ epoch 28: 0.43040016293525696
# INFO:lightwood-2698:Loss @ epoch 29: 0.42364151775836945
# INFO:lightwood-2698:Loss @ epoch 30: 0.417054146528244
# INFO:lightwood-2698:Loss @ epoch 31: 0.4066605716943741
# INFO:lightwood-2698:Loss @ epoch 32: 0.40028825402259827
# INFO:lightwood-2698:Loss @ epoch 33: 0.39402638375759125
# INFO:lightwood-2698:Loss @ epoch 34: 0.3878939747810364
# INFO:lightwood-2698:Loss @ epoch 35: 0.38183514028787613
# INFO:lightwood-2698:Loss @ epoch 36: 0.3759142756462097
# INFO:lightwood-2698:Loss @ epoch 37: 0.3665757402777672
# INFO:lightwood-2698:Loss @ epoch 38: 0.360802486538887
# INFO:lightwood-2698:Loss @ epoch 39: 0.35506903380155563
# INFO:lightwood-2698:Loss @ epoch 40: 0.34945034235715866
# INFO:lightwood-2698:Loss @ epoch 41: 0.3439880758523941
# INFO:lightwood-2698:Loss @ epoch 42: 0.338703416287899
# INFO:lightwood-2698:Loss @ epoch 43: 0.3304692432284355
# INFO:lightwood-2698:Loss @ epoch 44: 0.32552655041217804
# INFO:lightwood-2698:Loss @ epoch 45: 0.3207292929291725
# INFO:lightwood-2698:Loss @ epoch 46: 0.3160930648446083
# INFO:lightwood-2698:Loss @ epoch 47: 0.31160057336091995
# INFO:lightwood-2698:Loss @ epoch 48: 0.30729280412197113
# INFO:lightwood-2698:Loss @ epoch 49: 0.3007216453552246
# INFO:lightwood-2698:Loss @ epoch 50: 0.29679062962532043
# INFO:lightwood-2698:Loss @ epoch 51: 0.29299525916576385
# INFO:lightwood-2698:Loss @ epoch 52: 0.2893478199839592
# INFO:lightwood-2698:Loss @ epoch 53: 0.28580839931964874
# INFO:lightwood-2698:Loss @ epoch 54: 0.2824404016137123
# INFO:lightwood-2698:Loss @ epoch 55: 0.27728186547756195
# INFO:lightwood-2698:Loss @ epoch 56: 0.27414649724960327
# INFO:lightwood-2698:Loss @ epoch 57: 0.27105970680713654
# INFO:lightwood-2698:Loss @ epoch 58: 0.26808299124240875
# INFO:lightwood-2698:Loss @ epoch 59: 0.26521290093660355
# INFO:lightwood-2698:Loss @ epoch 60: 0.2624514773488045
# INFO:lightwood-2698:Loss @ epoch 61: 0.2583017572760582
# INFO:lightwood-2698:Loss @ epoch 62: 0.2557985931634903
# INFO:lightwood-2698:Loss @ epoch 63: 0.25336920469999313
# INFO:lightwood-2698:Loss @ epoch 64: 0.2510014623403549
# INFO:lightwood-2698:Loss @ epoch 65: 0.248685322701931
# INFO:lightwood-2698:Loss @ epoch 66: 0.2464492991566658
# INFO:lightwood-2698:Loss @ epoch 67: 0.24301879107952118
# INFO:lightwood-2698:Loss @ epoch 68: 0.24094930291175842
# INFO:lightwood-2698:Loss @ epoch 69: 0.23893649876117706
# INFO:lightwood-2698:Loss @ epoch 70: 0.23695876449346542
# INFO:lightwood-2698:Loss @ epoch 71: 0.23504973202943802
# INFO:lightwood-2698:Loss @ epoch 72: 0.23325738310813904
# INFO:lightwood-2698:Loss @ epoch 73: 0.23046809434890747
# INFO:lightwood-2698:Loss @ epoch 74: 0.22872937470674515
# INFO:lightwood-2698:Loss @ epoch 75: 0.2270365208387375
# INFO:lightwood-2698:Loss @ epoch 76: 0.22544725239276886
# INFO:lightwood-2698:Loss @ epoch 77: 0.22388754040002823
# INFO:lightwood-2698:Loss @ epoch 78: 0.22237689048051834
# INFO:lightwood-2698:Loss @ epoch 79: 0.22004080563783646
# INFO:lightwood-2698:Loss @ epoch 80: 0.21863172203302383
# INFO:lightwood-2698:Loss @ epoch 81: 0.2172679826617241
# INFO:lightwood-2698:Loss @ epoch 82: 0.2159307301044464
# INFO:lightwood-2698:Loss @ epoch 83: 0.21464645117521286
# INFO:lightwood-2698:Loss @ epoch 84: 0.21340198814868927
# INFO:lightwood-2698:Loss @ epoch 85: 0.21153557300567627
# INFO:lightwood-2698:Loss @ epoch 86: 0.21041064709424973
# INFO:lightwood-2698:Loss @ epoch 87: 0.20934855192899704
# INFO:lightwood-2698:Loss @ epoch 88: 0.20832157880067825
# INFO:lightwood-2698:Loss @ epoch 89: 0.20740050077438354
# INFO:lightwood-2698:Loss @ epoch 90: 0.20654255151748657
# INFO:lightwood-2698:Loss @ epoch 91: 0.20527973771095276
# INFO:lightwood-2698:Loss @ epoch 92: 0.20455700904130936
# INFO:lightwood-2698:Loss @ epoch 93: 0.20386116206645966
# INFO:lightwood-2698:Loss @ epoch 94: 0.20321343839168549
# INFO:lightwood-2698:Loss @ epoch 95: 0.2025998905301094
# INFO:lightwood-2698:Loss @ epoch 96: 0.2020171731710434
# INFO:lightwood-2698:Loss @ epoch 97: 0.20123017579317093
# INFO:lightwood-2698:Loss @ epoch 98: 0.20081742852926254
# INFO:lightwood-2698:Loss @ epoch 99: 0.20040922611951828
# INFO:lightwood-2698:Loss @ epoch 100: 0.20004107058048248
# INFO:lightwood-2698:Loss @ epoch 101: 0.19974002242088318
# INFO:lightwood-2698:Loss @ epoch 102: 0.1994161456823349
# INFO:lightwood-2698:Loss @ epoch 103: 0.19889723509550095
# INFO:lightwood-2698:Loss @ epoch 104: 0.19862805306911469
# INFO:lightwood-2698:Loss @ epoch 105: 0.19837718456983566
# INFO:lightwood-2698:Loss @ epoch 106: 0.19814179092645645
# INFO:lightwood-2698:Loss @ epoch 107: 0.19793184101581573
# INFO:lightwood-2698:Loss @ epoch 108: 0.19768711179494858
# INFO:lightwood-2698:Loss @ epoch 109: 0.19730570167303085
# INFO:lightwood-2698:Loss @ epoch 110: 0.1970890536904335
# INFO:lightwood-2698:Loss @ epoch 111: 0.19686567783355713
# INFO:lightwood-2698:Loss @ epoch 112: 0.19665618985891342
# INFO:lightwood-2698:Loss @ epoch 113: 0.1964607834815979
# INFO:lightwood-2698:Loss @ epoch 114: 0.19623813033103943
# INFO:lightwood-2698:Loss @ epoch 115: 0.19589807093143463
# INFO:lightwood-2698:Loss @ epoch 116: 0.19570882618427277
# INFO:lightwood-2698:Loss @ epoch 117: 0.19553833454847336
# INFO:lightwood-2698:Loss @ epoch 118: 0.1953554004430771
# INFO:lightwood-2698:Loss @ epoch 119: 0.19517147541046143
# INFO:lightwood-2698:Loss @ epoch 120: 0.19496972858905792
# INFO:lightwood-2698:Loss @ epoch 121: 0.19466502219438553
# INFO:lightwood-2698:Loss @ epoch 122: 0.19449129700660706
# INFO:lightwood-2698:Loss @ epoch 123: 0.19433776289224625
# INFO:lightwood-2698:Loss @ epoch 124: 0.19418250769376755
# INFO:lightwood-2698:Loss @ epoch 125: 0.1940084993839264
# INFO:lightwood-2698:Loss @ epoch 126: 0.19382800161838531
# INFO:lightwood-2698:Loss @ epoch 127: 0.1935490146279335
# INFO:lightwood-2698:Loss @ epoch 128: 0.19338923692703247
# INFO:lightwood-2698:Loss @ epoch 129: 0.19322805851697922
# INFO:lightwood-2698:Loss @ epoch 130: 0.193083718419075
# INFO:lightwood-2698:Loss @ epoch 131: 0.19291480630636215
# INFO:lightwood-2698:Loss @ epoch 132: 0.19272814691066742
# INFO:lightwood-2698:Loss @ epoch 133: 0.19243959337472916
# INFO:lightwood-2698:Loss @ epoch 134: 0.19228245317935944
# INFO:lightwood-2698:Loss @ epoch 135: 0.192121684551239
# INFO:lightwood-2698:Loss @ epoch 136: 0.19198494404554367
# INFO:lightwood-2698:Loss @ epoch 137: 0.19181425124406815
# INFO:lightwood-2698:Loss @ epoch 138: 0.1916380450129509
# INFO:lightwood-2698:Loss @ epoch 139: 0.19136816263198853
# INFO:lightwood-2698:Loss @ epoch 140: 0.19118881225585938
# INFO:lightwood-2698:Loss @ epoch 141: 0.19102032482624054
# INFO:lightwood-2698:Loss @ epoch 142: 0.1908757984638214
# INFO:lightwood-2698:Loss @ epoch 143: 0.19070609658956528
# INFO:lightwood-2698:Loss @ epoch 144: 0.19052352011203766
# INFO:lightwood-2698:Loss @ epoch 145: 0.19023460149765015
# INFO:lightwood-2698:Loss @ epoch 146: 0.1900547668337822
# INFO:lightwood-2698:Loss @ epoch 147: 0.18988925963640213
# INFO:lightwood-2698:Loss @ epoch 148: 0.18974731862545013
# INFO:lightwood-2698:Loss @ epoch 149: 0.1895570084452629
# INFO:lightwood-2698:Loss @ epoch 150: 0.18934714794158936
# INFO:lightwood-2698:Loss @ epoch 151: 0.18903516232967377
# INFO:lightwood-2698:Loss @ epoch 152: 0.1888437420129776
# INFO:lightwood-2698:Loss @ epoch 153: 0.18866044282913208
# INFO:lightwood-2698:Loss @ epoch 154: 0.18849459290504456
# INFO:lightwood-2698:Loss @ epoch 155: 0.18835602700710297
# INFO:lightwood-2698:Loss @ epoch 156: 0.18817149102687836
# INFO:lightwood-2698:Loss @ epoch 157: 0.18790679425001144
# INFO:lightwood-2698:Loss @ epoch 158: 0.18773043155670166
# INFO:lightwood-2698:Loss @ epoch 159: 0.18760228157043457
# INFO:lightwood-2698:Loss @ epoch 160: 0.18746992945671082
# INFO:lightwood-2698:Loss @ epoch 161: 0.18724679201841354
# INFO:lightwood-2698:Loss @ epoch 162: 0.18707240372896194
# INFO:lightwood-2698:Loss @ epoch 163: 0.18680114299058914
# INFO:lightwood-2698:Loss @ epoch 164: 0.18665215373039246
# INFO:lightwood-2698:Loss @ epoch 165: 0.18649768829345703
# INFO:lightwood-2698:Loss @ epoch 166: 0.18642044067382812
# INFO:lightwood-2698:Loss @ epoch 167: 0.18622063845396042
# INFO:lightwood-2698:Loss @ epoch 168: 0.18605175614356995
# INFO:lightwood-2698:Loss @ epoch 169: 0.18578042089939117
# INFO:lightwood-2698:Loss @ epoch 170: 0.18560545146465302
# INFO:lightwood-2698:Loss @ epoch 171: 0.18550607562065125
# INFO:lightwood-2698:Loss @ epoch 172: 0.18531618267297745
# INFO:lightwood-2698:Loss @ epoch 173: 0.18511050194501877
# INFO:lightwood-2698:Loss @ epoch 174: 0.1849067509174347
# INFO:lightwood-2698:Loss @ epoch 175: 0.18463138490915298
# INFO:lightwood-2698:Loss @ epoch 176: 0.18447770923376083
# INFO:lightwood-2698:Loss @ epoch 177: 0.18433361500501633
# INFO:lightwood-2698:Loss @ epoch 178: 0.1841624304652214
# INFO:lightwood-2698:Loss @ epoch 179: 0.1840340569615364
# INFO:lightwood-2698:Loss @ epoch 180: 0.1837971955537796
# INFO:lightwood-2698:Loss @ epoch 181: 0.18353502452373505
# INFO:lightwood-2698:Loss @ epoch 182: 0.18333381414413452
# INFO:lightwood-2698:Loss @ epoch 183: 0.18320561200380325
# INFO:lightwood-2698:Loss @ epoch 184: 0.18316370248794556
# INFO:lightwood-2698:Loss @ epoch 185: 0.18289247900247574
# INFO:lightwood-2698:Loss @ epoch 186: 0.18271617591381073
# INFO:lightwood-2698:Loss @ epoch 187: 0.1824185699224472
# INFO:lightwood-2698:Loss @ epoch 188: 0.1822681725025177
# INFO:lightwood-2698:Loss @ epoch 189: 0.18214710801839828
# INFO:lightwood-2698:Loss @ epoch 190: 0.18210606276988983
# INFO:lightwood-2698:Loss @ epoch 191: 0.18189623951911926
# INFO:lightwood-2698:Loss @ epoch 192: 0.18164081126451492
# INFO:lightwood-2698:Loss @ epoch 193: 0.18139826506376266
# INFO:lightwood-2698:Loss @ epoch 194: 0.18119296431541443
# INFO:lightwood-2698:Loss @ epoch 195: 0.1810949742794037
# INFO:lightwood-2698:Loss @ epoch 196: 0.18103821575641632
# INFO:lightwood-2698:Loss @ epoch 197: 0.1807945966720581
# INFO:lightwood-2698:Loss @ epoch 198: 0.18059152364730835
# INFO:lightwood-2698:Loss @ epoch 199: 0.18029826134443283
# INFO:lightwood-2698:Loss @ epoch 200: 0.180121012032032
# INFO:lightwood-2698:Loss @ epoch 201: 0.1800062358379364
# INFO:lightwood-2698:Loss @ epoch 202: 0.18009965866804123
# INFO:lightwood-2698:Loss @ epoch 203: 0.17979439347982407
# INFO:lightwood-2698:Loss @ epoch 204: 0.17950178682804108
# INFO:lightwood-2698:Loss @ epoch 205: 0.1792585849761963
# INFO:lightwood-2698:Loss @ epoch 206: 0.17903367429971695
# INFO:lightwood-2698:Loss @ epoch 207: 0.17894069105386734
# INFO:lightwood-2698:Loss @ epoch 208: 0.17879554629325867
# INFO:lightwood-2698:Loss @ epoch 209: 0.17871087044477463
# INFO:lightwood-2698:Loss @ epoch 210: 0.17850898206233978
# INFO:lightwood-2698:Loss @ epoch 211: 0.17815708369016647
# INFO:lightwood-2698:Loss @ epoch 212: 0.17798737436532974
# INFO:lightwood-2698:Loss @ epoch 213: 0.17780430614948273
# INFO:lightwood-2698:Loss @ epoch 214: 0.177828848361969
# INFO:lightwood-2698:Loss @ epoch 215: 0.17754680663347244
# INFO:lightwood-2698:Loss @ epoch 216: 0.17731241881847382
# INFO:lightwood-2698:Loss @ epoch 217: 0.17700915783643723
# INFO:lightwood-2698:Loss @ epoch 218: 0.17680098861455917
# INFO:lightwood-2698:Loss @ epoch 219: 0.176624596118927
# INFO:lightwood-2698:Loss @ epoch 220: 0.1765364333987236
# INFO:lightwood-2698:Loss @ epoch 221: 0.1763826087117195
# INFO:lightwood-2698:Loss @ epoch 222: 0.17614943534135818
# INFO:lightwood-2698:Loss @ epoch 223: 0.17588914185762405
# INFO:lightwood-2698:Loss @ epoch 224: 0.1757041960954666
# INFO:lightwood-2698:Loss @ epoch 225: 0.17558551579713821
# INFO:lightwood-2698:Loss @ epoch 226: 0.17552903294563293
# INFO:lightwood-2698:Loss @ epoch 227: 0.1752653419971466
# INFO:lightwood-2698:Loss @ epoch 228: 0.17507852613925934
# INFO:lightwood-2698:Loss @ epoch 229: 0.17483986914157867
# INFO:lightwood-2698:Loss @ epoch 230: 0.17468398809432983
# INFO:lightwood-2698:Loss @ epoch 231: 0.1745673194527626
# INFO:lightwood-2698:Loss @ epoch 232: 0.17461805045604706
# INFO:lightwood-2698:Loss @ epoch 233: 0.17432236671447754
# INFO:lightwood-2698:Loss @ epoch 234: 0.17408420145511627
# INFO:lightwood-2698:Loss @ epoch 235: 0.1739230453968048
# INFO:lightwood-2698:Loss @ epoch 236: 0.17374862730503082
# INFO:lightwood-2698:Loss @ epoch 237: 0.173599474132061
# INFO:lightwood-2698:Loss @ epoch 238: 0.1735384538769722
# INFO:lightwood-2698:Loss @ epoch 239: 0.17338162660598755
# INFO:lightwood-2698:Loss @ epoch 240: 0.17316745966672897
# INFO:lightwood-2698:Loss @ epoch 241: 0.17296073585748672
# INFO:lightwood-2698:Loss @ epoch 242: 0.1728065088391304
# INFO:lightwood-2698:Loss @ epoch 243: 0.17274950444698334
# INFO:lightwood-2698:Loss @ epoch 244: 0.17270051687955856
# INFO:lightwood-2698:Loss @ epoch 245: 0.17247111350297928
# INFO:lightwood-2698:Loss @ epoch 246: 0.1722761020064354
# INFO:lightwood-2698:Loss @ epoch 247: 0.17203594744205475
# INFO:lightwood-2698:Loss @ epoch 248: 0.1719367355108261
# INFO:lightwood-2698:Loss @ epoch 249: 0.17188577353954315
# INFO:lightwood-2698:Loss @ epoch 250: 0.17188497632741928
# INFO:lightwood-2698:Loss @ epoch 251: 0.17172197997570038
# INFO:lightwood-2698:Loss @ epoch 252: 0.17142724245786667
# INFO:lightwood-2698:Loss @ epoch 253: 0.17123868316411972
# INFO:lightwood-2698:Loss @ epoch 254: 0.1710694059729576
# INFO:lightwood-2698:Loss @ epoch 255: 0.17095834761857986
# INFO:lightwood-2698:Loss @ epoch 256: 0.17093656212091446
# INFO:lightwood-2698:Loss @ epoch 257: 0.1709524169564247
# INFO:lightwood-2698:Loss @ epoch 258: 0.17076386511325836
# INFO:lightwood-2698:Loss @ epoch 259: 0.17038153856992722
# INFO:lightwood-2698:Loss @ epoch 260: 0.17028065770864487
# INFO:lightwood-2698:Loss @ epoch 261: 0.17019856721162796
# INFO:lightwood-2698:Loss @ epoch 262: 0.17018349468708038
# INFO:lightwood-2698:Loss @ epoch 263: 0.16999658942222595
# INFO:lightwood-2698:Loss @ epoch 264: 0.1698225438594818
# INFO:lightwood-2698:Loss @ epoch 265: 0.16968444734811783
# INFO:lightwood-2698:Loss @ epoch 266: 0.16946608573198318
# INFO:lightwood-2698:Loss @ epoch 267: 0.1693248152732849
# INFO:lightwood-2698:Loss @ epoch 268: 0.16928566992282867
# INFO:lightwood-2698:Loss @ epoch 269: 0.16924188286066055
# INFO:lightwood-2698:Loss @ epoch 270: 0.16903704404830933
# INFO:lightwood-2698:Loss @ epoch 271: 0.16884467005729675
# INFO:lightwood-2698:Loss @ epoch 272: 0.1686776950955391
# INFO:lightwood-2698:Loss @ epoch 273: 0.1685045138001442
# INFO:lightwood-2698:Loss @ epoch 274: 0.16852892190217972
# INFO:lightwood-2698:Loss @ epoch 275: 0.16837461292743683
# INFO:lightwood-2698:Loss @ epoch 276: 0.16824906319379807
# INFO:lightwood-2698:Loss @ epoch 277: 0.1681346520781517
# INFO:lightwood-2698:Loss @ epoch 278: 0.16794873774051666
# INFO:lightwood-2698:Loss @ epoch 279: 0.16777601093053818
# INFO:lightwood-2698:Loss @ epoch 280: 0.16788572818040848
# INFO:lightwood-2698:Loss @ epoch 281: 0.16775178909301758
# INFO:lightwood-2698:Loss @ epoch 282: 0.16751158237457275
# INFO:lightwood-2698:Loss @ epoch 283: 0.16726744920015335
# INFO:lightwood-2698:Loss @ epoch 284: 0.1672767847776413
# INFO:lightwood-2698:Loss @ epoch 285: 0.16708366572856903
# INFO:lightwood-2698:Loss @ epoch 286: 0.1671437993645668
# INFO:lightwood-2698:Loss @ epoch 287: 0.16694073379039764
# INFO:lightwood-2698:Loss @ epoch 288: 0.16685091704130173
# INFO:lightwood-2698:Loss @ epoch 289: 0.16680964082479477
# INFO:lightwood-2698:Loss @ epoch 290: 0.1666017472743988
# INFO:lightwood-2698:Loss @ epoch 291: 0.16653435677289963
# INFO:lightwood-2698:Loss @ epoch 292: 0.16657016426324844
# INFO:lightwood-2698:Loss @ epoch 293: 0.16637612879276276
# INFO:lightwood-2698:Loss @ epoch 294: 0.1662203073501587
# INFO:lightwood-2698:Loss @ epoch 295: 0.16609467566013336
# INFO:lightwood-2698:Loss @ epoch 296: 0.16607815772294998
# INFO:lightwood-2698:Loss @ epoch 297: 0.16595612466335297
# INFO:lightwood-2698:Loss @ epoch 298: 0.16600461304187775
# INFO:lightwood-2698:Loss @ epoch 299: 0.1658293604850769
# INFO:lightwood-2698:Loss @ epoch 300: 0.16572540998458862
# INFO:lightwood-2698:Loss @ epoch 301: 0.16562112420797348
# INFO:lightwood-2698:Loss @ epoch 302: 0.16550561040639877
# INFO:lightwood-2698:Loss @ epoch 303: 0.16544943302869797
# INFO:lightwood-2698:Loss @ epoch 304: 0.1655188649892807
# INFO:lightwood-2698:Loss @ epoch 305: 0.16532408446073532
# INFO:lightwood-2698:Loss @ epoch 306: 0.1651734709739685
# INFO:lightwood-2698:Loss @ epoch 307: 0.16505476832389832
# INFO:lightwood-2698:Loss @ epoch 308: 0.16501688957214355
# INFO:lightwood-2698:Loss @ epoch 309: 0.16498330980539322
# INFO:lightwood-2698:Loss @ epoch 310: 0.16500603407621384
# INFO:lightwood-2698:Loss @ epoch 311: 0.16491425782442093
# INFO:lightwood-2698:Loss @ epoch 312: 0.16482017934322357
# INFO:lightwood-2698:Loss @ epoch 313: 0.16481488198041916
# INFO:lightwood-2698:Loss @ epoch 314: 0.1645912230014801
# INFO:lightwood-2698:Loss @ epoch 315: 0.16457167267799377
# INFO:lightwood-2698:Loss @ epoch 316: 0.16456732153892517
# INFO:lightwood-2698:Loss @ epoch 317: 0.16445833444595337
# INFO:lightwood-2698:Loss @ epoch 318: 0.1643865704536438
# INFO:lightwood-2698:Loss @ epoch 319: 0.16428104043006897
# INFO:lightwood-2698:Loss @ epoch 320: 0.1641649752855301
# INFO:lightwood-2698:Loss @ epoch 321: 0.16419266164302826
# INFO:lightwood-2698:Loss @ epoch 322: 0.16420342773199081
# INFO:lightwood-2698:Loss @ epoch 323: 0.16403250396251678
# INFO:lightwood-2698:Loss @ epoch 324: 0.16404785215854645
# INFO:lightwood-2698:Loss @ epoch 325: 0.16399074345827103
# INFO:lightwood-2698:Loss @ epoch 326: 0.16380032151937485
# INFO:lightwood-2698:Loss @ epoch 327: 0.1637674793601036
# INFO:lightwood-2698:Loss @ epoch 328: 0.1638527438044548
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2698:Loss @ epoch 1: 0.13275036012584512
# INFO:lightwood-2698:Loss @ epoch 2: 0.13121584396470676
# INFO:lightwood-2698:Loss @ epoch 3: 0.1321793564341285
# INFO:lightwood-2698:Loss @ epoch 4: 0.13170510056343945
# INFO:lightwood-2698:Loss @ epoch 5: 0.13428192111578854
# INFO:lightwood-2698:Started fitting LGBM models for array prediction
# INFO:lightwood-2698:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2698:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2698:Lightgbm model contains 24 weak estimators
# INFO:lightwood-2698:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:Model now has a total of 25 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2698:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2698:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2698:Lightgbm model contains 29 weak estimators
# INFO:lightwood-2698:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:Model now has a total of 30 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2698:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2698:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2698:Lightgbm model contains 24 weak estimators
# INFO:lightwood-2698:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:Model now has a total of 25 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2698:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2698:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2698:Lightgbm model contains 23 weak estimators
# INFO:lightwood-2698:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:Model now has a total of 24 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2698:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2698:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2698:Lightgbm model contains 18 weak estimators
# INFO:lightwood-2698:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:Model now has a total of 19 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2698:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2698:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2698:Lightgbm model contains 20 weak estimators
# INFO:lightwood-2698:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:Model now has a total of 21 weak estimators
# INFO:lightwood-2698:Started fitting sktime forecaster for array prediction
# INFO:lightwood-2698:Ensembling the mixer
# INFO:lightwood-2698:Mixer: Neural got accuracy: 0.5692246242195278
# INFO:lightwood-2698:Mixer: LightGBMArray got accuracy: 0.4470164267347387
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/pmdarima/arima/arima.py:692: UserWarning: As of version 1.5.0 'typ' is no longer a valid arg for predict. In future versions this will raise a TypeError.
#   warnings.warn("As of version 1.5.0 'typ' is no longer a valid "
# INFO:lightwood-2698:Mixer: SkTime got accuracy: 0.202543582497771
# INFO:lightwood-2698:Picked best mixer: Neural
# INFO:lightwood-2698:Analyzing the ensemble of mixers
# INFO:lightwood-2698:The block ICP is now running its analyze() method
# INFO:lightwood-2698:The block AccStats is now running its analyze() method
# INFO:lightwood-2698:Adjustment on validation requested.
# INFO:lightwood-2698:Updating the mixers
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2698:Loss @ epoch 1: 0.13369672683378062
# INFO:lightwood-2698:Loss @ epoch 2: 0.13380325275162855
# INFO:lightwood-2698:Loss @ epoch 3: 0.13298117369413376
# INFO:lightwood-2698:Loss @ epoch 4: 0.13348364209135374
# INFO:lightwood-2698:Loss @ epoch 5: 0.13388391646246114
# INFO:lightwood-2698:Updating array of LGBM models...
# INFO:lightwood-2698:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:Model now has a total of 26 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2698:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:Model now has a total of 31 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2698:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:Model now has a total of 26 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2698:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:Model now has a total of 25 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2698:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:Model now has a total of 20 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2698:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2698:Model now has a total of 22 weak estimators
# INFO:lightwood-2698:Started fitting sktime forecaster for array prediction

# %% [markdown]
# ## Predict
#
# Once the predictor has trained, we can use it to generate 6-month forecasts for each of the test set data points:

# %%
forecasts = predictor.predict(test)
# Out:
# INFO:lightwood-2698:Dropping features: []
# INFO:lightwood-2698:Cleaning the data
# INFO:lightwood-2698:Transforming timeseries data
# INFO:lightwood-2698:Featurizing the data
# INFO:lightwood-2698:The block ICP is now running its explain() method
# INFO:lightwood-2698:The block AccStats is now running its explain() method
# INFO:lightwood-2698:AccStats.explain() has not been implemented, no modifications will be done to the data insights.

# %% [markdown]
# Let's check how a single row might look:

# %%
forecasts.iloc[[10]]
# Out:
#                                            prediction  \
# 10  [73.06599535904427, 72.41663042737521, 75.3824...
#
#                                           order_Month  \
# 10  [-271555200.0, -268876800.0, -266198400.0, -26...
#
#                               confidence  \
# 10  [0.74, 0.74, 0.74, 0.74, 0.74, 0.74]
#
#                                                 lower  \
# 10  [51.90934947765348, 51.25998454598442, 54.2257...
#
#                                                 upper
# 10  [94.22264124043505, 93.573276308766, 96.539056...

# %% [markdown]
# You'll note that the point `prediction` has associated `lower` and `upper` bounds that are a function of the estimated `confidence` the model has on its own output. Apart from this, `order_Month` yields the timestamps of each prediction, the `anomaly` tag will let you know if the observed value falls outside of the predicted region.
#
#
# ## Visualizing a forecast
#
# Okay, time series are much easier to appreciate through plots. Let's make one:
#
# NOTE: We will use `matplotlib` to generate a simple plot of these forecasts. If you want to run this notebook locally, you will need to `pip install matplotlib` for the following code to work.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['prediction'], color='purple', label='point prediction')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['lower'], color='grey')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['upper'], color='grey')
plt.xlabel('timestep')
plt.ylabel('# sunspots')
plt.title("Forecasted amount of sunspots for the next semester")
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we have gone through how you can train a machine learning model with Lightwood to produce forecasts for a univariate time series task.
#
# There are additional parameters to further customize your timeseries settings and/or prediction insights, so be sure to check the rest of the documentation.
