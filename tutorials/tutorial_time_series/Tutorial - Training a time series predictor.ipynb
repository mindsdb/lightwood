# %% [markdown]
# # Tutorial - Time series forecasting
#
# ## Introduction
#
# Time series are an ubiquitous type of data in all types of processes. Producing forecasts for them can be highly valuable in domains like retail or industrial manufacture, among many others.
#
# Lightwood supports time series forecasting (both univariate and multivariate inputs), handling many of the pain points commonly associated with setting up a manual time series predictive pipeline.
#
# In this tutorial, we will train a lightwood predictor and analyze its forecasts for the task of counting sunspots in monthly intervals.
#
# ## Load data
#
# Let's begin by loading the dataset and looking at it:

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/mindsdb/benchmarks/main/benchmarks/datasets/monthly_sunspots/data.csv")
df
# Out:
#         Month  Sunspots
# 0     1749-01      58.0
# 1     1749-02      62.6
# 2     1749-03      70.0
# 3     1749-04      55.7
# 4     1749-05      85.0
# ...       ...       ...
# 2815  1983-08      71.8
# 2816  1983-09      50.3
# 2817  1983-10      55.8
# 2818  1983-11      33.3
# 2819  1983-12      33.4
#
# [2820 rows x 2 columns]

# %% [markdown]
# This is a very simple dataset. It's got a single column that specifies the month in which the measurement was done, and then in the 'Sunspots' column we have the actual quantity we are interested in forecasting. As such, we can characterize this as a univariate time series problem.
#
# ## Define the predictive task
#
# We will use Lightwood high level methods to state what we want to predict. As this is a time series task (because we want to leverage the notion of time to predict), we need to specify a set of arguments that will activate Lightwood's time series pipeline:

# %%
from lightwood.api.high_level import ProblemDefinition
# Out:
# [nltk_data] Downloading package punkt to /home/runner/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
tss = {'nr_predictions': 6,   # the predictor will learn to forecast what the next semester counts will look like (6 data points at monthly intervals -> 6 months)
       'order_by': ['Month'], # what column is used to order the entire datset
       'window': 12           # how many past values to consider for emitting predictions
      }

pdef = ProblemDefinition.from_dict({'target': 'Sunspots',         # specify the column to forecast
                                    'timeseries_settings': tss    # pass along all time series specific parameters
                                   })

# %% [markdown]
# Now, let's do a very simple train-test split, leaving 10% of the data to check the forecasts that our predictor will produce:

# %%
cutoff = int(len(df)*0.9)

train = df[:cutoff]
test = df[cutoff:]

print(train.shape, test.shape)
# Out:
# (2538, 2) (282, 2)

# %% [markdown]
# ## Generate the predictor object
#
# Now, we can generate code for a machine learning model by using our problem definition and the data:

# %%
from lightwood.api.high_level import (
    json_ai_from_problem,
    code_from_json_ai,
    predictor_from_code
)

json_ai = json_ai_from_problem(df, problem_definition=pdef)
code = code_from_json_ai(json_ai)
predictor = predictor_from_code(code)

# uncomment this to see the generated code:
# print(code)
# Out:
# INFO:lightwood-2272:Dropping features: []
# INFO:lightwood-2272:Analyzing a sample of 2467
# INFO:lightwood-2272:from a total population of 2820, this is equivalent to 87.5% of your data.
# INFO:lightwood-2272:Infering type for: Month
# INFO:lightwood-2272:Column Month has data type date
# INFO:lightwood-2272:Infering type for: Sunspots
# INFO:lightwood-2272:Column Sunspots has data type float
# /home/runner/work/lightwood/lightwood/lightwood/helpers/text.py:236: RuntimeWarning: invalid value encountered in double_scalars
#   randomness_per_index.append(S / np.log(N))
# INFO:lightwood-2272:Starting statistical analysis
# INFO:lightwood-2272:Finished statistical analysis
# INFO:lightwood-2272:Unable to import black formatter, predictor code might be a bit ugly.

# %% [markdown]
# ## Train
#
# Okay, everything is ready now for our predictor to learn based on the training data we will provide.
#
# Internally, lightwood cleans and reshapes the data, featurizes measurements and timestamps, and comes up with a handful of different models that will be evaluated to keep the one that produces the best forecasts.
#
# Let's train the predictor. This should take a couple of minutes, at most:

# %%
predictor.learn(train)
# Out:
# INFO:lightwood-2272:Dropping features: []
# INFO:lightwood-2272:Performing statistical analysis on data
# INFO:lightwood-2272:Starting statistical analysis
# INFO:lightwood-2272:Finished statistical analysis
# INFO:lightwood-2272:Cleaning the data
# INFO:lightwood-2272:Transforming timeseries data
# INFO:lightwood-2272:Using 1 processes to reshape.
# INFO:lightwood-2272:Splitting the data into train/test
# INFO:lightwood-2272:Preparing the encoders
# INFO:lightwood-2272:Encoder prepping dict length of: 1
# INFO:lightwood-2272:Done running for: Sunspots
# INFO:lightwood-2272:time series encoder epoch [1/100000] average_loss = 0.018415506234447283
# INFO:lightwood-2272:time series encoder epoch [2/100000] average_loss = 0.007314067861917721
# INFO:lightwood-2272:time series encoder epoch [3/100000] average_loss = 0.005609883556976921
# INFO:lightwood-2272:time series encoder epoch [4/100000] average_loss = 0.0048330749739361935
# INFO:lightwood-2272:time series encoder epoch [5/100000] average_loss = 0.004470130287277536
# INFO:lightwood-2272:time series encoder epoch [6/100000] average_loss = 0.004392791861450008
# INFO:lightwood-2272:time series encoder epoch [7/100000] average_loss = 0.004247126505007708
# INFO:lightwood-2272:time series encoder epoch [8/100000] average_loss = 0.0042891268041794
# INFO:lightwood-2272:time series encoder epoch [9/100000] average_loss = 0.004214218908781125
# INFO:lightwood-2272:time series encoder epoch [10/100000] average_loss = 0.004204119805339765
# INFO:lightwood-2272:time series encoder epoch [11/100000] average_loss = 0.004162483567886051
# INFO:lightwood-2272:time series encoder epoch [12/100000] average_loss = 0.0041568696158870684
# INFO:lightwood-2272:time series encoder epoch [13/100000] average_loss = 0.004140803064887803
# INFO:lightwood-2272:time series encoder epoch [14/100000] average_loss = 0.004104613525504446
# INFO:lightwood-2272:time series encoder epoch [15/100000] average_loss = 0.00409198241466072
# INFO:lightwood-2272:time series encoder epoch [16/100000] average_loss = 0.004057748687010996
# INFO:lightwood-2272:time series encoder epoch [17/100000] average_loss = 0.004041305232748958
# INFO:lightwood-2272:time series encoder epoch [18/100000] average_loss = 0.004050599503485766
# INFO:lightwood-2272:time series encoder epoch [19/100000] average_loss = 0.004070517210230173
# INFO:lightwood-2272:time series encoder epoch [20/100000] average_loss = 0.004072533672762942
# INFO:lightwood-2272:time series encoder epoch [21/100000] average_loss = 0.004025135818622049
# INFO:lightwood-2272:time series encoder epoch [22/100000] average_loss = 0.0038934281098314313
# INFO:lightwood-2272:time series encoder epoch [23/100000] average_loss = 0.0038381411141081303
# INFO:lightwood-2272:time series encoder epoch [24/100000] average_loss = 0.003929717465417853
# INFO:lightwood-2272:time series encoder epoch [25/100000] average_loss = 0.0039778590045408384
# INFO:lightwood-2272:time series encoder epoch [26/100000] average_loss = 0.0038132165387410144
# INFO:lightwood-2272:time series encoder epoch [27/100000] average_loss = 0.003979220953673948
# INFO:lightwood-2272:time series encoder epoch [28/100000] average_loss = 0.003830171797870805
# INFO:lightwood-2272:time series encoder epoch [29/100000] average_loss = 0.0038710732426545033
# INFO:lightwood-2272:time series encoder epoch [30/100000] average_loss = 0.003766286773292471
# INFO:lightwood-2272:time series encoder epoch [31/100000] average_loss = 0.0037920859729370145
# INFO:lightwood-2272:time series encoder epoch [32/100000] average_loss = 0.0037127090368735366
# INFO:lightwood-2272:time series encoder epoch [33/100000] average_loss = 0.0036698430318903535
# INFO:lightwood-2272:time series encoder epoch [34/100000] average_loss = 0.0037480704666177866
# INFO:lightwood-2272:time series encoder epoch [35/100000] average_loss = 0.003730369064043153
# INFO:lightwood-2272:time series encoder epoch [36/100000] average_loss = 0.003764706936359615
# INFO:lightwood-2272:time series encoder epoch [37/100000] average_loss = 0.0038263771606150718
# INFO:lightwood-2272:Featurizing the data
# INFO:lightwood-2272:Training the mixers
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2272:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2272:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2272:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2272:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2272:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2272:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/pytorch_ranger/ranger.py:172: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1025.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# INFO:lightwood-2272:Loss of 0.6577673554420471 with learning rate 0.0001
# INFO:lightwood-2272:Loss of 0.757037341594696 with learning rate 0.00014
# INFO:lightwood-2272:Found learning rate of: 0.0001
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2272:Loss @ epoch 1: 0.6906661540269852
# INFO:lightwood-2272:Loss @ epoch 2: 0.6878491342067719
# INFO:lightwood-2272:Loss @ epoch 3: 0.68440181016922
# INFO:lightwood-2272:Loss @ epoch 4: 0.6803991794586182
# INFO:lightwood-2272:Loss @ epoch 5: 0.6759125143289566
# INFO:lightwood-2272:Loss @ epoch 6: 0.6709996461868286
# INFO:lightwood-2272:Loss @ epoch 7: 0.6623700559139252
# INFO:lightwood-2272:Loss @ epoch 8: 0.6564162075519562
# INFO:lightwood-2272:Loss @ epoch 9: 0.6501653790473938
# INFO:lightwood-2272:Loss @ epoch 10: 0.6436219960451126
# INFO:lightwood-2272:Loss @ epoch 11: 0.636842280626297
# INFO:lightwood-2272:Loss @ epoch 12: 0.6298393607139587
# INFO:lightwood-2272:Loss @ epoch 13: 0.6181558966636658
# INFO:lightwood-2272:Loss @ epoch 14: 0.6104386746883392
# INFO:lightwood-2272:Loss @ epoch 15: 0.6024721711874008
# INFO:lightwood-2272:Loss @ epoch 16: 0.5942974388599396
# INFO:lightwood-2272:Loss @ epoch 17: 0.5859730094671249
# INFO:lightwood-2272:Loss @ epoch 18: 0.5776587426662445
# INFO:lightwood-2272:Loss @ epoch 19: 0.5643730461597443
# INFO:lightwood-2272:Loss @ epoch 20: 0.5560251325368881
# INFO:lightwood-2272:Loss @ epoch 21: 0.5477806329727173
# INFO:lightwood-2272:Loss @ epoch 22: 0.5397049784660339
# INFO:lightwood-2272:Loss @ epoch 23: 0.5316976010799408
# INFO:lightwood-2272:Loss @ epoch 24: 0.5237874984741211
# INFO:lightwood-2272:Loss @ epoch 25: 0.5111135840415955
# INFO:lightwood-2272:Loss @ epoch 26: 0.5031179040670395
# INFO:lightwood-2272:Loss @ epoch 27: 0.49511872231960297
# INFO:lightwood-2272:Loss @ epoch 28: 0.48711858689785004
# INFO:lightwood-2272:Loss @ epoch 29: 0.4791778326034546
# INFO:lightwood-2272:Loss @ epoch 30: 0.47135505080223083
# INFO:lightwood-2272:Loss @ epoch 31: 0.4588877856731415
# INFO:lightwood-2272:Loss @ epoch 32: 0.4511416256427765
# INFO:lightwood-2272:Loss @ epoch 33: 0.44344839453697205
# INFO:lightwood-2272:Loss @ epoch 269: 0.1833430901169777
# INFO:lightwood-2272:Loss @ epoch 270: 0.18322459608316422
# INFO:lightwood-2272:Loss @ epoch 271: 0.18301136046648026
# INFO:lightwood-2272:Loss @ epoch 272: 0.18287056684494019
# INFO:lightwood-2272:Loss @ epoch 273: 0.18271945416927338
# INFO:lightwood-2272:Loss @ epoch 274: 0.18277768045663834
# INFO:lightwood-2272:Loss @ epoch 275: 0.1825171858072281
# INFO:lightwood-2272:Loss @ epoch 276: 0.1824178248643875
# INFO:lightwood-2272:Loss @ epoch 277: 0.18219983577728271
# INFO:lightwood-2272:Loss @ epoch 278: 0.1821255162358284
# INFO:lightwood-2272:Loss @ epoch 279: 0.18198125809431076
# INFO:lightwood-2272:Loss @ epoch 280: 0.18187934160232544
# INFO:lightwood-2272:Loss @ epoch 281: 0.18174219876527786
# INFO:lightwood-2272:Loss @ epoch 282: 0.18162601441144943
# INFO:lightwood-2272:Loss @ epoch 283: 0.18154454231262207
# INFO:lightwood-2272:Loss @ epoch 284: 0.18140721321105957
# INFO:lightwood-2272:Loss @ epoch 285: 0.1812911480665207
# INFO:lightwood-2272:Loss @ epoch 286: 0.1814015954732895
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2272:Loss @ epoch 1: 0.14731487360867587
# INFO:lightwood-2272:Loss @ epoch 2: 0.1461266644976356
# INFO:lightwood-2272:Loss @ epoch 3: 0.14640462669459256
# INFO:lightwood-2272:Loss @ epoch 4: 0.15291502665389667
# INFO:lightwood-2272:Loss @ epoch 5: 0.14691886576739224
# INFO:lightwood-2272:Loss @ epoch 6: 0.1477341733195565
# INFO:lightwood-2272:Loss @ epoch 7: 0.1471941891041669
# INFO:lightwood-2272:Loss @ epoch 8: 0.1462243375453082
# INFO:lightwood-2272:Loss @ epoch 9: 0.14493380893360486
# INFO:lightwood-2272:Loss @ epoch 10: 0.1450034799900922
# INFO:lightwood-2272:Loss @ epoch 11: 0.14384442432360214
# INFO:lightwood-2272:Loss @ epoch 12: 0.1455244774168188
# INFO:lightwood-2272:Started fitting LGBM models for array prediction
# INFO:lightwood-2272:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2272:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2272:Lightgbm model contains 27 weak estimators
# INFO:lightwood-2272:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:Model now has a total of 28 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2272:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2272:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2272:Lightgbm model contains 45 weak estimators
# INFO:lightwood-2272:Updating lightgbm model with 2.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:Model now has a total of 47 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2272:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2272:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2272:Lightgbm model contains 25 weak estimators
# INFO:lightwood-2272:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:Model now has a total of 26 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2272:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2272:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2272:Lightgbm model contains 19 weak estimators
# INFO:lightwood-2272:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:Model now has a total of 20 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2272:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2272:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2272:Lightgbm model contains 24 weak estimators
# INFO:lightwood-2272:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:Model now has a total of 25 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2272:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2272:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2272:Lightgbm model contains 18 weak estimators
# INFO:lightwood-2272:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:Model now has a total of 19 weak estimators
# INFO:lightwood-2272:Started fitting sktime forecaster for array prediction
# INFO:lightwood-2272:Ensembling the mixer
# INFO:lightwood-2272:Mixer: Neural got accuracy: 0.5519557825691912
# INFO:lightwood-2272:Mixer: LightGBMArray got accuracy: 0.42732942183378736
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/pmdarima/arima/arima.py:692: UserWarning: As of version 1.5.0 'typ' is no longer a valid arg for predict. In future versions this will raise a TypeError.
#   warnings.warn("As of version 1.5.0 'typ' is no longer a valid "
# INFO:lightwood-2272:Mixer: SkTime got accuracy: 0.202543582497771
# INFO:lightwood-2272:Picked best mixer: Neural
# INFO:lightwood-2272:Analyzing the ensemble of mixers
# INFO:lightwood-2272:The block ICP is now running its analyze() method
# INFO:lightwood-2272:The block AccStats is now running its analyze() method
# INFO:lightwood-2272:Adjustment on validation requested.
# INFO:lightwood-2272:Updating the mixers
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2272:Loss @ epoch 1: 0.14752244328459105
# INFO:lightwood-2272:Loss @ epoch 2: 0.14769836266835532
# INFO:lightwood-2272:Loss @ epoch 3: 0.14839962994058928
# INFO:lightwood-2272:Loss @ epoch 4: 0.14840721090634665
# INFO:lightwood-2272:Loss @ epoch 5: 0.14809029176831245
# INFO:lightwood-2272:Loss @ epoch 6: 0.14898723860581717
# INFO:lightwood-2272:Updating array of LGBM models...
# INFO:lightwood-2272:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:Model now has a total of 29 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2272:Updating lightgbm model with 2.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:Model now has a total of 49 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2272:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:Model now has a total of 27 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2272:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:Model now has a total of 21 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2272:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:Model now has a total of 26 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2272:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2272:Model now has a total of 20 weak estimators
# INFO:lightwood-2272:Started fitting sktime forecaster for array prediction

# %% [markdown]
# ## Predict
#
# Once the predictor has trained, we can use it to generate 6-month forecasts for each of the test set data points:

# %%
forecasts = predictor.predict(test)
# Out:
# INFO:lightwood-2272:Dropping features: []
# INFO:lightwood-2272:Cleaning the data
# INFO:lightwood-2272:Transforming timeseries data
# INFO:lightwood-2272:Featurizing the data
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# INFO:lightwood-2272:The block ICP is now running its explain() method
# INFO:lightwood-2272:The block AccStats is now running its explain() method
# INFO:lightwood-2272:AccStats.explain() has not been implemented, no modifications will be done to the data insights.

# %% [markdown]
# Let's check how a single row might look:

# %%
forecasts.iloc[[10]]
# Out:
#                                            prediction  truth  \
# 10  [72.72915575618333, 71.88690022158487, 69.4850...   51.0
#
#                                           order_Month  \
# 10  [-272592000.0, -269913600.0, -267235200.0, -26...
#
#                               confidence  \
# 10  [0.72, 0.72, 0.72, 0.72, 0.72, 0.72]
#
#                                                 lower  \
# 10  [52.71634551452513, 51.874089979926666, 49.472...
#
#                                                 upper  anomaly
# 10  [92.74196599784153, 91.89971046324307, 89.4978...     True

# %% [markdown]
# You'll note that the point `prediction` has associated `lower` and `upper` bounds that are a function of the estimated `confidence` the model has on its own output. Apart from this, `order_Month` yields the timestamps of each prediction, `truth` lets us know what is the one-step-ahead observed value (if it exists at all). Finally, the `anomaly` tag will let you know if the observed value falls outside of the predicted region.
#
#
# ## Visualizing a forecast
#
# Okay, time series are much easier to appreciate through plots. Let's make one:
#
# NOTE: We will use `matplotlib` to generate a simple plot of these forecasts. If you want to run this notebook locally, you will need to `pip install matplotlib` for the following code to work.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.plot(forecasts['truth'].iloc[-24:], color='green', label='observed series')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['prediction'], color='purple', label='point prediction')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['lower'], color='grey')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['upper'], color='grey')
plt.xlabel('timestep')
plt.ylabel('# sunspots')
plt.title("Forecasted amount of sunspots for the next semester")
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we have gone through how you can train a machine learning model with Lightwood to produce forecasts for a univariate time series task.
#
# There are additional parameters to further customize your timeseries settings and/or prediction insights, so be sure to check the rest of the documentation.
