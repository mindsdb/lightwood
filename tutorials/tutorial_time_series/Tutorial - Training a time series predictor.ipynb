# %% [markdown]
# # Tutorial - Time series forecasting
#
# ## Introduction
#
# Time series are an ubiquitous type of data in all types of processes. Producing forecasts for them can be highly valuable in domains like retail or industrial manufacture, among many others.
#
# Lightwood supports time series forecasting (both univariate and multivariate inputs), handling many of the pain points commonly associated with setting up a manual time series predictive pipeline.
#
# In this tutorial, we will train a lightwood predictor and analyze its forecasts for the task of counting sunspots in monthly intervals.
#
# ## Load data
#
# Let's begin by loading the dataset and looking at it:

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/mindsdb/benchmarks/main/benchmarks/datasets/monthly_sunspots/data.csv")
df
# Out:
#         Month  Sunspots
# 0     1749-01      58.0
# 1     1749-02      62.6
# 2     1749-03      70.0
# 3     1749-04      55.7
# 4     1749-05      85.0
# ...       ...       ...
# 2815  1983-08      71.8
# 2816  1983-09      50.3
# 2817  1983-10      55.8
# 2818  1983-11      33.3
# 2819  1983-12      33.4
#
# [2820 rows x 2 columns]

# %% [markdown]
# This is a very simple dataset. It's got a single column that specifies the month in which the measurement was done, and then in the 'Sunspots' column we have the actual quantity we are interested in forecasting. As such, we can characterize this as a univariate time series problem.
#
# ## Define the predictive task
#
# We will use Lightwood high level methods to state what we want to predict. As this is a time series task (because we want to leverage the notion of time to predict), we need to specify a set of arguments that will activate Lightwood's time series pipeline:

# %%
from lightwood.api.high_level import ProblemDefinition
# Out:
# INFO:lightwood-2339:No torchvision detected, image helpers not supported.
# INFO:lightwood-2339:No torchvision/pillow detected, image encoder not supported

# %%
tss = {'nr_predictions': 6,   # the predictor will learn to forecast what the next semester counts will look like (6 data points at monthly intervals -> 6 months)
       'order_by': ['Month'], # what column is used to order the entire datset
       'window': 12           # how many past values to consider for emitting predictions
      }

pdef = ProblemDefinition.from_dict({'target': 'Sunspots',         # specify the column to forecast
                                    'timeseries_settings': tss    # pass along all time series specific parameters
                                   })

# %% [markdown]
# Now, let's do a very simple train-test split, leaving 10% of the data to check the forecasts that our predictor will produce:

# %%
cutoff = int(len(df)*0.9)

train = df[:cutoff]
test = df[cutoff:]

print(train.shape, test.shape)
# Out:
# (2538, 2) (282, 2)

# %% [markdown]
# ## Generate the predictor object
#
# Now, we can generate code for a machine learning model by using our problem definition and the data:

# %%
from lightwood.api.high_level import (
    json_ai_from_problem,
    code_from_json_ai,
    predictor_from_code
)

json_ai = json_ai_from_problem(df, problem_definition=pdef)
code = code_from_json_ai(json_ai)
predictor = predictor_from_code(code)

# uncomment this to see the generated code:
# print(code)
# Out:
# INFO:lightwood-2339:Dropping features: []
# INFO:lightwood-2339:Analyzing a sample of 2467
# INFO:lightwood-2339:from a total population of 2820, this is equivalent to 87.5% of your data.
# INFO:lightwood-2339:Infering type for: Month
# INFO:lightwood-2339:Column Month has data type date
# INFO:lightwood-2339:Infering type for: Sunspots
# INFO:lightwood-2339:Column Sunspots has data type float
# /home/runner/work/lightwood/lightwood/lightwood/helpers/text.py:242: RuntimeWarning: invalid value encountered in double_scalars
#   randomness_per_index.append(S / np.log(N))
# INFO:lightwood-2339:Starting statistical analysis
# INFO:lightwood-2339:Finished statistical analysis
# INFO:lightwood-2339:Unable to import black formatter, predictor code might be a bit ugly.

# %% [markdown]
# ## Train
#
# Okay, everything is ready now for our predictor to learn based on the training data we will provide.
#
# Internally, lightwood cleans and reshapes the data, featurizes measurements and timestamps, and comes up with a handful of different models that will be evaluated to keep the one that produces the best forecasts.
#
# Let's train the predictor. This should take a couple of minutes, at most:

# %%
predictor.learn(train)
# Out:
# INFO:lightwood-2339:Dropping features: []
# INFO:lightwood-2339:Performing statistical analysis on data
# INFO:lightwood-2339:Starting statistical analysis
# INFO:lightwood-2339:Finished statistical analysis
# INFO:lightwood-2339:Cleaning the data
# INFO:lightwood-2339:Transforming timeseries data
# INFO:lightwood-2339:Using 1 processes to reshape.
# INFO:lightwood-2339:Splitting the data into train/test
# INFO:lightwood-2339:Preparing the encoders
# INFO:lightwood-2339:Encoder prepping dict length of: 1
# INFO:lightwood-2339:Done running for: Sunspots
# INFO:lightwood-2339:time series encoder epoch [1/100000] average_loss = 0.01843290367602467
# INFO:lightwood-2339:time series encoder epoch [2/100000] average_loss = 0.007156400828770706
# INFO:lightwood-2339:time series encoder epoch [3/100000] average_loss = 0.005600586376966821
# INFO:lightwood-2339:time series encoder epoch [4/100000] average_loss = 0.004798773212942267
# INFO:lightwood-2339:time series encoder epoch [5/100000] average_loss = 0.004521547521475944
# INFO:lightwood-2339:time series encoder epoch [6/100000] average_loss = 0.004395283928268219
# INFO:lightwood-2339:time series encoder epoch [7/100000] average_loss = 0.004274004134113024
# INFO:lightwood-2339:time series encoder epoch [8/100000] average_loss = 0.004281672256005416
# INFO:lightwood-2339:time series encoder epoch [9/100000] average_loss = 0.004204172621466442
# INFO:lightwood-2339:time series encoder epoch [10/100000] average_loss = 0.00419766248420742
# INFO:lightwood-2339:time series encoder epoch [11/100000] average_loss = 0.004161955752848744
# INFO:lightwood-2339:time series encoder epoch [12/100000] average_loss = 0.0041722538383537336
# INFO:lightwood-2339:time series encoder epoch [13/100000] average_loss = 0.004164086514513046
# INFO:lightwood-2339:time series encoder epoch [14/100000] average_loss = 0.004133207524511735
# INFO:lightwood-2339:time series encoder epoch [15/100000] average_loss = 0.004137708144931159
# INFO:lightwood-2339:time series encoder epoch [16/100000] average_loss = 0.004116830130592119
# INFO:lightwood-2339:time series encoder epoch [17/100000] average_loss = 0.00413588302669926
# INFO:lightwood-2339:time series encoder epoch [18/100000] average_loss = 0.004220760040859416
# INFO:lightwood-2339:time series encoder epoch [19/100000] average_loss = 0.004220088183775466
# INFO:lightwood-2339:time series encoder epoch [20/100000] average_loss = 0.004122402381980482
# INFO:lightwood-2339:time series encoder epoch [21/100000] average_loss = 0.004018332489526418
# INFO:lightwood-2339:time series encoder epoch [22/100000] average_loss = 0.003861745711800931
# INFO:lightwood-2339:time series encoder epoch [23/100000] average_loss = 0.0038220164759146563
# INFO:lightwood-2339:time series encoder epoch [24/100000] average_loss = 0.0038303530623324073
# INFO:lightwood-2339:time series encoder epoch [25/100000] average_loss = 0.003749249721575535
# INFO:lightwood-2339:time series encoder epoch [26/100000] average_loss = 0.0037430172782854524
# INFO:lightwood-2339:time series encoder epoch [27/100000] average_loss = 0.003901398236718153
# INFO:lightwood-2339:time series encoder epoch [28/100000] average_loss = 0.0041569730498536035
# INFO:lightwood-2339:time series encoder epoch [29/100000] average_loss = 0.00378132244855844
# INFO:lightwood-2339:time series encoder epoch [30/100000] average_loss = 0.0038590496715856307
# INFO:lightwood-2339:time series encoder epoch [31/100000] average_loss = 0.003896903344503426
# INFO:lightwood-2339:time series encoder epoch [32/100000] average_loss = 0.003759696544678115
# INFO:lightwood-2339:time series encoder epoch [33/100000] average_loss = 0.0036734867899722687
# INFO:lightwood-2339:time series encoder epoch [34/100000] average_loss = 0.0037662841888526275
# INFO:lightwood-2339:time series encoder epoch [35/100000] average_loss = 0.0036785009132792776
# INFO:lightwood-2339:time series encoder epoch [36/100000] average_loss = 0.003746514171100957
# INFO:lightwood-2339:time series encoder epoch [37/100000] average_loss = 0.003815096909026966
# INFO:lightwood-2339:Featurizing the data
# INFO:lightwood-2339:Training the mixers
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2339:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2339:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2339:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2339:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2339:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2339:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/pytorch_ranger/ranger.py:172: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1025.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# INFO:lightwood-2339:Loss of 0.6321964263916016 with learning rate 0.0001
# INFO:lightwood-2339:Loss of 0.7140899896621704 with learning rate 0.00014
# INFO:lightwood-2339:Found learning rate of: 0.0001
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2339:Loss @ epoch 1: 0.6531286835670471
# INFO:lightwood-2339:Loss @ epoch 2: 0.6506245583295822
# INFO:lightwood-2339:Loss @ epoch 3: 0.6475531607866287
# INFO:lightwood-2339:Loss @ epoch 4: 0.643964022397995
# INFO:lightwood-2339:Loss @ epoch 5: 0.6399384289979935
# INFO:lightwood-2339:Loss @ epoch 6: 0.6355404704809189
# INFO:lightwood-2339:Loss @ epoch 7: 0.6278322488069534
# INFO:lightwood-2339:Loss @ epoch 8: 0.6224851757287979
# INFO:lightwood-2339:Loss @ epoch 9: 0.6168435513973236
# INFO:lightwood-2339:Loss @ epoch 10: 0.6109253466129303
# INFO:lightwood-2339:Loss @ epoch 11: 0.6047475039958954
# INFO:lightwood-2339:Loss @ epoch 12: 0.5983649045228958
# INFO:lightwood-2339:Loss @ epoch 13: 0.5877244621515274
# INFO:lightwood-2339:Loss @ epoch 14: 0.5807344615459442
# INFO:lightwood-2339:Loss @ epoch 15: 0.5735640823841095
# INFO:lightwood-2339:Loss @ epoch 16: 0.5662230402231216
# INFO:lightwood-2339:Loss @ epoch 17: 0.5587218105792999
# INFO:lightwood-2339:Loss @ epoch 18: 0.5510770678520203
# INFO:lightwood-2339:Loss @ epoch 19: 0.5385252386331558
# INFO:lightwood-2339:Loss @ epoch 20: 0.530552089214325
# INFO:lightwood-2339:Loss @ epoch 21: 0.5226694494485855
# INFO:lightwood-2339:Loss @ epoch 22: 0.5148765742778778
# INFO:lightwood-2339:Loss @ epoch 23: 0.5071615725755692
# INFO:lightwood-2339:Loss @ epoch 24: 0.4995679557323456
# INFO:lightwood-2339:Loss @ epoch 25: 0.487431600689888
# INFO:lightwood-2339:Loss @ epoch 26: 0.47972600162029266
# INFO:lightwood-2339:Loss @ epoch 27: 0.4719661772251129
# INFO:lightwood-2339:Loss @ epoch 28: 0.46418802440166473
# INFO:lightwood-2339:Loss @ epoch 29: 0.45643846690654755
# INFO:lightwood-2339:Loss @ epoch 215: 0.17974595725536346
# INFO:lightwood-2339:Loss @ epoch 216: 0.1793823540210724
# INFO:lightwood-2339:Loss @ epoch 217: 0.1791897639632225
# INFO:lightwood-2339:Loss @ epoch 218: 0.1789385974407196
# INFO:lightwood-2339:Loss @ epoch 219: 0.17897098511457443
# INFO:lightwood-2339:Loss @ epoch 220: 0.1787709966301918
# INFO:lightwood-2339:Loss @ epoch 221: 0.1785549893975258
# INFO:lightwood-2339:Loss @ epoch 222: 0.17837409675121307
# INFO:lightwood-2339:Loss @ epoch 223: 0.17820098251104355
# INFO:lightwood-2339:Loss @ epoch 224: 0.17789452522993088
# INFO:lightwood-2339:Loss @ epoch 225: 0.1780540868639946
# INFO:lightwood-2339:Loss @ epoch 226: 0.1780015155673027
# INFO:lightwood-2339:Loss @ epoch 227: 0.17775917053222656
# INFO:lightwood-2339:Loss @ epoch 228: 0.1773882880806923
# INFO:lightwood-2339:Loss @ epoch 229: 0.17724047601222992
# INFO:lightwood-2339:Loss @ epoch 230: 0.1770026683807373
# INFO:lightwood-2339:Loss @ epoch 231: 0.17702509462833405
# INFO:lightwood-2339:Loss @ epoch 232: 0.17698559165000916
# INFO:lightwood-2339:Loss @ epoch 233: 0.17672239243984222
# INFO:lightwood-2339:Loss @ epoch 234: 0.17643330246210098
# INFO:lightwood-2339:Loss @ epoch 235: 0.17642926424741745
# INFO:lightwood-2339:Loss @ epoch 236: 0.1761656552553177
# INFO:lightwood-2339:Loss @ epoch 237: 0.17628611624240875
# INFO:lightwood-2339:Loss @ epoch 238: 0.17635143548250198
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2339:Loss @ epoch 1: 0.13952374322847885
# INFO:lightwood-2339:Loss @ epoch 2: 0.1385807604952292
# INFO:lightwood-2339:Loss @ epoch 3: 0.13794451816515488
# INFO:lightwood-2339:Loss @ epoch 4: 0.13788499209013852
# INFO:lightwood-2339:Loss @ epoch 5: 0.13978164168921384
# INFO:lightwood-2339:Started fitting LGBM models for array prediction
# INFO:lightwood-2339:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2339:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37794 iterations given 4724.342236280441 seconds constraint
# INFO:lightwood-2339:Lightgbm model contains 30 weak estimators
# INFO:lightwood-2339:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 31 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2339:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37793 iterations given 4724.204599618912 seconds constraint
# INFO:lightwood-2339:Lightgbm model contains 30 weak estimators
# INFO:lightwood-2339:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 31 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2339:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37793 iterations given 4724.199692964554 seconds constraint
# INFO:lightwood-2339:Lightgbm model contains 28 weak estimators
# INFO:lightwood-2339:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 29 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2339:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37792 iterations given 4724.037637710571 seconds constraint
# INFO:lightwood-2339:Lightgbm model contains 38 weak estimators
# INFO:lightwood-2339:Updating lightgbm model with 2.0 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 40 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2339:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37792 iterations given 4724.047411680222 seconds constraint
# INFO:lightwood-2339:Lightgbm model contains 21 weak estimators
# INFO:lightwood-2339:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 22 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2339:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37793 iterations given 4724.245039701462 seconds constraint
# INFO:lightwood-2339:Lightgbm model contains 23 weak estimators
# INFO:lightwood-2339:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 24 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = original_target_train
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = original_target_dev
# INFO:lightwood-2339:Started fitting sktime forecaster for array prediction
# INFO:lightwood-2339:Ensembling the mixer
# INFO:lightwood-2339:Mixer: Neural got accuracy: 0.5337441210503763
# WARNING:lightwood-2339:This model does not output probability estimates
# INFO:lightwood-2339:Mixer: LightGBMArray got accuracy: 0.47486041234030274
# WARNING:lightwood-2339:This mixer does not output probability estimates
# INFO:lightwood-2339:Mixer: SkTime got accuracy: 0.21481464258617453
# INFO:lightwood-2339:Picked best mixer: Neural
# INFO:lightwood-2339:Analyzing the ensemble of mixers
# INFO:lightwood-2339:The block ICP is now running its analyze() method
# INFO:lightwood-2339:The block AccStats is now running its analyze() method
# INFO:lightwood-2339:Adjustment on validation requested.
# INFO:lightwood-2339:Updating the mixers
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2339:Loss @ epoch 1: 0.14068967352310816
# INFO:lightwood-2339:Loss @ epoch 2: 0.13892031585176787
# INFO:lightwood-2339:Loss @ epoch 3: 0.14056562259793282
# INFO:lightwood-2339:Loss @ epoch 4: 0.14060896014173827
# INFO:lightwood-2339:Loss @ epoch 5: 0.14023192847768465
# INFO:lightwood-2339:Loss @ epoch 6: 0.140409454703331
# INFO:lightwood-2339:Updating array of LGBM models...
# INFO:lightwood-2339:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 32 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 32 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 30 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Updating lightgbm model with 2.0 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 42 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 23 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2339:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2339:Model now has a total of 25 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = original_target_train
# INFO:lightwood-2339:Started fitting sktime forecaster for array prediction

# %% [markdown]
# ## Predict
#
# Once the predictor has trained, we can use it to generate 6-month forecasts for each of the test set data points:

# %%
forecasts = predictor.predict(test)
# Out:
# INFO:lightwood-2339:Dropping features: []
# INFO:lightwood-2339:Cleaning the data
# INFO:lightwood-2339:Transforming timeseries data
# INFO:lightwood-2339:Featurizing the data
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# INFO:lightwood-2339:The block ICP is now running its explain() method
# INFO:lightwood-2339:The block AccStats is now running its explain() method
# INFO:lightwood-2339:AccStats.explain() has not been implemented, no modifications will be done to the data insights.

# %% [markdown]
# Let's check how a single row might look:

# %%
forecasts.iloc[[10]]
# Out:
#     original_index                                         prediction  \
# 10              10  [68.66232563741005, 68.71540340062103, 65.3413...
#
#                                           order_Month  \
# 10  [-271382400.0, -268704000.0, -266025600.0, -26...
#
#                               confidence  \
# 10  [0.66, 0.66, 0.66, 0.66, 0.66, 0.66]
#
#                                                 lower  \
# 10  [54.76231884040938, 52.4684134893365, 47.08699...
#
#                                                 upper
# 10  [82.56233243441072, 84.96239331190556, 83.5956...

# %% [markdown]
# You'll note that the point `prediction` has associated `lower` and `upper` bounds that are a function of the estimated `confidence` the model has on its own output. Apart from this, `order_Month` yields the timestamps of each prediction, the `anomaly` tag will let you know if the observed value falls outside of the predicted region.
#
#
# ## Visualizing a forecast
#
# Okay, time series are much easier to appreciate through plots. Let's make one:
#
# NOTE: We will use `matplotlib` to generate a simple plot of these forecasts. If you want to run this notebook locally, you will need to `pip install matplotlib` for the following code to work.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['prediction'], color='purple', label='point prediction')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['lower'], color='grey')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['upper'], color='grey')
plt.xlabel('timestep')
plt.ylabel('# sunspots')
plt.title("Forecasted amount of sunspots for the next semester")
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we have gone through how you can train a machine learning model with Lightwood to produce forecasts for a univariate time series task.
#
# There are additional parameters to further customize your timeseries settings and/or prediction insights, so be sure to check the rest of the documentation.
