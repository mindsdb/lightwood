# %% [markdown]
# # Tutorial - Time series forecasting
#
# ## Introduction
#
# Time series are an ubiquitous type of data in all types of processes. Producing forecasts for them can be highly valuable in domains like retail or industrial manufacture, among many others.
#
# Lightwood supports time series forecasting (both univariate and multivariate inputs), handling many of the pain points commonly associated with setting up a manual time series predictive pipeline.
#
# In this tutorial, we will train a lightwood predictor and analyze its forecasts for the task of counting sunspots in monthly intervals.
#
# ## Load data
#
# Let's begin by loading the dataset and looking at it:

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/mindsdb/benchmarks/main/benchmarks/datasets/monthly_sunspots/data.csv")
df
# Out:
#         Month  Sunspots
# 0     1749-01      58.0
# 1     1749-02      62.6
# 2     1749-03      70.0
# 3     1749-04      55.7
# 4     1749-05      85.0
# ...       ...       ...
# 2815  1983-08      71.8
# 2816  1983-09      50.3
# 2817  1983-10      55.8
# 2818  1983-11      33.3
# 2819  1983-12      33.4
#
# [2820 rows x 2 columns]

# %% [markdown]
# This is a very simple dataset. It's got a single column that specifies the month in which the measurement was done, and then in the 'Sunspots' column we have the actual quantity we are interested in forecasting. As such, we can characterize this as a univariate time series problem.
#
# ## Define the predictive task
#
# We will use Lightwood high level methods to state what we want to predict. As this is a time series task (because we want to leverage the notion of time to predict), we need to specify a set of arguments that will activate Lightwood's time series pipeline:

# %%
from lightwood.api.high_level import ProblemDefinition
# Out:
# INFO:lightwood-2256:No torchvision detected, image helpers not supported.
# INFO:lightwood-2256:No torchvision/pillow detected, image encoder not supported

# %%
tss = {'horizon': 6,   # the predictor will learn to forecast what the next semester counts will look like (6 data points at monthly intervals -> 6 months)
       'order_by': ['Month'], # what column is used to order the entire datset
       'window': 12           # how many past values to consider for emitting predictions
      }

pdef = ProblemDefinition.from_dict({'target': 'Sunspots',         # specify the column to forecast
                                    'timeseries_settings': tss    # pass along all time series specific parameters
                                   })

# %% [markdown]
# Now, let's do a very simple train-test split, leaving 10% of the data to check the forecasts that our predictor will produce:

# %%
cutoff = int(len(df)*0.9)

train = df[:cutoff]
test = df[cutoff:]

print(train.shape, test.shape)
# Out:
# (2538, 2) (282, 2)

# %% [markdown]
# ## Generate the predictor object
#
# Now, we can generate code for a machine learning model by using our problem definition and the data:

# %%
from lightwood.api.high_level import (
    json_ai_from_problem,
    code_from_json_ai,
    predictor_from_code
)

json_ai = json_ai_from_problem(df, problem_definition=pdef)
code = code_from_json_ai(json_ai)
predictor = predictor_from_code(code)

# uncomment this to see the generated code:
# print(code)
# Out:
# INFO:lightwood-2256:Dropping features: []
# INFO:lightwood-2256:Analyzing a sample of 2467
# INFO:lightwood-2256:from a total population of 2820, this is equivalent to 87.5% of your data.
# INFO:lightwood-2256:Infering type for: Month
# INFO:lightwood-2256:Column Month has data type date
# INFO:lightwood-2256:Infering type for: Sunspots
# INFO:lightwood-2256:Column Sunspots has data type float
# /home/runner/work/lightwood/lightwood/lightwood/helpers/text.py:242: RuntimeWarning: invalid value encountered in double_scalars
#   randomness_per_index.append(S / np.log(N))
# INFO:lightwood-2256:Starting statistical analysis
# INFO:lightwood-2256:Finished statistical analysis
# INFO:lightwood-2256:Unable to import black formatter, predictor code might be a bit ugly.

# %% [markdown]
# ## Train
#
# Okay, everything is ready now for our predictor to learn based on the training data we will provide.
#
# Internally, lightwood cleans and reshapes the data, featurizes measurements and timestamps, and comes up with a handful of different models that will be evaluated to keep the one that produces the best forecasts.
#
# Let's train the predictor. This should take a couple of minutes, at most:

# %%
predictor.learn(train)
# Out:
# INFO:lightwood-2256:Dropping features: []
# INFO:lightwood-2256:Performing statistical analysis on data
# INFO:lightwood-2256:Starting statistical analysis
# INFO:lightwood-2256:Finished statistical analysis
# INFO:lightwood-2256:Cleaning the data
# INFO:lightwood-2256:Transforming timeseries data
# INFO:lightwood-2256:Using 1 processes to reshape.
# INFO:lightwood-2256:Splitting the data into train/test
# INFO:lightwood-2256:Preparing the encoders
# INFO:lightwood-2256:Encoder prepping dict length of: 1
# INFO:lightwood-2256:Done running for: Sunspots
# INFO:lightwood-2256:time series encoder epoch [1/100000] average_loss = 0.016536667603744934
# INFO:lightwood-2256:time series encoder epoch [2/100000] average_loss = 0.006772914721961614
# INFO:lightwood-2256:time series encoder epoch [3/100000] average_loss = 0.005277954446455226
# INFO:lightwood-2256:time series encoder epoch [4/100000] average_loss = 0.004577496136341329
# INFO:lightwood-2256:time series encoder epoch [5/100000] average_loss = 0.004496108186015315
# INFO:lightwood-2256:time series encoder epoch [6/100000] average_loss = 0.004538014661618582
# INFO:lightwood-2256:time series encoder epoch [7/100000] average_loss = 0.004507196528899064
# INFO:lightwood-2256:time series encoder epoch [8/100000] average_loss = 0.004485477420995616
# INFO:lightwood-2256:time series encoder epoch [9/100000] average_loss = 0.0042719926600280865
# INFO:lightwood-2256:time series encoder epoch [10/100000] average_loss = 0.004178001224055181
# INFO:lightwood-2256:time series encoder epoch [11/100000] average_loss = 0.004110610030995985
# INFO:lightwood-2256:time series encoder epoch [12/100000] average_loss = 0.004098347654067071
# INFO:lightwood-2256:time series encoder epoch [13/100000] average_loss = 0.004072865024339505
# INFO:lightwood-2256:time series encoder epoch [14/100000] average_loss = 0.00404390230800976
# INFO:lightwood-2256:time series encoder epoch [15/100000] average_loss = 0.00403841325259668
# INFO:lightwood-2256:time series encoder epoch [16/100000] average_loss = 0.003997601999292858
# INFO:lightwood-2256:time series encoder epoch [17/100000] average_loss = 0.003963165076518017
# INFO:lightwood-2256:time series encoder epoch [18/100000] average_loss = 0.003934689270635829
# INFO:lightwood-2256:time series encoder epoch [19/100000] average_loss = 0.003986574017855416
# INFO:lightwood-2256:time series encoder epoch [20/100000] average_loss = 0.003986544815754932
# INFO:lightwood-2256:time series encoder epoch [21/100000] average_loss = 0.003947232929816805
# INFO:lightwood-2256:time series encoder epoch [22/100000] average_loss = 0.0038307887842901536
# INFO:lightwood-2256:time series encoder epoch [23/100000] average_loss = 0.004081579841895195
# INFO:lightwood-2256:time series encoder epoch [24/100000] average_loss = 0.004082985235387932
# INFO:lightwood-2256:time series encoder epoch [25/100000] average_loss = 0.0037998067779424103
# INFO:lightwood-2256:time series encoder epoch [26/100000] average_loss = 0.0038029774371045274
# INFO:lightwood-2256:time series encoder epoch [27/100000] average_loss = 0.0038743332524224464
# INFO:lightwood-2256:time series encoder epoch [28/100000] average_loss = 0.003792084583885407
# INFO:lightwood-2256:time series encoder epoch [29/100000] average_loss = 0.0037522885928847117
# INFO:lightwood-2256:time series encoder epoch [30/100000] average_loss = 0.003678560648407076
# INFO:lightwood-2256:time series encoder epoch [31/100000] average_loss = 0.00371046453035859
# INFO:lightwood-2256:time series encoder epoch [32/100000] average_loss = 0.003695723732799657
# INFO:lightwood-2256:time series encoder epoch [33/100000] average_loss = 0.0036232231507785685
# INFO:lightwood-2256:time series encoder epoch [34/100000] average_loss = 0.003694905734730268
# INFO:lightwood-2256:time series encoder epoch [35/100000] average_loss = 0.003725717199767325
# INFO:lightwood-2256:time series encoder epoch [36/100000] average_loss = 0.0038596476230855162
# INFO:lightwood-2256:Featurizing the data
# INFO:lightwood-2256:Training the mixers
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2256:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2256:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2256:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2256:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2256:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2256:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/pytorch_ranger/ranger.py:172: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1025.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# INFO:lightwood-2256:Loss of 0.5831912159919739 with learning rate 0.0001
# INFO:lightwood-2256:Loss of 0.7095090746879578 with learning rate 0.00014
# INFO:lightwood-2256:Found learning rate of: 0.0001
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2256:Loss @ epoch 1: 0.6429444998502731
# INFO:lightwood-2256:Loss @ epoch 2: 0.6406124532222748
# INFO:lightwood-2256:Loss @ epoch 3: 0.6377822905778885
# INFO:lightwood-2256:Loss @ epoch 4: 0.6345142871141434
# INFO:lightwood-2256:Loss @ epoch 5: 0.6308446526527405
# INFO:lightwood-2256:Loss @ epoch 6: 0.6268293410539627
# INFO:lightwood-2256:Loss @ epoch 7: 0.6197826713323593
# INFO:lightwood-2256:Loss @ epoch 8: 0.6148134917020798
# INFO:lightwood-2256:Loss @ epoch 9: 0.6094835698604584
# INFO:lightwood-2256:Loss @ epoch 10: 0.6038319915533066
# INFO:lightwood-2256:Loss @ epoch 11: 0.5979265868663788
# INFO:lightwood-2256:Loss @ epoch 12: 0.5918391048908234
# INFO:lightwood-2256:Loss @ epoch 13: 0.5817225873470306
# INFO:lightwood-2256:Loss @ epoch 14: 0.5751195102930069
# INFO:lightwood-2256:Loss @ epoch 15: 0.568437248468399
# INFO:lightwood-2256:Loss @ epoch 16: 0.5616742521524429
# INFO:lightwood-2256:Loss @ epoch 17: 0.5548484623432159
# INFO:lightwood-2256:Loss @ epoch 18: 0.5480526834726334
# INFO:lightwood-2256:Loss @ epoch 19: 0.5371439605951309
# INFO:lightwood-2256:Loss @ epoch 20: 0.5302286893129349
# INFO:lightwood-2256:Loss @ epoch 21: 0.52326600253582
# INFO:lightwood-2256:Loss @ epoch 22: 0.5162793546915054
# INFO:lightwood-2256:Loss @ epoch 23: 0.5092956721782684
# INFO:lightwood-2256:Loss @ epoch 24: 0.5023512244224548
# INFO:lightwood-2256:Loss @ epoch 25: 0.4911596179008484
# INFO:lightwood-2256:Loss @ epoch 26: 0.4841418117284775
# INFO:lightwood-2256:Loss @ epoch 27: 0.4771450161933899
# INFO:lightwood-2256:Loss @ epoch 28: 0.4701719731092453
# INFO:lightwood-2256:Loss @ epoch 29: 0.46319499611854553
# INFO:lightwood-2256:Loss @ epoch 30: 0.4563368409872055
# INFO:lightwood-2256:Loss @ epoch 31: 0.44547151029109955
# INFO:lightwood-2256:Loss @ epoch 32: 0.43873080611228943
# INFO:lightwood-2256:Loss @ epoch 33: 0.4320559576153755
# INFO:lightwood-2256:Loss @ epoch 34: 0.4254295378923416
# INFO:lightwood-2256:Loss @ epoch 35: 0.4188528060913086
# INFO:lightwood-2256:Loss @ epoch 36: 0.41239216178655624
# INFO:lightwood-2256:Loss @ epoch 37: 0.402196042239666
# INFO:lightwood-2256:Loss @ epoch 38: 0.3959059789776802
# INFO:lightwood-2256:Loss @ epoch 39: 0.3897003009915352
# INFO:lightwood-2256:Loss @ epoch 40: 0.38357800990343094
# INFO:lightwood-2256:Loss @ epoch 41: 0.37754467129707336
# INFO:lightwood-2256:Loss @ epoch 42: 0.3716881573200226
# INFO:lightwood-2256:Loss @ epoch 43: 0.36251507699489594
# INFO:lightwood-2256:Loss @ epoch 44: 0.35689645260572433
# INFO:lightwood-2256:Loss @ epoch 45: 0.3513665646314621
# INFO:lightwood-2256:Loss @ epoch 46: 0.3459363505244255
# INFO:lightwood-2256:Loss @ epoch 47: 0.34057804197072983
# INFO:lightwood-2256:Loss @ epoch 48: 0.33539967983961105
# INFO:lightwood-2256:Loss @ epoch 49: 0.32728660106658936
# INFO:lightwood-2256:Loss @ epoch 50: 0.3223472982645035
# INFO:lightwood-2256:Loss @ epoch 51: 0.3175235837697983
# INFO:lightwood-2256:Loss @ epoch 52: 0.31280696392059326
# INFO:lightwood-2256:Loss @ epoch 53: 0.30819685012102127
# INFO:lightwood-2256:Loss @ epoch 54: 0.30376558750867844
# INFO:lightwood-2256:Loss @ epoch 55: 0.2969738394021988
# INFO:lightwood-2256:Loss @ epoch 56: 0.2929064780473709
# INFO:lightwood-2256:Loss @ epoch 57: 0.28897059708833694
# INFO:lightwood-2256:Loss @ epoch 58: 0.2851542681455612
# INFO:lightwood-2256:Loss @ epoch 59: 0.2815157324075699
# INFO:lightwood-2256:Loss @ epoch 60: 0.278082937002182
# INFO:lightwood-2256:Loss @ epoch 61: 0.2728574573993683
# INFO:lightwood-2256:Loss @ epoch 62: 0.2696924954652786
# INFO:lightwood-2256:Loss @ epoch 63: 0.2666158825159073
# INFO:lightwood-2256:Loss @ epoch 64: 0.2636163458228111
# INFO:lightwood-2256:Loss @ epoch 65: 0.2606782913208008
# INFO:lightwood-2256:Loss @ epoch 66: 0.25787053257226944
# INFO:lightwood-2256:Loss @ epoch 67: 0.25352803617715836
# INFO:lightwood-2256:Loss @ epoch 68: 0.2508671134710312
# INFO:lightwood-2256:Loss @ epoch 69: 0.2483055293560028
# INFO:lightwood-2256:Loss @ epoch 70: 0.24585405737161636
# INFO:lightwood-2256:Loss @ epoch 71: 0.24349519610404968
# INFO:lightwood-2256:Loss @ epoch 72: 0.2413211688399315
# INFO:lightwood-2256:Loss @ epoch 73: 0.23810187727212906
# INFO:lightwood-2256:Loss @ epoch 74: 0.23612432926893234
# INFO:lightwood-2256:Loss @ epoch 75: 0.23425813019275665
# INFO:lightwood-2256:Loss @ epoch 76: 0.2324524149298668
# INFO:lightwood-2256:Loss @ epoch 77: 0.2307005375623703
# INFO:lightwood-2256:Loss @ epoch 78: 0.22904515266418457
# INFO:lightwood-2256:Loss @ epoch 79: 0.22657395154237747
# INFO:lightwood-2256:Loss @ epoch 80: 0.22512632608413696
# INFO:lightwood-2256:Loss @ epoch 81: 0.22374150156974792
# INFO:lightwood-2256:Loss @ epoch 82: 0.22239602357149124
# INFO:lightwood-2256:Loss @ epoch 83: 0.22108910977840424
# INFO:lightwood-2256:Loss @ epoch 84: 0.21985413879156113
# INFO:lightwood-2256:Loss @ epoch 85: 0.21800100058317184
# INFO:lightwood-2256:Loss @ epoch 86: 0.21687327325344086
# INFO:lightwood-2256:Loss @ epoch 87: 0.21580874919891357
# INFO:lightwood-2256:Loss @ epoch 88: 0.21478591859340668
# INFO:lightwood-2256:Loss @ epoch 89: 0.21377750486135483
# INFO:lightwood-2256:Loss @ epoch 90: 0.21282397955656052
# INFO:lightwood-2256:Loss @ epoch 91: 0.21145184338092804
# INFO:lightwood-2256:Loss @ epoch 92: 0.2106468752026558
# INFO:lightwood-2256:Loss @ epoch 93: 0.20984896272420883
# INFO:lightwood-2256:Loss @ epoch 94: 0.20912178605794907
# INFO:lightwood-2256:Loss @ epoch 95: 0.20841985195875168
# INFO:lightwood-2256:Loss @ epoch 96: 0.20776332169771194
# INFO:lightwood-2256:Loss @ epoch 97: 0.20682397484779358
# INFO:lightwood-2256:Loss @ epoch 98: 0.20627333968877792
# INFO:lightwood-2256:Loss @ epoch 99: 0.20573153346776962
# INFO:lightwood-2256:Loss @ epoch 100: 0.20522601157426834
# INFO:lightwood-2256:Loss @ epoch 101: 0.20475807785987854
# INFO:lightwood-2256:Loss @ epoch 102: 0.20434091985225677
# INFO:lightwood-2256:Loss @ epoch 103: 0.2037075161933899
# INFO:lightwood-2256:Loss @ epoch 104: 0.20331664383411407
# INFO:lightwood-2256:Loss @ epoch 105: 0.20292966812849045
# INFO:lightwood-2256:Loss @ epoch 106: 0.20255691558122635
# INFO:lightwood-2256:Loss @ epoch 107: 0.2022053748369217
# INFO:lightwood-2256:Loss @ epoch 108: 0.20188815146684647
# INFO:lightwood-2256:Loss @ epoch 109: 0.20140168070793152
# INFO:lightwood-2256:Loss @ epoch 110: 0.2011023759841919
# INFO:lightwood-2256:Loss @ epoch 111: 0.2008351907134056
# INFO:lightwood-2256:Loss @ epoch 112: 0.2005765289068222
# INFO:lightwood-2256:Loss @ epoch 113: 0.20031718164682388
# INFO:lightwood-2256:Loss @ epoch 114: 0.20008492469787598
# INFO:lightwood-2256:Loss @ epoch 115: 0.19975601881742477
# INFO:lightwood-2256:Loss @ epoch 116: 0.1995292529463768
# INFO:lightwood-2256:Loss @ epoch 117: 0.19931227713823318
# INFO:lightwood-2256:Loss @ epoch 118: 0.19913145899772644
# INFO:lightwood-2256:Loss @ epoch 119: 0.19893907010555267
# INFO:lightwood-2256:Loss @ epoch 120: 0.1987380087375641
# INFO:lightwood-2256:Loss @ epoch 121: 0.1984458938241005
# INFO:lightwood-2256:Loss @ epoch 122: 0.1982627511024475
# INFO:lightwood-2256:Loss @ epoch 123: 0.19812313467264175
# INFO:lightwood-2256:Loss @ epoch 124: 0.19801422208547592
# INFO:lightwood-2256:Loss @ epoch 125: 0.19773626327514648
# INFO:lightwood-2256:Loss @ epoch 126: 0.1975139081478119
# INFO:lightwood-2256:Loss @ epoch 127: 0.1972210928797722
# INFO:lightwood-2256:Loss @ epoch 128: 0.19700738042593002
# INFO:lightwood-2256:Loss @ epoch 129: 0.1968211606144905
# INFO:lightwood-2256:Loss @ epoch 130: 0.19668550789356232
# INFO:lightwood-2256:Loss @ epoch 131: 0.19652009755373
# INFO:lightwood-2256:Loss @ epoch 132: 0.19631564617156982
# INFO:lightwood-2256:Loss @ epoch 133: 0.1960235834121704
# INFO:lightwood-2256:Loss @ epoch 134: 0.19584716111421585
# INFO:lightwood-2256:Loss @ epoch 135: 0.1957053691148758
# INFO:lightwood-2256:Loss @ epoch 136: 0.1956220492720604
# INFO:lightwood-2256:Loss @ epoch 137: 0.19542159885168076
# INFO:lightwood-2256:Loss @ epoch 138: 0.19518017023801804
# INFO:lightwood-2256:Loss @ epoch 139: 0.19488316029310226
# INFO:lightwood-2256:Loss @ epoch 140: 0.19467388838529587
# INFO:lightwood-2256:Loss @ epoch 141: 0.19450557231903076
# INFO:lightwood-2256:Loss @ epoch 142: 0.1944131702184677
# INFO:lightwood-2256:Loss @ epoch 143: 0.19422970712184906
# INFO:lightwood-2256:Loss @ epoch 144: 0.19400770962238312
# INFO:lightwood-2256:Loss @ epoch 145: 0.19368644803762436
# INFO:lightwood-2256:Loss @ epoch 146: 0.1935054212808609
# INFO:lightwood-2256:Loss @ epoch 147: 0.19334762543439865
# INFO:lightwood-2256:Loss @ epoch 148: 0.193224236369133
# INFO:lightwood-2256:Loss @ epoch 149: 0.19301817566156387
# INFO:lightwood-2256:Loss @ epoch 150: 0.19282609969377518
# INFO:lightwood-2256:Loss @ epoch 151: 0.192530557513237
# INFO:lightwood-2256:Loss @ epoch 152: 0.19235292077064514
# INFO:lightwood-2256:Loss @ epoch 153: 0.192177914083004
# INFO:lightwood-2256:Loss @ epoch 154: 0.19203968346118927
# INFO:lightwood-2256:Loss @ epoch 155: 0.19188173860311508
# INFO:lightwood-2256:Loss @ epoch 156: 0.19171053916215897
# INFO:lightwood-2256:Loss @ epoch 157: 0.19142232835292816
# INFO:lightwood-2256:Loss @ epoch 158: 0.1912401244044304
# INFO:lightwood-2256:Loss @ epoch 159: 0.19107038527727127
# INFO:lightwood-2256:Loss @ epoch 160: 0.19094721972942352
# INFO:lightwood-2256:Loss @ epoch 161: 0.19079254567623138
# INFO:lightwood-2256:Loss @ epoch 162: 0.19062534719705582
# INFO:lightwood-2256:Loss @ epoch 163: 0.19032902270555496
# INFO:lightwood-2256:Loss @ epoch 164: 0.19012964516878128
# INFO:lightwood-2256:Loss @ epoch 165: 0.18996264785528183
# INFO:lightwood-2256:Loss @ epoch 166: 0.18984707444906235
# INFO:lightwood-2256:Loss @ epoch 167: 0.18969520181417465
# INFO:lightwood-2256:Loss @ epoch 168: 0.18949338793754578
# INFO:lightwood-2256:Loss @ epoch 169: 0.189198836684227
# INFO:lightwood-2256:Loss @ epoch 170: 0.18899907916784286
# INFO:lightwood-2256:Loss @ epoch 171: 0.1888446882367134
# INFO:lightwood-2256:Loss @ epoch 172: 0.18876024335622787
# INFO:lightwood-2256:Loss @ epoch 173: 0.1885964646935463
# INFO:lightwood-2256:Loss @ epoch 174: 0.18839504569768906
# INFO:lightwood-2256:Loss @ epoch 175: 0.18811458349227905
# INFO:lightwood-2256:Loss @ epoch 176: 0.1879342868924141
# INFO:lightwood-2256:Loss @ epoch 177: 0.1877596527338028
# INFO:lightwood-2256:Loss @ epoch 178: 0.1876452937722206
# INFO:lightwood-2256:Loss @ epoch 179: 0.18753682076931
# INFO:lightwood-2256:Loss @ epoch 180: 0.18733475357294083
# INFO:lightwood-2256:Loss @ epoch 181: 0.1870192214846611
# INFO:lightwood-2256:Loss @ epoch 182: 0.1868443340063095
# INFO:lightwood-2256:Loss @ epoch 183: 0.18670997768640518
# INFO:lightwood-2256:Loss @ epoch 184: 0.18663140386343002
# INFO:lightwood-2256:Loss @ epoch 185: 0.186562679708004
# INFO:lightwood-2256:Loss @ epoch 186: 0.18628153949975967
# INFO:lightwood-2256:Loss @ epoch 187: 0.1859956756234169
# INFO:lightwood-2256:Loss @ epoch 188: 0.18580543249845505
# INFO:lightwood-2256:Loss @ epoch 189: 0.18561986833810806
# INFO:lightwood-2256:Loss @ epoch 190: 0.18552187085151672
# INFO:lightwood-2256:Loss @ epoch 191: 0.1854376420378685
# INFO:lightwood-2256:Loss @ epoch 192: 0.18516939133405685
# INFO:lightwood-2256:Loss @ epoch 193: 0.18490568548440933
# INFO:lightwood-2256:Loss @ epoch 194: 0.18469233065843582
# INFO:lightwood-2256:Loss @ epoch 195: 0.18453631550073624
# INFO:lightwood-2256:Loss @ epoch 196: 0.18439451605081558
# INFO:lightwood-2256:Loss @ epoch 197: 0.184287391602993
# INFO:lightwood-2256:Loss @ epoch 198: 0.18409033119678497
# INFO:lightwood-2256:Loss @ epoch 199: 0.1839216873049736
# INFO:lightwood-2256:Loss @ epoch 200: 0.18365802615880966
# INFO:lightwood-2256:Loss @ epoch 201: 0.1836729198694229
# INFO:lightwood-2256:Loss @ epoch 202: 0.18363875150680542
# INFO:lightwood-2256:Loss @ epoch 203: 0.1832863613963127
# INFO:lightwood-2256:Loss @ epoch 204: 0.183064267039299
# INFO:lightwood-2256:Loss @ epoch 205: 0.18287337571382523
# INFO:lightwood-2256:Loss @ epoch 206: 0.18267852067947388
# INFO:lightwood-2256:Loss @ epoch 207: 0.18249540030956268
# INFO:lightwood-2256:Loss @ epoch 208: 0.18236997723579407
# INFO:lightwood-2256:Loss @ epoch 209: 0.18230190873146057
# INFO:lightwood-2256:Loss @ epoch 210: 0.18208637088537216
# INFO:lightwood-2256:Loss @ epoch 211: 0.18189681321382523
# INFO:lightwood-2256:Loss @ epoch 212: 0.181700199842453
# INFO:lightwood-2256:Loss @ epoch 213: 0.181553453207016
# INFO:lightwood-2256:Loss @ epoch 214: 0.18143867701292038
# INFO:lightwood-2256:Loss @ epoch 215: 0.1813720390200615
# INFO:lightwood-2256:Loss @ epoch 216: 0.18108347803354263
# INFO:lightwood-2256:Loss @ epoch 217: 0.18086206167936325
# INFO:lightwood-2256:Loss @ epoch 218: 0.18064326792955399
# INFO:lightwood-2256:Loss @ epoch 219: 0.18049317598342896
# INFO:lightwood-2256:Loss @ epoch 220: 0.18034406751394272
# INFO:lightwood-2256:Loss @ epoch 221: 0.1802280992269516
# INFO:lightwood-2256:Loss @ epoch 222: 0.18003597855567932
# INFO:lightwood-2256:Loss @ epoch 223: 0.17979500442743301
# INFO:lightwood-2256:Loss @ epoch 224: 0.17967789620161057
# INFO:lightwood-2256:Loss @ epoch 225: 0.17959324270486832
# INFO:lightwood-2256:Loss @ epoch 226: 0.179746612906456
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2256:Loss @ epoch 1: 0.1405235156416893
# INFO:lightwood-2256:Loss @ epoch 2: 0.14209243113344366
# INFO:lightwood-2256:Loss @ epoch 3: 0.14094427227973938
# INFO:lightwood-2256:Loss @ epoch 4: 0.13873509588566693
# INFO:lightwood-2256:Loss @ epoch 5: 0.14211726595054974
# INFO:lightwood-2256:Started fitting LGBM models for array prediction
# INFO:lightwood-2256:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2256:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37879 iterations given 4734.952384233475 seconds constraint
# INFO:lightwood-2256:Lightgbm model contains 29 weak estimators
# INFO:lightwood-2256:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:Model now has a total of 30 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2256:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2256:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37882 iterations given 4735.298373699188 seconds constraint
# INFO:lightwood-2256:Lightgbm model contains 31 weak estimators
# INFO:lightwood-2256:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:Model now has a total of 32 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2256:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2256:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37882 iterations given 4735.321017503738 seconds constraint
# INFO:lightwood-2256:Lightgbm model contains 30 weak estimators
# INFO:lightwood-2256:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:Model now has a total of 31 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2256:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2256:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37880 iterations given 4735.035006284714 seconds constraint
# INFO:lightwood-2256:Lightgbm model contains 24 weak estimators
# INFO:lightwood-2256:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:Model now has a total of 25 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2256:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2256:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37880 iterations given 4735.076854228973 seconds constraint
# INFO:lightwood-2256:Lightgbm model contains 24 weak estimators
# INFO:lightwood-2256:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:Model now has a total of 25 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2256:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2256:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 37877 iterations given 4734.631222724915 seconds constraint
# INFO:lightwood-2256:Lightgbm model contains 25 weak estimators
# INFO:lightwood-2256:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:Model now has a total of 26 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = original_target_train
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = original_target_dev
# INFO:lightwood-2256:Started fitting sktime forecaster for array prediction
# INFO:lightwood-2256:Ensembling the mixer
# INFO:lightwood-2256:Mixer: Neural got accuracy: 0.5258669663377543
# WARNING:lightwood-2256:This model does not output probability estimates
# INFO:lightwood-2256:Mixer: LightGBMArray got accuracy: 0.4684575624993634
# WARNING:lightwood-2256:This mixer does not output probability estimates
# INFO:lightwood-2256:Mixer: SkTime got accuracy: 0.21481464159207728
# INFO:lightwood-2256:Picked best mixer: Neural
# INFO:lightwood-2256:Analyzing the ensemble of mixers
# INFO:lightwood-2256:The block ICP is now running its analyze() method
# INFO:lightwood-2256:The block AccStats is now running its analyze() method
# INFO:lightwood-2256:Adjustment on validation requested.
# INFO:lightwood-2256:Updating the mixers
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2256:Loss @ epoch 1: 0.14152104904254278
# INFO:lightwood-2256:Loss @ epoch 2: 0.1422630101442337
# INFO:lightwood-2256:Loss @ epoch 3: 0.14258675649762154
# INFO:lightwood-2256:Loss @ epoch 4: 0.14249470829963684
# INFO:lightwood-2256:Loss @ epoch 5: 0.14245746036370596
# INFO:lightwood-2256:Updating array of LGBM models...
# INFO:lightwood-2256:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:Model now has a total of 31 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2256:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:Model now has a total of 33 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2256:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:Model now has a total of 32 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2256:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:Model now has a total of 26 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2256:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:Model now has a total of 26 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2256:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2256:Model now has a total of 27 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = original_target_train
# INFO:lightwood-2256:Started fitting sktime forecaster for array prediction

# %% [markdown]
# ## Predict
#
# Once the predictor has trained, we can use it to generate 6-month forecasts for each of the test set data points:

# %%
forecasts = predictor.predict(test)
# Out:
# INFO:lightwood-2256:Dropping features: []
# INFO:lightwood-2256:Cleaning the data
# INFO:lightwood-2256:Transforming timeseries data
# INFO:lightwood-2256:Featurizing the data
# /opt/hostedtoolcache/Python/3.9.9/x64/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# INFO:lightwood-2256:The block ICP is now running its explain() method
# INFO:lightwood-2256:The block AccStats is now running its explain() method
# INFO:lightwood-2256:AccStats.explain() has not been implemented, no modifications will be done to the data insights.

# %% [markdown]
# Let's check how a single row might look:

# %%
forecasts.iloc[[10]]
# Out:
#     original_index                                         prediction  \
# 10              10  [68.8688668582832, 72.7056233456982, 67.096918...
#
#                                           order_Month  \
# 10  [-273283200.0, -270604800.0, -267926400.0, -26...
#
#                               confidence  \
# 10  [0.62, 0.62, 0.62, 0.62, 0.62, 0.62]
#
#                                                 lower  \
# 10  [55.72053564539189, 57.33722765454159, 49.8297...
#
#                                                 upper
# 10  [82.0171980711745, 88.0740190368548, 84.364118...

# %% [markdown]
# You'll note that the point `prediction` has associated `lower` and `upper` bounds that are a function of the estimated `confidence` the model has on its own output. Apart from this, `order_Month` yields the timestamps of each prediction, the `anomaly` tag will let you know if the observed value falls outside of the predicted region.
#
#
# ## Visualizing a forecast
#
# Okay, time series are much easier to appreciate through plots. Let's make one:
#
# NOTE: We will use `matplotlib` to generate a simple plot of these forecasts. If you want to run this notebook locally, you will need to `pip install matplotlib` for the following code to work.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['prediction'], color='purple', label='point prediction')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['lower'], color='grey')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['upper'], color='grey')
plt.xlabel('timestep')
plt.ylabel('# sunspots')
plt.title("Forecasted amount of sunspots for the next semester")
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we have gone through how you can train a machine learning model with Lightwood to produce forecasts for a univariate time series task.
#
# There are additional parameters to further customize your timeseries settings and/or prediction insights, so be sure to check the rest of the documentation.
