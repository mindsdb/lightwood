# %% [markdown]
# # Tutorial - Time series forecasting
#
# ## Introduction
#
# Time series are an ubiquitous type of data in all types of processes. Producing forecasts for them can be highly valuable in domains like retail or industrial manufacture, among many others.
#
# Lightwood supports time series forecasting (both univariate and multivariate inputs), handling many of the pain points commonly associated with setting up a manual time series predictive pipeline.
#
# In this tutorial, we will train a lightwood predictor and analyze its forecasts for the task of counting sunspots in monthly intervals.
#
# ## Load data
#
# Let's begin by loading the dataset and looking at it:

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/mindsdb/benchmarks/main/benchmarks/datasets/monthly_sunspots/data.csv")
df
# Out:
#         Month  Sunspots
# 0     1749-01      58.0
# 1     1749-02      62.6
# 2     1749-03      70.0
# 3     1749-04      55.7
# 4     1749-05      85.0
# ...       ...       ...
# 2815  1983-08      71.8
# 2816  1983-09      50.3
# 2817  1983-10      55.8
# 2818  1983-11      33.3
# 2819  1983-12      33.4
#
# [2820 rows x 2 columns]

# %% [markdown]
# This is a very simple dataset. It's got a single column that specifies the month in which the measurement was done, and then in the 'Sunspots' column we have the actual quantity we are interested in forecasting. As such, we can characterize this as a univariate time series problem.
#
# ## Define the predictive task
#
# We will use Lightwood high level methods to state what we want to predict. As this is a time series task (because we want to leverage the notion of time to predict), we need to specify a set of arguments that will activate Lightwood's time series pipeline:

# %%
from lightwood.api.high_level import ProblemDefinition
# Out:
# [nltk_data] Downloading package punkt to /home/runner/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
tss = {'nr_predictions': 6,   # the predictor will learn to forecast what the next semester counts will look like (6 data points at monthly intervals -> 6 months)
       'order_by': ['Month'], # what column is used to order the entire datset
       'window': 12           # how many past values to consider for emitting predictions
      }

pdef = ProblemDefinition.from_dict({'target': 'Sunspots',         # specify the column to forecast
                                    'timeseries_settings': tss    # pass along all time series specific parameters
                                   })

# %% [markdown]
# Now, let's do a very simple train-test split, leaving 10% of the data to check the forecasts that our predictor will produce:

# %%
cutoff = int(len(df)*0.9)

train = df[:cutoff]
test = df[cutoff:]

print(train.shape, test.shape)
# Out:
# (2538, 2) (282, 2)

# %% [markdown]
# ## Generate the predictor object
#
# Now, we can generate code for a machine learning model by using our problem definition and the data:

# %%
from lightwood.api.high_level import (
    json_ai_from_problem,
    code_from_json_ai,
    predictor_from_code
)

json_ai = json_ai_from_problem(df, problem_definition=pdef)
code = code_from_json_ai(json_ai)
predictor = predictor_from_code(code)

# uncomment this to see the generated code:
# print(code)
# Out:
# INFO:lightwood-2261:Dropping features: []
# INFO:lightwood-2261:Analyzing a sample of 2467
# INFO:lightwood-2261:from a total population of 2820, this is equivalent to 87.5% of your data.
# INFO:lightwood-2261:Infering type for: Month
# INFO:lightwood-2261:Column Month has data type date
# INFO:lightwood-2261:Infering type for: Sunspots
# INFO:lightwood-2261:Column Sunspots has data type float
# /home/runner/work/lightwood/lightwood/lightwood/helpers/text.py:236: RuntimeWarning: invalid value encountered in double_scalars
#   randomness_per_index.append(S / np.log(N))
# INFO:lightwood-2261:Starting statistical analysis
# INFO:lightwood-2261:Finished statistical analysis
# INFO:lightwood-2261:Unable to import black formatter, predictor code might be a bit ugly.

# %% [markdown]
# ## Train
#
# Okay, everything is ready now for our predictor to learn based on the training data we will provide.
#
# Internally, lightwood cleans and reshapes the data, featurizes measurements and timestamps, and comes up with a handful of different models that will be evaluated to keep the one that produces the best forecasts.
#
# Let's train the predictor. This should take a couple of minutes, at most:

# %%
predictor.learn(train)
# Out:
# INFO:lightwood-2261:Dropping features: []
# INFO:lightwood-2261:Performing statistical analysis on data
# INFO:lightwood-2261:Starting statistical analysis
# INFO:lightwood-2261:Finished statistical analysis
# INFO:lightwood-2261:Cleaning the data
# INFO:lightwood-2261:Transforming timeseries data
# INFO:lightwood-2261:Using 1 processes to reshape.
# INFO:lightwood-2261:Splitting the data into train/test
# INFO:lightwood-2261:Preparing the encoders
# INFO:lightwood-2261:Encoder prepping dict length of: 1
# INFO:lightwood-2261:Done running for: Sunspots
# INFO:lightwood-2261:time series encoder epoch [1/100000] average_loss = 0.01843487452707462
# INFO:lightwood-2261:time series encoder epoch [2/100000] average_loss = 0.007301074729357021
# INFO:lightwood-2261:time series encoder epoch [3/100000] average_loss = 0.005594222730793102
# INFO:lightwood-2261:time series encoder epoch [4/100000] average_loss = 0.0048316995686426036
# INFO:lightwood-2261:time series encoder epoch [5/100000] average_loss = 0.004473394471964014
# INFO:lightwood-2261:time series encoder epoch [6/100000] average_loss = 0.004396596044864295
# INFO:lightwood-2261:time series encoder epoch [7/100000] average_loss = 0.004248358220999677
# INFO:lightwood-2261:time series encoder epoch [8/100000] average_loss = 0.004282138859195215
# INFO:lightwood-2261:time series encoder epoch [9/100000] average_loss = 0.00421474331980894
# INFO:lightwood-2261:time series encoder epoch [10/100000] average_loss = 0.004198973615109894
# INFO:lightwood-2261:time series encoder epoch [11/100000] average_loss = 0.004172237937311271
# INFO:lightwood-2261:time series encoder epoch [12/100000] average_loss = 0.004164964915263438
# INFO:lightwood-2261:time series encoder epoch [13/100000] average_loss = 0.004159387264820817
# INFO:lightwood-2261:time series encoder epoch [14/100000] average_loss = 0.004120741616534057
# INFO:lightwood-2261:time series encoder epoch [15/100000] average_loss = 0.004112133073827686
# INFO:lightwood-2261:time series encoder epoch [16/100000] average_loss = 0.004079028879042622
# INFO:lightwood-2261:time series encoder epoch [17/100000] average_loss = 0.004071156829007104
# INFO:lightwood-2261:time series encoder epoch [18/100000] average_loss = 0.004080370519704179
# INFO:lightwood-2261:time series encoder epoch [19/100000] average_loss = 0.004088299428229272
# INFO:lightwood-2261:time series encoder epoch [20/100000] average_loss = 0.00407173987698691
# INFO:lightwood-2261:time series encoder epoch [21/100000] average_loss = 0.00399460056048833
# INFO:lightwood-2261:time series encoder epoch [22/100000] average_loss = 0.003866119910981269
# INFO:lightwood-2261:time series encoder epoch [23/100000] average_loss = 0.0037953556237800335
# INFO:lightwood-2261:time series encoder epoch [24/100000] average_loss = 0.003919446034199211
# INFO:lightwood-2261:time series encoder epoch [25/100000] average_loss = 0.004070654295682384
# INFO:lightwood-2261:time series encoder epoch [26/100000] average_loss = 0.003925594806461911
# INFO:lightwood-2261:time series encoder epoch [27/100000] average_loss = 0.003907260088190378
# INFO:lightwood-2261:time series encoder epoch [28/100000] average_loss = 0.00405957998022169
# INFO:lightwood-2261:time series encoder epoch [29/100000] average_loss = 0.0038712735550609687
# INFO:lightwood-2261:time series encoder epoch [30/100000] average_loss = 0.0038496283859262973
# INFO:lightwood-2261:time series encoder epoch [31/100000] average_loss = 0.004125821271346503
# INFO:lightwood-2261:time series encoder epoch [32/100000] average_loss = 0.003960413308246139
# INFO:lightwood-2261:time series encoder epoch [33/100000] average_loss = 0.0040706156533556375
# INFO:lightwood-2261:time series encoder epoch [34/100000] average_loss = 0.0040695153081976776
# INFO:lightwood-2261:time series encoder epoch [35/100000] average_loss = 0.003833085023922688
# INFO:lightwood-2261:time series encoder epoch [36/100000] average_loss = 0.003870576999332885
# INFO:lightwood-2261:time series encoder epoch [37/100000] average_loss = 0.003746510519694738
# INFO:lightwood-2261:time series encoder epoch [38/100000] average_loss = 0.0036650392087523797
# INFO:lightwood-2261:time series encoder epoch [39/100000] average_loss = 0.0036732712405038643
# INFO:lightwood-2261:time series encoder epoch [40/100000] average_loss = 0.0036291219048878768
# INFO:lightwood-2261:time series encoder epoch [41/100000] average_loss = 0.0036489531600511927
# INFO:lightwood-2261:time series encoder epoch [42/100000] average_loss = 0.0035002816005880867
# INFO:lightwood-2261:time series encoder epoch [43/100000] average_loss = 0.0034004994629244366
# INFO:lightwood-2261:time series encoder epoch [44/100000] average_loss = 0.003766387504880603
# INFO:lightwood-2261:Featurizing the data
# INFO:lightwood-2261:Training the mixers
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2261:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2261:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2261:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2261:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2261:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# WARNING:lightwood-2261:LightGBM running on CPU, this somewhat slower than the GPU version, consider using a GPU instead
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/pytorch_ranger/ranger.py:172: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1025.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# INFO:lightwood-2261:Loss of 0.6526395678520203 with learning rate 0.0001
# INFO:lightwood-2261:Loss of 0.8773521184921265 with learning rate 0.00014
# INFO:lightwood-2261:Found learning rate of: 0.0001
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2261:Loss @ epoch 1: 0.7948245704174042
# INFO:lightwood-2261:Loss @ epoch 2: 0.7914908230304718
# INFO:lightwood-2261:Loss @ epoch 3: 0.787421703338623
# INFO:lightwood-2261:Loss @ epoch 4: 0.7826807200908661
# INFO:lightwood-2261:Loss @ epoch 5: 0.7773492634296417
# INFO:lightwood-2261:Loss @ epoch 6: 0.7715007066726685
# INFO:lightwood-2261:Loss @ epoch 7: 0.7612430453300476
# INFO:lightwood-2261:Loss @ epoch 8: 0.7541359066963196
# INFO:lightwood-2261:Loss @ epoch 9: 0.746649980545044
# INFO:lightwood-2261:Loss @ epoch 10: 0.7387912273406982
# INFO:lightwood-2261:Loss @ epoch 11: 0.7305888831615448
# INFO:lightwood-2261:Loss @ epoch 12: 0.7220957577228546
# INFO:lightwood-2261:Loss @ epoch 13: 0.7079432010650635
# INFO:lightwood-2261:Loss @ epoch 14: 0.6986496299505234
# INFO:lightwood-2261:Loss @ epoch 15: 0.6891179382801056
# INFO:lightwood-2261:Loss @ epoch 16: 0.6793617904186249
# INFO:lightwood-2261:Loss @ epoch 17: 0.6693423092365265
# INFO:lightwood-2261:Loss @ epoch 242: 0.1889207363128662
# INFO:lightwood-2261:Loss @ epoch 243: 0.1887778714299202
# INFO:lightwood-2261:Loss @ epoch 244: 0.18868301808834076
# INFO:lightwood-2261:Loss @ epoch 245: 0.18845457583665848
# INFO:lightwood-2261:Loss @ epoch 246: 0.18828676640987396
# INFO:lightwood-2261:Loss @ epoch 247: 0.1879260167479515
# INFO:lightwood-2261:Loss @ epoch 248: 0.18787693977355957
# INFO:lightwood-2261:Loss @ epoch 249: 0.187698133289814
# INFO:lightwood-2261:Loss @ epoch 250: 0.1877918317914009
# INFO:lightwood-2261:Loss @ epoch 251: 0.18750931322574615
# INFO:lightwood-2261:Loss @ epoch 252: 0.18725214898586273
# INFO:lightwood-2261:Loss @ epoch 253: 0.18693936616182327
# INFO:lightwood-2261:Loss @ epoch 254: 0.1868169754743576
# INFO:lightwood-2261:Loss @ epoch 255: 0.18661657720804214
# INFO:lightwood-2261:Loss @ epoch 256: 0.1866498962044716
# INFO:lightwood-2261:Loss @ epoch 257: 0.18662860244512558
# INFO:lightwood-2261:Loss @ epoch 258: 0.18632296472787857
# INFO:lightwood-2261:Loss @ epoch 259: 0.18598240613937378
# INFO:lightwood-2261:Loss @ epoch 260: 0.18587613105773926
# INFO:lightwood-2261:Loss @ epoch 261: 0.18586540967226028
# INFO:lightwood-2261:Loss @ epoch 262: 0.18606127798557281
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2261:Loss @ epoch 1: 0.1483749435706572
# INFO:lightwood-2261:Loss @ epoch 2: 0.1475808390162208
# INFO:lightwood-2261:Loss @ epoch 3: 0.15122473646293988
# INFO:lightwood-2261:Loss @ epoch 4: 0.1467558280988173
# INFO:lightwood-2261:Loss @ epoch 5: 0.15011644227938217
# INFO:lightwood-2261:Started fitting LGBM models for array prediction
# INFO:lightwood-2261:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2261:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2261:Lightgbm model contains 27 weak estimators
# INFO:lightwood-2261:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:Model now has a total of 28 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2261:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2261:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2261:Lightgbm model contains 25 weak estimators
# INFO:lightwood-2261:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:Model now has a total of 26 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2261:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2261:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2261:Lightgbm model contains 23 weak estimators
# INFO:lightwood-2261:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:Model now has a total of 24 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2261:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2261:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2261:Lightgbm model contains 19 weak estimators
# INFO:lightwood-2261:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:Model now has a total of 20 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2261:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2261:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2261:Lightgbm model contains 20 weak estimators
# INFO:lightwood-2261:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:Model now has a total of 21 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev_data.data_frame[self.target] = dev_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2261:Started fitting LGBM model
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:A single GBM iteration takes 0.1 seconds
# INFO:lightwood-2261:Training GBM (<module 'lightgbm' from '/opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/__init__.py'>) with 882 iterations given 110.33333333333333 seconds constraint
# INFO:lightwood-2261:Lightgbm model contains 25 weak estimators
# INFO:lightwood-2261:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:Model now has a total of 26 weak estimators
# INFO:lightwood-2261:Started fitting sktime forecaster for array prediction
# INFO:lightwood-2261:Ensembling the mixer
# INFO:lightwood-2261:Mixer: Neural got accuracy: 0.5372099247076619
# INFO:lightwood-2261:Mixer: LightGBMArray got accuracy: 0.46709323456857427
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/pmdarima/arima/arima.py:692: UserWarning: As of version 1.5.0 'typ' is no longer a valid arg for predict. In future versions this will raise a TypeError.
#   warnings.warn("As of version 1.5.0 'typ' is no longer a valid "
# INFO:lightwood-2261:Mixer: SkTime got accuracy: 0.2025435825521946
# INFO:lightwood-2261:Picked best mixer: Neural
# INFO:lightwood-2261:Analyzing the ensemble of mixers
# INFO:lightwood-2261:The block ICP is now running its analyze() method
# INFO:lightwood-2261:The block AccStats is now running its analyze() method
# INFO:lightwood-2261:Adjustment on validation requested.
# INFO:lightwood-2261:Updating the mixers
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# INFO:lightwood-2261:Loss @ epoch 1: 0.15111780042449632
# INFO:lightwood-2261:Loss @ epoch 2: 0.151806170741717
# INFO:lightwood-2261:Loss @ epoch 3: 0.15174935261408487
# INFO:lightwood-2261:Loss @ epoch 4: 0.15099822854002318
# INFO:lightwood-2261:Loss @ epoch 5: 0.15101016064484915
# INFO:lightwood-2261:Loss @ epoch 6: 0.1519240029156208
# INFO:lightwood-2261:Updating array of LGBM models...
# INFO:lightwood-2261:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:Model now has a total of 29 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2261:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:Model now has a total of 27 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2261:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:Model now has a total of 25 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2261:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:Model now has a total of 21 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2261:Updating lightgbm model with 1 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:Model now has a total of 22 weak estimators
# /home/runner/work/lightwood/lightwood/lightwood/mixer/lightgbm_array.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.data_frame[self.target] = train_data.data_frame[f'{self.target}_timestep_{timestep}']
# INFO:lightwood-2261:Updating lightgbm model with 1.5 iterations
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/lightgbm/engine.py:240: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# INFO:lightwood-2261:Model now has a total of 27 weak estimators
# INFO:lightwood-2261:Started fitting sktime forecaster for array prediction

# %% [markdown]
# ## Predict
#
# Once the predictor has trained, we can use it to generate 6-month forecasts for each of the test set data points:

# %%
forecasts = predictor.predict(test)
# Out:
# INFO:lightwood-2261:Dropping features: []
# INFO:lightwood-2261:Cleaning the data
# INFO:lightwood-2261:Transforming timeseries data
# INFO:lightwood-2261:Featurizing the data
# /opt/hostedtoolcache/Python/3.9.8/x64/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# INFO:lightwood-2261:The block ICP is now running its explain() method
# INFO:lightwood-2261:The block AccStats is now running its explain() method
# INFO:lightwood-2261:AccStats.explain() has not been implemented, no modifications will be done to the data insights.

# %% [markdown]
# Let's check how a single row might look:

# %%
forecasts.iloc[[10]]
# Out:
#                                            prediction  truth  \
# 10  [73.82232329530535, 73.64624697202754, 69.0295...   51.0
#
#                                           order_Month  \
# 10  [-272678400.0, -270000000.0, -267321600.0, -26...
#
#                               confidence  \
# 10  [0.73, 0.73, 0.73, 0.73, 0.73, 0.73]
#
#                                                 lower  \
# 10  [53.12221646310989, 52.94614013983208, 48.3294...
#
#                                                 upper  anomaly
# 10  [94.52243012750081, 94.346353804223, 89.729702...     True

# %% [markdown]
# You'll note that the point `prediction` has associated `lower` and `upper` bounds that are a function of the estimated `confidence` the model has on its own output. Apart from this, `order_Month` yields the timestamps of each prediction, `truth` lets us know what is the one-step-ahead observed value (if it exists at all). Finally, the `anomaly` tag will let you know if the observed value falls outside of the predicted region.
#
#
# ## Visualizing a forecast
#
# Okay, time series are much easier to appreciate through plots. Let's make one:
#
# NOTE: We will use `matplotlib` to generate a simple plot of these forecasts. If you want to run this notebook locally, you will need to `pip install matplotlib` for the following code to work.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.plot(forecasts['truth'].iloc[-24:], color='green', label='observed series')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['prediction'], color='purple', label='point prediction')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['lower'], color='grey')
plt.plot([None for _ in range(forecasts.shape[0])] + forecasts.iloc[-1]['upper'], color='grey')
plt.xlabel('timestep')
plt.ylabel('# sunspots')
plt.title("Forecasted amount of sunspots for the next semester")
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we have gone through how you can train a machine learning model with Lightwood to produce forecasts for a univariate time series task.
#
# There are additional parameters to further customize your timeseries settings and/or prediction insights, so be sure to check the rest of the documentation.
